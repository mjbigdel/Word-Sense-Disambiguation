# %%
# !pip install tensorflow==1.12.0
# !pip install tensorflow 
# TensorFlow and tf.keras
# its just working with tensorflow 1.13.1, with others has problem
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.14.0

# %% [markdown]
# **- goolge Colab Configuration**

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **- Setting root address to project in Google Drive**

# %%
# !ls "/content/gdrive/My Drive/NLPHW3"
root_path = '/content/gdrive/My Drive/NLPHW3'

# %%
# Imports
from collections import Counter
import codecs
import xml.etree.cElementTree as etree
import pickle
import nltk
nltk.download('wordnet')
import numpy as np
import copy
from nltk.corpus import wordnet as wn


# Added Chars to dictionaries
UNK = "<UNK>"
PAD = "<PAD>"


RESOURCE_PATH = root_path+'/resources/'

MAP_WN2BN_FILE = RESOURCE_PATH + 'babelnet2wordnet.tsv'
MAP_BN2WNDOMAIN_FILE = RESOURCE_PATH + 'babelnet2wndomains.tsv'
MAP_BN2LEXNAMES_FILE = RESOURCE_PATH + 'babelnet2lexnames.tsv'
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
all_dict_data = pickle.load(open(root_path+'/semcor/semcor/all_dict_data.pkl', "rb"))

RawWords2id = all_dict_data["RawWords2id"]
SenseWords2id = all_dict_data["SenseWords2id"] 
pos2id = all_dict_data["pos2id"] 
lex2id = all_dict_data["lex2id"] 
wnDomain2id = all_dict_data["wnDomain2id"]

print(len(pos2id))
print(len(SenseWords2id))
# Out:
# 12
# 60919

# %% [markdown]
# **- python library imports**

# %%
# ===-----------------------------------------------------------------------===
# Trainig Section
# ===-----------------------------------------------------------------------===

# function for add padding for train_y in every batch based on maximum length of sentence in that batch
# this method boost the performance of running.
def padding(X,padding_word):
	max_len = 0
	for x in X:
		if len(x) > max_len:
			max_len = len(x)
	padded_X = np.ones((len(X), max_len), dtype=np.int32) * padding_word
	for i in range(len(X)):
		for j in range(len(X[i])):
			padded_X[i, j] = X[i][j]
	return padded_X


# padding function for train_x
def padding3(X,padding_word):
	max_len = 0
	for x in X:
		if len(x) > max_len:
			max_len = len(x)
	padded_X = np.ones((len(X), max_len), dtype=np.int32) * padding_word
	for i in range(len(X)):
		for j in range(len(X[i])):
			padded_X[i, j] = X[i][j]
	return padded_X

# function for calculating umber of hits and number of all predictions.
def number_of_batch_hits(y_batch_pred,y_batch_true):
    num_hits = 0
    num_all_chars = 0    
    for i in range(len(y_batch_true)):
        for j in range(len(y_batch_true[i])):
            num_all_chars = num_all_chars+1
            if y_batch_pred[i][j] == y_batch_true[i][j]:
                num_hits = num_hits+1    
    return num_hits, num_all_chars

# function for calculating umber of hits and number of all predictions.
def number_of_batch_sense_hits(y_batch_pred,y_batch_true):
    num_hits = 0
    num_all_chars = 0    
    for i in range(len(y_batch_true)):
        for j in range(len(y_batch_true[i])):
            if id2Sensewords[y_batch_true[i][j]].startswith('bn'):
                num_all_chars = num_all_chars+1
                if y_batch_pred[i][j] == y_batch_true[i][j]:
                    num_hits = num_hits+1    
    return num_hits, num_all_chars

# ----------------- Add Summary Function ------------------------------------------
def add_summary(writer, name, value, global_step):
    summary = tf.Summary(value=[tf.Summary.Value(tag=name, simple_value=value)])
    writer.add_summary(summary, global_step=global_step)                                 
    

## ----------------------------------------------------------------------------
def mask_lemmaToSenses_batch(x_Raw_Sent_batch, y_allSenses_Sent_batch, y_allSenses_Sent_id_batch, SenseWords2id):
     
    max_len = 0    
    for inp in x_Raw_Sent_batch:
        if len(inp) > max_len:
            max_len = len(inp)
            
    mask_lemma2sense_batch = [0]*np.ones(shape = (len(x_Raw_Sent_batch), max_len, len(SenseWords2id)))
            
    for i in range(len(x_Raw_Sent_batch)):
        for j in range(len(x_Raw_Sent_batch[i])):
            for k in range(len(y_allSenses_Sent_batch[i][j])):            
#                 if SenseWords2id.get(y_allSenses_Sent_batch[i][j][k]) is not None:
                mask_lemma2sense_batch[i][j][y_allSenses_Sent_id_batch[i][j][k]] = 1    
#                    mask_lemma2sense_batch[rawWords_batch2id[x_Raw_Sent_batch[i][j]]][y_allSenses_Sent_id_batch[i][j][k]] = 1    
#                 else:
#                     print('not in dictionary sense is : ', y_allSenses_Sent_batch[i][j][k])
            
    return mask_lemma2sense_batch    

#x_Raw_Sent_batch = x_Raw_Sent[:12]
#y_allSenses_Sent_batch = y_allSenses_Sent[:12]
#y_allSenses_Sent_id_batch = y_allSenses_Sent_id[:12]
#
#mask_lemma2sense_batch = mask_lemmaToSenses_batch(x_Raw_Sent_batch, y_allSenses_Sent_batch, y_allSenses_Sent_id_batch, SenseWords2id)    

# use pretrained embeddings function, for chars we are using pretrain file and for bigram, trigram 
# and fourgram we are using mean of embeddings of all unigrams of them
def reading_pretrained_sense_embeddings(filename, RawWords2id):
    # Reading Pretrained Embeddings from file
    pretrain_embeddigs = {}
    with codecs.open(filename, "r", "utf-8") as f:
        for line in f:
            pre_train = line.split()
            if len(pre_train) > 2:
                word = pre_train[0]
                if word in RawWords2id:
                    vec = pre_train[1:]
                    pretrain_embeddigs[word] = vec                
    
    print("pretrained embeddings files reading finished ...")
    # making embeddings for all RawWords2id.
    embedding_dim = len(next(iter(pretrain_embeddigs.values())))
    out_of_vocab = 0
    out = np.ones((len(RawWords2id), embedding_dim))*0.001
    for word in RawWords2id.keys():
        if len(word) == 1:
            if word in pretrain_embeddigs.keys():        
                out[RawWords2id[word]]=np.array(pretrain_embeddigs[word])
            else:                
                out_of_vocab+=1
                np.random.uniform(-1.0, 1.0, embedding_dim)
        
    return out,out_of_vocab

# %%
PAD_ID = RawWords2id[PAD]
id2Sensewords = dict(zip(SenseWords2id.values(), SenseWords2id.keys()))

sense_embeddings, out_of_vocab = reading_pretrained_sense_embeddings(root_path + '/allWordsSensesembeddings.vec', RawWords2id)
print('sense_embeddings: ', len(sense_embeddings))
print('out_of_vocab: ', out_of_vocab)

# we are using pretrained embedding - len(words2id)
VOCAB_SIZE =  len(RawWords2id)
WORD_EMBEDDING_DIM = 100
print('WORD_EMBEDDING_DIM: ', WORD_EMBEDDING_DIM)
print('VOCAB_SIZE: ', VOCAB_SIZE)

# some Basic Hyper parameters
NUM_EPOCHS = 5
BATCH_SIZE = 4
HIDDEN_LAYER_DIM = 256
LEARNING_RATE = 1
NUM_CLASSES = len(SenseWords2id)
print('num sense classes: ', NUM_CLASSES)
L2_REGU_LAMBDA=0.0001
NUM_LAYERS = 2
CLIP=10
crf_lambda = 0.05
num_sense_pos = len(pos2id)
print('num_sense_pos: ', num_sense_pos)
num_sense_lex = len(lex2id)
print('num_sense_lex: ', num_sense_lex)
num_sense_wnDomain = len(wnDomain2id)
print('num_sense_wnDomain: ', num_sense_wnDomain)
VERY_BIG_NUMBER = 1e30
summaries = []
# Out:
# pretrained embeddings files reading finished ...
# sense_embeddings:  32893
# out_of_vocab:  5
# WORD_EMBEDDING_DIM:  100
# VOCAB_SIZE:  32893
# num sense classes:  60919
# num_sense_pos:  12
# num_sense_lex:  46
# num_sense_wnDomain:  160

# %%
# --------------------- Tensorflow part ---------------------------------------------------
import tensorflow as tf
from tensorflow.contrib import layers
from tensorflow.contrib import crf

def create_tensorflow_model(vocab_size, embedding_dim, hidden_layer_dim, sense_embed_bool = False, total_loss = 0):
    print("Creating TENSORFLOW model")
     
    # Inputs have (batch_size, timesteps) shape.
    input_ = tf.placeholder(dtype = tf.int32, shape=[None, None], name='input_x')   
    # Labels have (batch_size,) shape.
    labels = tf.placeholder(dtype = tf.int32, shape=[None, None], name='labels_BN')    
    
    y_wnDomain = tf.placeholder(dtype = tf.int32, shape=[None, None],name='wnDomain_tag')        
    
    # dropout_keep_prob is a scalar.
    dropout_keep_prob = tf.placeholder(dtype = tf.float32, name='dropout_keep_prob')
    
    seq_length = tf.reduce_sum(tf.cast( tf.not_equal(input_[:,:], tf.ones_like(input_[:,:] ) * PAD_ID ), tf.int32), 1)    
    print('seq_length: ', seq_length)
    
    max_sent_size = tf.size(input_[0,:])    
    print('max_sent_size: ', max_sent_size)
    
    batch_size = tf.size(input_[:,0])    
    print('batch_size: ', batch_size)        
    
    mask_RawTosense_batch = tf.placeholder(dtype = tf.bool, shape=[None, None, None], name='mask_Raw2Senses')    
    print('mask_RawTosense_batch: ', mask_RawTosense_batch)    
    
    mask_wnDomain2sense = tf.placeholder(dtype = tf.bool, shape=[None, None], name='mask_Raw2Senses')    
    print('mask_wnDomain2sense: ', mask_wnDomain2sense)
    mask_matrix_wnDomain = tf.tile(tf.expand_dims(mask_wnDomain2sense, 0), [batch_size, 1, 1])     
    print('mask_matrix_wnDomain: ', mask_matrix_wnDomain)
        
    x_mask = tf.not_equal(input_[:,:], tf.ones_like(input_[:,:] ) * PAD_ID )    
    print('x_mask: ', x_mask)
    
    attention_mask = (tf.cast(x_mask, 'float') -1) * VERY_BIG_NUMBER     
    print('attention_mask: ', attention_mask)

    # initialize weights randomly from a Gaussian distribution
    # step 1: create the initializer for weights
    weight_initer = tf.truncated_normal_initializer(mean=0.0, stddev=0.01)
        
## ---------------------------- embedding Block --------------------------------------------
## -----------------------------------------------------------------------------------------  
    with tf.variable_scope('embeddings', reuse=tf.AUTO_REUSE):
        if sense_embed_bool:
            embedding_matrix = tf.Variable(sense_embeddings, dtype=tf.float32, name='embedding')
        else:
            embedding_matrix = tf.get_variable("embeddings", shape=[vocab_size, embedding_dim])
        
        embeddings = tf.nn.embedding_lookup(embedding_matrix, input_)        
        print('embeddings: ', embeddings)
        
        embeddings = tf.reshape(embeddings,[batch_size, max_sent_size, embedding_dim]) #         
        print('embeddings: ', embeddings)

        embeddings = tf.nn.dropout(tf.cast(embeddings, tf.float32), dropout_keep_prob) #     embeddings shape (batch size, sentence length with padding, 100) 

        print ('embeddings is ok \n')
                
    ## --------------------------- wnDomain Block ------------------------------------------------
    ## -------------------------------------------------------------------------------------------
    with tf.variable_scope('rnn_cell_wnDomain', reuse=tf.AUTO_REUSE):
        print ('lstm_cell_wnDomain is is ok ... ')
        def lstm_cell1():
            return tf.nn.rnn_cell.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(hidden_layer_dim), output_keep_prob=dropout_keep_prob)

        stacked_fw_lstm_wnDomain = tf.nn.rnn_cell.MultiRNNCell(
            [lstm_cell1() for _ in range(NUM_LAYERS)])

        stacked_bw_lstm_wnDomain = tf.nn.rnn_cell.MultiRNNCell(
        [lstm_cell1() for _ in range(NUM_LAYERS)])

    with tf.variable_scope('rnn_wnDomain', reuse=tf.AUTO_REUSE):                        
            (forward_output_wnDomain, backword_output_wnDomain), _ = tf.nn.bidirectional_dynamic_rnn(
                cell_fw = stacked_fw_lstm_wnDomain,
                cell_bw = stacked_bw_lstm_wnDomain,
                inputs = embeddings,
                sequence_length = seq_length,
                dtype=tf.float32
            )

            outputBD_wnDomain = tf.concat([forward_output_wnDomain, backword_output_wnDomain], axis=2)
            print('outputBD_wnDomain: ', outputBD_wnDomain) # shape is batch*max_len*(2*hidden_layer_size) 

            print ('outputBD_wnDomain is ok \n')         

    with tf.variable_scope("softmax_layer_wnDomain", reuse=tf.AUTO_REUSE):
        W_wnDomain = tf.get_variable("W_wnDomain", shape=[2*hidden_layer_dim, num_sense_wnDomain], initializer = weight_initer)
        b_wnDomain = tf.get_variable("b_wnDomain", shape=[num_sense_wnDomain], initializer=tf.zeros_initializer())

        flat_softmax_wnDomain = tf.reshape(outputBD_wnDomain, [-1, tf.shape(outputBD_wnDomain)[2]]) # shape is (batch*max_len)*(2*hidden_layer_size)
        print('flat_softmax_wnDomain: ', flat_softmax_wnDomain)

        drop_flat_softmax_wnDomain = tf.nn.dropout(flat_softmax_wnDomain, dropout_keep_prob) # shape is (batch*max_len)*(2*hidden_layer_size)
        print('drop_flat_softmax_wnDomain: ', drop_flat_softmax_wnDomain)

        flat_wnDomain_logits = tf.matmul(drop_flat_softmax_wnDomain, W_wnDomain) + b_wnDomain # shape is (batch*max_len)*num_sense_lex
        print('flat_wnDomain_logits: ', flat_wnDomain_logits)

        wnDomain_logits = tf.reshape(flat_wnDomain_logits, [batch_size, max_sent_size, num_sense_wnDomain]) # shape is batch*max_len*num_sense_lex ->3D
        print('wnDomain_logits: ', wnDomain_logits)

        predict_wnDomain = tf.argmax(wnDomain_logits , axis=2)

        loss_wnDomain = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels= y_wnDomain, logits= wnDomain_logits))
        total_loss = total_loss + loss_wnDomain

        float_mask_matrix_wnDomain = tf.cast(mask_matrix_wnDomain, dtype=tf.float32)
        print('float_mask_matrix_wnDomain: ', float_mask_matrix_wnDomain)

        wnDomain_masked_senses = tf.matmul(wnDomain_logits, float_mask_matrix_wnDomain) #mask_mat = 2*11*56 or batch*lex_num*NUM_CLASSES
        print('wnDomain_masked_senses: ', wnDomain_masked_senses)  # size is: batch*max_len*NUM_CLASSES

        print ('softmax_layer_wnDomain is ok \n')                         


    input_rnn_sense = outputBD_wnDomain

            
## --------------------------- SENSE Block ------------------------------------------------   
## ----------------------------------------------------------------------------------------   
    with tf.variable_scope('rnn_cell_sense', reuse=tf.AUTO_REUSE):
            print ('lstm_sense is ok')
            def lstm_cell():
                return tf.nn.rnn_cell.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(hidden_layer_dim), output_keep_prob=dropout_keep_prob)
        
            stacked_fw_lstm_Sense = tf.nn.rnn_cell.MultiRNNCell(
                [lstm_cell() for _ in range(NUM_LAYERS)])
            
            stacked_bw_lstm_Sense = tf.nn.rnn_cell.MultiRNNCell(
                [lstm_cell() for _ in range(NUM_LAYERS)])
            
    with tf.variable_scope('rnn_sense', reuse=tf.AUTO_REUSE):                        
            (forward_output_Sense, backword_output_Sense), _ = tf.nn.bidirectional_dynamic_rnn(
                cell_fw = stacked_fw_lstm_Sense,
                cell_bw = stacked_bw_lstm_Sense,
                inputs = input_rnn_sense,
                sequence_length = seq_length,
                dtype=tf.float32
            )
            
            outputBD_Sense = tf.concat([forward_output_Sense, backword_output_Sense], axis=2)            
            print('outputBD_Sense: ', outputBD_Sense) # shape is batch*max_len*(2*hidden_layer_size) 
            
            print ('outputBD_Sense is ok \n')   

            
## --------------------------- attention_layer --------------------------------------------------
    with tf.variable_scope("attention_layer", reuse=tf.AUTO_REUSE):
        W_attention_L = tf.get_variable("W_attention_L", shape=[2*hidden_layer_dim, 1], initializer = weight_initer )
        flat_outputBD_Sense = tf.reshape(outputBD_Sense, [batch_size*max_sent_size, tf.shape(outputBD_Sense)[2]])        
        print('flat_outputBD_Sense: ', flat_outputBD_Sense) # shape is  shape is (batch*max_length*(2*hidden_layer_size)).(51(2*hidden_layer_size)2*1) = (batch*max_length)*1 ->2D
        
        flat_outputBD_Sense_tanh = tf.tanh(flat_outputBD_Sense)
        
        u_flat_outputBD_Sense_tanh = tf.matmul(flat_outputBD_Sense_tanh, W_attention_L) # shape is batch*max_length -> 2D
        print('u_flat: ', u_flat_outputBD_Sense_tanh)
        
        u = tf.reshape(u_flat_outputBD_Sense_tanh, [batch_size, max_sent_size]) + attention_mask #
        print('u: ', u)
        
        u_softmax = tf.nn.softmax(u, 1)
        
        a = tf.expand_dims(u_softmax, 2) # shape is expand to batch*max_len*1 -> 3D
        print('a: ', a)
        
        c = tf.reduce_sum(tf.multiply(outputBD_Sense, a), axis=1) # shape is batch*max_len*(2*hidden_layer_size) and then reduce_sum with axis 1 to: batch*(2*hidden_layer_size)
        print('c: ', c)
        
        tiled_c = tf.tile(tf.expand_dims(c, 1), [1, max_sent_size, 1]) # shape is batch*max_len*(2*hidden_layer_size)
        print('tiled_c: ', tiled_c)
        
        attention_output = tf.concat([tiled_c, outputBD_Sense], 2) # batch*max_len*(2*hidden_layer_size) "concat with" batch*max_len*(2*hidden_layer_size) -> batch*max_len*(4*hidden_layer_size)
        print('attention_output: ', attention_output)
        
        flat_attention_output = tf.reshape(attention_output, [batch_size*max_sent_size, tf.shape(attention_output)[2]]) # reshape to (batch*max_len)*(4*hidden_layer_size) -> 2D
        print('flat_attention_output: ', flat_attention_output)

        print ('global_attention is ok \n') 
        
## --------------------------- hidden_layer Sense ------------------------------------------------------------
    with tf.variable_scope("hidden_layer", reuse=tf.AUTO_REUSE):
        W = tf.get_variable("W", shape=[4*hidden_layer_dim, 2*hidden_layer_dim], initializer = weight_initer)
        b = tf.get_variable("b", shape=[2*hidden_layer_dim], initializer = tf.zeros_initializer())
        
        drop_flat_attention_output = tf.nn.dropout(flat_attention_output, dropout_keep_prob) # shape is (batch*max_len)*(4*hidden_layer_size) -> 2D
        print('drop_flat_attention_output: ', drop_flat_attention_output)
        
        hidden_layer_output = tf.matmul(drop_flat_attention_output, W) + b  # shape is (batch*max_len)*(2*hidden_layer_size) -> 2D
        print('hidden_layer_output: ', hidden_layer_output)
                
        print ('hidden_layer is ok \n') 
        
## --------------------------- softmax_layer Sense ------------------------------------------------------------
    with tf.variable_scope("softmax_layer", reuse=tf.AUTO_REUSE):
        W_sense = tf.get_variable("W_sense", shape=[2*hidden_layer_dim, NUM_CLASSES], initializer = weight_initer)
        b_sense = tf.get_variable("b_sense", shape=[NUM_CLASSES], initializer=tf.zeros_initializer())
        
        drop_hidden_layer_output = tf.nn.dropout(hidden_layer_output, dropout_keep_prob)
        print('drop_hidden_layer_output: ', drop_hidden_layer_output)
        
        flat_sense_logits = tf.matmul(drop_hidden_layer_output, W_sense) + b_sense
        print('flat_sense_logits: ', flat_sense_logits)
        
        sense_logits = tf.reshape(flat_sense_logits, [batch_size, max_sent_size, NUM_CLASSES])
        print('sense_logits: ', sense_logits)
        
        masked_sense_logits = tf.multiply(sense_logits, wnDomain_masked_senses) # multiply is element wise multiplicatin, matmul is matrix multiplication.
        
        float_mask_RawTosense_batch = tf.cast(mask_RawTosense_batch, dtype=tf.float32)
        print('float_mask_RawTosense_batch: ', float_mask_RawTosense_batch)
        
        final_sense_logits = tf.multiply(masked_sense_logits, float_mask_RawTosense_batch)
        print('final_sense_logits: ', final_sense_logits)

        predictions = tf.argmax(final_sense_logits , axis=2)
        print('predictions: ', predictions)
        loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels= labels, logits= final_sense_logits))
        total_loss = total_loss + loss
        print ('softmax_layer is ok \n')
        
                        
## --------------------------- train_op Block ----------------------------------------------
## -----------------------------------------------------------------------------------------          
    with tf.variable_scope('train_op', reuse=tf.AUTO_REUSE):
                        
        optimizer = tf.train.AdadeltaOptimizer(LEARNING_RATE)
        
#         optimizer = tf.train.AdamOptimizer(LEARNING_RATE)
#         optimizer=tf.train.GradientDescentOptimizer(learning_rate=LEARNING_RATE, use_locking=False, name='GradientDescent')
        print ('AdamOptimizer is ok .... \n')
        
        tvars=tf.trainable_variables()
        print ('tvars is ok ....')
    
        l2_loss = tf.add_n([tf.nn.l2_loss(v) for v in tvars if v.get_shape().ndims > 1])
        print ('l2_loss is ok ....')
        
        total_loss = total_loss + L2_REGU_LAMBDA*l2_loss             
        print ('total_loss is ok ....')
        
        summaries.append(tf.summary.scalar("loss", loss))
        summaries.append(tf.summary.scalar("total_loss", total_loss))
        
        grads,_ = tf.clip_by_global_norm(tf.gradients(total_loss,tvars),CLIP)
        print ('grads is ok ....')
        
        train_op = optimizer.apply_gradients(zip(grads,tvars))
        print ('train_op apply_gradients is ok ....')
                               
    return input_, labels, y_wnDomain, mask_RawTosense_batch, train_op, predictions, dropout_keep_prob, total_loss, seq_length,  mask_wnDomain2sense

# %%
# create tensorflow model without sense embedding and just basic LSTM
input_, labels, y_wnDomain, mask_RawTosense_batch, train_op, predictions, dropout_keep_prob, total_loss, seq_length, mask_wnDomain2sense\
= create_tensorflow_model(VOCAB_SIZE, WORD_EMBEDDING_DIM, HIDDEN_LAYER_DIM, sense_embed_bool = True, total_loss = 0)
# Out:
# Creating TENSORFLOW model
# seq_length:  Tensor("Sum:0", shape=(?,), dtype=int32)
# max_sent_size:  Tensor("Size:0", shape=(), dtype=int32)
# batch_size:  Tensor("Size_1:0", shape=(), dtype=int32)
# mask_RawTosense_batch:  Tensor("mask_Raw2Senses:0", shape=(?, ?, ?), dtype=bool)
# mask_wnDomain2sense:  Tensor("mask_Raw2Senses_1:0", shape=(?, ?), dtype=bool)
# mask_matrix_wnDomain:  Tensor("Tile:0", shape=(?, ?, ?), dtype=bool)
# x_mask:  Tensor("NotEqual_1:0", shape=(?, ?), dtype=bool)
# attention_mask:  Tensor("mul_2:0", shape=(?, ?), dtype=float32)
# embeddings:  Tensor("embeddings/embedding_lookup/Identity:0", shape=(?, ?, 100), dtype=float32)
# embeddings:  Tensor("embeddings/Reshape:0", shape=(?, ?, 100), dtype=float32)
# WARNING:tensorflow:From <ipython-input-9-b718d2c8804f>:59: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# embeddings is ok
#
# lstm_cell_wnDomain is is ok ...
# WARNING:tensorflow:From <ipython-input-9-b718d2c8804f>:68: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-9-b718d2c8804f>:71: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-9-b718d2c8804f>:82: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn_cell_impl.py:961: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:244: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# outputBD_wnDomain:  Tensor("rnn_wnDomain/concat:0", shape=(?, ?, 512), dtype=float32)
# outputBD_wnDomain is ok
#
# flat_softmax_wnDomain:  Tensor("softmax_layer_wnDomain/Reshape:0", shape=(?, ?), dtype=float32)
# drop_flat_softmax_wnDomain:  Tensor("softmax_layer_wnDomain/dropout/mul_1:0", shape=(?, ?), dtype=float32)
# flat_wnDomain_logits:  Tensor("softmax_layer_wnDomain/add:0", shape=(?, 160), dtype=float32)
# wnDomain_logits:  Tensor("softmax_layer_wnDomain/Reshape_1:0", shape=(?, ?, 160), dtype=float32)
# float_mask_matrix_wnDomain:  Tensor("softmax_layer_wnDomain/Cast:0", shape=(?, ?, ?), dtype=float32)
# wnDomain_masked_senses:  Tensor("softmax_layer_wnDomain/MatMul_1:0", shape=(?, ?, ?), dtype=float32)
# softmax_layer_wnDomain is ok
#
# lstm_sense is ok
# outputBD_Sense:  Tensor("rnn_sense/concat:0", shape=(?, ?, 512), dtype=float32)
# outputBD_Sense is ok
#
# flat_outputBD_Sense:  Tensor("attention_layer/Reshape:0", shape=(?, ?), dtype=float32)
# u_flat:  Tensor("attention_layer/MatMul:0", shape=(?, 1), dtype=float32)
# u:  Tensor("attention_layer/add:0", shape=(?, ?), dtype=float32)
# a:  Tensor("attention_layer/ExpandDims:0", shape=(?, ?, 1), dtype=float32)
# c:  Tensor("attention_layer/Sum:0", shape=(?, 512), dtype=float32)
# tiled_c:  Tensor("attention_layer/Tile:0", shape=(?, ?, 512), dtype=float32)
# attention_output:  Tensor("attention_layer/concat:0", shape=(?, ?, 1024), dtype=float32)
# flat_attention_output:  Tensor("attention_layer/Reshape_2:0", shape=(?, ?), dtype=float32)
# global_attention is ok
#
# drop_flat_attention_output:  Tensor("hidden_layer/dropout/mul_1:0", shape=(?, ?), dtype=float32)
# hidden_layer_output:  Tensor("hidden_layer/add:0", shape=(?, 512), dtype=float32)
# hidden_layer is ok
#
# drop_hidden_layer_output:  Tensor("softmax_layer/dropout/mul_1:0", shape=(?, 512), dtype=float32)
# flat_sense_logits:  Tensor("softmax_layer/add:0", shape=(?, 60919), dtype=float32)
# sense_logits:  Tensor("softmax_layer/Reshape:0", shape=(?, ?, 60919), dtype=float32)
# float_mask_RawTosense_batch:  Tensor("softmax_layer/Cast:0", shape=(?, ?, ?), dtype=float32)
# final_sense_logits:  Tensor("softmax_layer/Mul_1:0", shape=(?, ?, 60919), dtype=float32)
# predictions:  Tensor("softmax_layer/ArgMax:0", shape=(?, ?), dtype=int64)
# softmax_layer is ok
#
# AdamOptimizer is ok ....
#
# tvars is ok ....
# l2_loss is ok ....
# total_loss is ok ....
# grads is ok ....
# train_op apply_gradients is ok ....

# %%
# -----------------------------------------------------------------------------
def BN_to_WNDOMAIN_dic(mapping_file):
    print('WN_to_BN_dic is started ....')
    BN_ID = []
    WN_DOMAIN = []
    with codecs.open(mapping_file,'rb') as f:        
        for line in f:            
            line_synsets = line.decode().strip().split('\t')
            BN_ID.append(line_synsets[0])
            WN_DOMAIN.append(line_synsets[1])    
    BN2WnDomain_dic = dict(zip(BN_ID, WN_DOMAIN))
    print('BN_to_WNDOMAIN_dic is done ....')
    return BN2WnDomain_dic


# -----------------------------------------------------------------------------
def BN_to_LexNames_dic(mapping_file):
    print('BN_to_LexNames is started ....')
    BN_ID = []
    LEXNAMES = []
    with codecs.open(mapping_file,'rb') as f:        
        for line in f:            
            line_synsets = line.decode().strip().split('\t')
            BN_ID.append(line_synsets[0])
            LEXNAMES.append(line_synsets[1])    
    BN2LexNames_dic = dict(zip(BN_ID, LEXNAMES))
    print('BN_to_LexNames_dic is done ....')

    return BN2LexNames_dic

# -----------------------------------------------------------------------------
def WN_to_BN_dic(mapping_file):
    print('WN_to_BN_dic is started ....')
    BN_ID = []
    WN_ID = []
    with codecs.open(mapping_file,'rb') as f:        
        for line in f:            
            line_synsets = line.decode().strip().split('\t')
            BN_ID.append(line_synsets[0])
            WN_ID.append(line_synsets[1])    
    WN2BN_map_dic = dict(zip(WN_ID,BN_ID))
    print('WN_to_BN_dic is done ....')

    return WN2BN_map_dic


# -----------------------------------------------------------------------------
def WN_to_BN_dic(mapping_file):
    print('WN_to_BN_dic is started ....')
    BN_ID = []
    WN_ID = []
    with codecs.open(mapping_file,'rb') as f:        
        for line in f:            
            line_synsets = line.decode().strip().split('\t')
            BN_ID.append(line_synsets[0])
            WN_ID.append(line_synsets[1])    
    WN2BN_map_dic = dict(zip(WN_ID,BN_ID))
    print('WN_to_BN_dic is done ....')

    return WN2BN_map_dic


WN2BN_map_dic = WN_to_BN_dic(MAP_WN2BN_FILE)
print(len(WN2BN_map_dic))

BN2WnDomain_dic = BN_to_WNDOMAIN_dic(MAP_BN2WNDOMAIN_FILE)
print(len(BN2WnDomain_dic))

BN2LexNames_dic = BN_to_LexNames_dic(MAP_BN2LEXNAMES_FILE)
print(len(BN2LexNames_dic))

## ----------------------------------------------------------------------------
def getMFS_(word, WN2BN_map_dic):
    MFS_wnId = UNK
    all_synsets = wn.synsets(word)

    # check if the word has synsets or not!
    if len(all_synsets) == 0 or all_synsets is None:
        return word
    
    synset = all_synsets[0]
    MFS_wnId = "wn:" + str(synset.offset()).zfill( 8) + synset.pos()
    if WN2BN_map_dic.get(MFS_wnId) is not None:
        MFS_bnId = WN2BN_map_dic.get(MFS_wnId)
        
    return MFS_bnId

def Tagger_acc(Id_Instance, pred_sent, true_sent):    
    T = 0
    F = 0
    f1Score = 0
    for i in range(len(pred_sent)):
        for j in range(len(pred_sent[i])):
            if Id_Instance[i][j] != 'None':
                if pred_sent[i][j] == true_sent[i][j]:
                    T = T + 1
                else:
                    F = F + 1
                                
    f1Score = T/(T+F)
    
    return f1Score
# Out:
# WN_to_BN_dic is started ....
# WN_to_BN_dic is done ....
# 117659
# WN_to_BN_dic is started ....
# BN_to_WNDOMAIN_dic is done ....
# 92601
# BN_to_LexNames is started ....
# BN_to_LexNames_dic is done ....
# 117653

# %%
# model loading, prediction and write part #Restore Saved Tensorflow model.
import tensorflow as tf
saver = tf.train.Saver()

with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:    
    
    saver.restore(sess, root_path+'/WnDomain_BDLSTM_SenseEmbed_models_51.0158013544018/model.ckpt')
    
    print("Model restored.")         
    
    file_names = ['senseval2', 'senseval3', 'semeval2007', 'semeval2013', 'semeval2015', 'ALL']

    for file_name in file_names:
        test_path = root_path + '/semcor/{}/'.format(file_name)
        x_test_IdInstance_Sent = pickle.load(open(test_path + 'x_IdInstance_Sent.pkl', "rb"))
        x_test_Raw_Sent = pickle.load(open(test_path + 'x_Raw_Sent.pkl', "rb"))
        x_test_Raw_Sent_id = pickle.load(open(test_path + 'x_Raw_Sent_id.pkl', "rb"))
        y_test_BNsense_Sent = pickle.load(open(test_path + 'y_BNsense_Sent.pkl', "rb"))
        y_test_POS_Sent_id = pickle.load(open(test_path + 'y_POS_Sent_id.pkl', "rb"))
        y_test_allSenses_Sent = pickle.load(open(test_path + 'y_allSenses_Sent.pkl', "rb"))
        y_test_allSenses_Sent_id = pickle.load(open(test_path + 'y_allSenses_Sent_id.pkl', "rb"))    
        y_test_Lex_Sent = pickle.load(open(test_path + 'y_Lex_Sent.pkl', "rb"))
        y_test_WnDomain_Sent = pickle.load(open(test_path + 'y_WnDomain_Sent.pkl', "rb"))
        mask_test_wnDomain2sense = pickle.load(open(test_path + 'mask_wnDomain2sense.pkl', "rb"))

        test_pred_BN = []
        test_pred_Lex = []
        test_pred_WnDomain = []

        for i in range(0, len(x_test_Raw_Sent_id), BATCH_SIZE):                            
            batch_x_Lemma = x_test_Raw_Sent[slice(i, i + BATCH_SIZE)]
            batch_x_Raw = x_test_Raw_Sent_id[slice(i, i + BATCH_SIZE)]
            
            y_test_allSenses_Sent_batch = y_test_allSenses_Sent[slice(i, i + BATCH_SIZE)]
            y_test_allSenses_Sent_id_batch = y_test_allSenses_Sent_id[slice(i, i + BATCH_SIZE)]

            mask_lemma2Sense_b = mask_lemmaToSenses_batch(batch_x_Raw, y_test_allSenses_Sent_batch, y_test_allSenses_Sent_id_batch, SenseWords2id)

            batch_x_Raw = padding3(batch_x_Raw, PAD_ID)

            lengths, predict = sess.run(
                [seq_length, predictions], feed_dict = {input_ : batch_x_Raw, mask_RawTosense_batch : mask_lemma2Sense_b,\
                                                                    mask_wnDomain2sense: mask_test_wnDomain2sense , dropout_keep_prob: 1.0 })            

            pred_sense = []
            for sent_num in range(len(predict)):
                pr_BN, pr_Lex, pr_WnDomain = [], [], []
                for L_ in range(lengths[sent_num]):
                    # if our prediction is UNK means that word is not in our dictionary and we can't predict anything for that, so we put BackOff plan and MFS as our prediction.
                    if id2Sensewords[predict[sent_num][L_]] != UNK:
                        pr_BN.append(id2Sensewords[predict[sent_num][L_]])
                        pr_Lex.append(BN2LexNames_dic.get(id2Sensewords[predict[sent_num][L_]])) # BN2LexNames_dic
                        pr_WnDomain.append(BN2WnDomain_dic.get(id2Sensewords[predict[sent_num][L_]])) # BN2WnDomain_dic
                    else:
                        pr_BN.append(getMFS_(batch_x_Lemma[sent_num][L_], WN2BN_map_dic))
                        pr_Lex.append(BN2LexNames_dic.get(getMFS_(batch_x_Lemma[sent_num][L_], WN2BN_map_dic)))
                        pr_WnDomain.append(BN2WnDomain_dic.get(getMFS_(batch_x_Lemma[sent_num][L_], WN2BN_map_dic)))

                test_pred_BN.append(pr_BN)
                test_pred_Lex.append(pr_Lex)
                test_pred_WnDomain.append(pr_WnDomain)


        f1Score_Bn = Tagger_acc(x_test_IdInstance_Sent, test_pred_BN, y_test_BNsense_Sent)
        print('f1Score_Bn = ',f1Score_Bn) 

        f1Score_Lex = Tagger_acc(x_test_IdInstance_Sent, test_pred_Lex, y_test_Lex_Sent)
        print('f1Score_Lex = ',f1Score_Lex) 

        f1Score_WnDomain = Tagger_acc(x_test_IdInstance_Sent, test_pred_WnDomain, y_test_WnDomain_Sent)
        print('f1Score_WnDomain = ',f1Score_WnDomain) 

        print('Tagger Results is ok ......... ', file_name)
        print('-------------------------------------------------------')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/NLPHW3/WnDomain_BDLSTM_SenseEmbed_models_51.0158013544018/model.ckpt
# Model restored.
# f1Score_Bn =  0.5832602979842244
# f1Score_Lex =  0.7567922874671341
# f1Score_WnDomain =  0.5477651183172656
# Tagger Results is ok .........  senseval2
# -------------------------------------------------------
# f1Score_Bn =  0.6037837837837838
# f1Score_Lex =  0.76
# f1Score_WnDomain =  0.6535135135135135
# Tagger Results is ok .........  senseval3
# -------------------------------------------------------
# f1Score_Bn =  0.4967032967032967
# f1Score_Lex =  0.6681318681318681
# f1Score_WnDomain =  0.843956043956044
# Tagger Results is ok .........  semeval2007
# -------------------------------------------------------
# f1Score_Bn =  0.5334549878345499
# f1Score_Lex =  0.6453771289537713
# f1Score_WnDomain =  0.6465936739659367
# Tagger Results is ok .........  semeval2013
# -------------------------------------------------------
# f1Score_Bn =  0.5244618395303327
# f1Score_Lex =  0.7054794520547946
# f1Score_WnDomain =  0.5264187866927593
# Tagger Results is ok .........  semeval2015
# -------------------------------------------------------
# f1Score_Bn =  0.5634909692541018
# f1Score_Lex =  0.7195643182131531
# f1Score_WnDomain =  0.6127119812491383
# Tagger Results is ok .........  ALL
# -------------------------------------------------------

# %%
for i in range(len(test_pred_BN)):
    print(test_pred_BN[i])
    print(y_test_BNsense_Sent[i])
    print('\n')
# Out:
# ['the', 'bn:00005927n', 'of', 'bn:00017671n', 'be', 'bn:00108295a', 'to', 'the', 'bn:00030862n', ',', 'and', ',', 'like', 'bn:00106953a', 'bn:00102248a', 'bn:00027768n', ',', 'bn:00107878a', 'to', 'the', 'bn:00008047n', 'of', 'the', 'bn:00028141n', '.']
# ['the', 'bn:00005928n', 'of', 'bn:00017671n', 'be', 'bn:00108295a', 'to', 'the', 'bn:00030863n', ',', 'and', ',', 'like', 'bn:00106953a', 'bn:00102248a', 'bn:00027769n', ',', 'bn:00107878a', 'to', 'the', 'bn:00008047n', 'of', 'the', 'bn:00063584n', '.']
#
#
# ['dorothy', 'l.', 'sayer', ',', '``', 'the', 'nine', 'bn:00069297n', '``']
# ['dorothy', 'l.', 'sayer', ',', '``', 'the', 'nine', 'bn:00069297n', '``']
#
#
# ['aslacton', ',', 'bn:00030861n', '--']
# ['aslacton', ',', 'bn:00030861n', '--']
#
#
# ['of', 'all', 'bn:00069550n', 'that', 'bn:00084418v', 'bn:00109997a', 'bn:00030861n', ',', 'this', 'be', 'one', 'of', 'the', 'bn:00106201a', ':', 'a', 'bn:00097066a', 'bn:00068045n', 'bn:00018995n', 'bn:00094276v', 'amid', 'the', 'bn:00034267n', ',', 'the', 'bn:00072892n', 'of', 'bn:00009727n', 'bn:00084612v', 'from', 'its', 'bn:00077766n', ',', 'bn:00084385v', 'the', 'bn:00021837n', 'to', 'bn:00032020n', '.']
# ['of', 'all', 'bn:00006384n', 'that', 'bn:00087782v', 'bn:00109997a', 'bn:00030861n', ',', 'this', 'be', 'one', 'of', 'the', 'bn:00106201a', ':', 'a', 'bn:00097067a', 'bn:00074410n', 'bn:00018995n', 'bn:00094277v', 'amid', 'the', 'bn:00017609n', ',', 'the', 'bn:00072892n', 'of', 'bn:00009727n', 'bn:00084612v', 'from', 'its', 'bn:00077766n', ',', 'bn:00084389v', 'the', 'bn:00021837n', 'to', 'bn:00032009n', '.']
#
#
# ['the', 'bn:00060682n', 'of', 'st.', 'michael', 'and', 'all', 'angel', 'bn:00084710v', 'to', 'bn:00084747v', 'at', 'the', 'bn:00018995n', 'bn:00028247n', ',', 'as', 'bn:00034004n', 'bn:00115639r', 'bn:00114250r', 'have', '.']
# ['the', 'bn:00060682n', 'of', 'st.', 'michael', 'and', 'all', 'angel', 'bn:00089154v', 'to', 'bn:00084747v', 'at', 'the', 'bn:00018995n', 'bn:00028247n', ',', 'as', 'bn:00034004n', 'bn:00115639r', 'bn:00114250r', 'have', '.']
#
#
# ['in', 'the', 'bn:00077766n', ',', 'five', 'bn:00001533n', 'and', 'bn:00001530n', 'bn:00085426v', 'bn:00116859r', 'on', 'bn:00068266n', 'bn:00082893v', 'to', 'the', 'bn:00110075a', 'five', 'bn:00009727n', 'that', 'bn:00115377r', 'bn:00094053v', 'bn:00115639r', 'in', '1614', '.']
# ['in', 'the', 'bn:00077766n', ',', 'five', 'bn:00001533n', 'and', 'bn:00001530n', 'bn:00092138v', 'bn:00116859r', 'on', 'bn:00068266n', 'bn:00082894v', 'to', 'the', 'bn:00110075a', 'five', 'bn:00009727n', 'that', 'bn:00115377r', 'bn:00088919v', 'bn:00115639r', 'in', '1614', '.']
#
#
# ['but', 'there', 'be', 'bn:00114246r', 'a', 'bn:00101484a', ',', 'bn:00106831a', 'bn:00027765n', 'in', 'aslacton', ',', 'though', 'it', 'can', 'not', 'be', 'hear', 'by', 'the', 'bn:00019007n', 'bn:00083145v', 'the', 'bn:00061178n', 'of', 'bn:00009727n', 'this', 'bn:00100441a', 'bn:00007406n', 'bn:00031998n', '.']
# ['but', 'there', 'be', 'bn:00114246r', 'a', 'bn:00101484a', ',', 'bn:00106831a', 'bn:00058147n', 'in', 'aslacton', ',', 'though', 'it', 'can', 'not', 'be', 'hear', 'by', 'the', 'bn:00019007n', 'bn:00083145v', 'the', 'bn:00061178n', 'of', 'bn:00009727n', 'this', 'bn:00100441a', 'bn:00007406n', 'bn:00031998n', '.']
#
#
# ['like', 'bn:00106953a', 'of', 'the', 'bn:00108011a', '6,000', 'bn:00018995n', 'in', 'bn:00013173n', 'with', 'bn:00070696n', 'of', 'bn:00009727n', ',', 'st.', 'michael', 'bn:00115811r', 'have', 'its', 'bn:00096707a', '``', 'bn:00008280n', '``', 'of', 'bn:00009757n', ',', 'who', 'would', 'bn:00082211v', 'every', 'bn:00028190n', 'bn:00035851n', 'and', 'bn:00031998n', 'bn:00070651n', '.']
# ['like', 'bn:00106953a', 'of', 'the', 'bn:00108011a', '6,000', 'bn:00018995n', 'in', 'bn:00013173n', 'with', 'bn:00070696n', 'of', 'bn:00009727n', ',', 'st.', 'michael', 'bn:00114423r', 'have', 'its', 'bn:00096707a', '``', 'bn:00008280n', '``', 'of', 'bn:00009757n', ',', 'who', 'would', 'bn:00082640v', 'every', 'bn:00028190n', 'bn:00035851n', 'and', 'bn:00031998n', 'bn:00027898n', '.']
#
#
# ['bn:00116381r', ',', 'bn:00114626r', 'one', 'bn:00106108a', 'bn:00009757n', 'bn:00092756v', ':', '64-year-old', 'derek', 'hammond', '.']
# ['bn:00116382r', ',', 'bn:00114626r', 'one', 'bn:00106109a', 'bn:00009757n', 'bn:00085719v', ':', '64-year-old', 'derek', 'hammond', '.']
#
#
# ['the', 'other', 'bn:00115639r', 'bn:00077462n', 'bn:00087441v', 'bn:00115192r', '.']
# ['the', 'other', 'bn:00115639r', 'bn:00077463n', 'bn:00087441v', 'bn:00115192r', '.']
#
#
# ['they', 'bn:00083391v', 'a', 'bn:00041942n', 'of', '15', 'bn:00009757n', '--', 'bn:00089660v', 'two', 'bn:00058615n', 'and', 'four', 'bn:00018345n', 'in', 'bn:00041853n', '--', 'who', 'bn:00087327v', 'every', 'bn:00028190n', 'from', 'bn:00018995n', 'to', 'bn:00018995n', 'in', 'a', 'sometimes-exhausting', 'bn:00007011n', 'to', 'bn:00089384v', 'the', 'bn:00009727n', 'bn:00094053v', 'in', 'the', 'bn:00106408a', 'bn:00009702n', 'of', 'east', 'anglium', '.']
# ['they', 'bn:00083391v', 'a', 'bn:00041942n', 'of', '15', 'bn:00009757n', '--', 'bn:00089660v', 'two', 'bn:00058615n', 'and', 'four', 'bn:00018345n', 'in', 'bn:00041853n', '--', 'who', 'bn:00087328v', 'every', 'bn:00028190n', 'from', 'bn:00018995n', 'to', 'bn:00018995n', 'in', 'a', 'sometimes-exhausting', 'bn:00007011n', 'to', 'bn:00089384v', 'the', 'bn:00009727n', 'bn:00088919v', 'in', 'the', 'bn:00106408a', 'bn:00009702n', 'of', 'east', 'anglium', '.']
#
#
# ['``', 'to', 'ring', 'for', 'bn:00115244r', 'one', 'bn:00070651n', 'at', 'this', 'bn:00077766n', ',', 'we', 'have', 'to', 'bn:00093368v', ',', '``', 'bn:00093287v', 'mr.', 'hammond', ',', 'a', 'bn:00109765a', 'water-authority', 'bn:00081593n', '.', '``']
# ['``', 'to', 'ring', 'for', 'bn:00115244r', 'one', 'bn:00027898n', 'at', 'this', 'bn:00077766n', ',', 'we', 'have', 'to', 'bn:00085394v', ',', '``', 'bn:00093290v', 'mr.', 'hammond', ',', 'a', 'bn:00109765a', 'water-authority', 'bn:00081593n', '.', '``']
#
#
# ['we', 'have', 'bn:00082844v', 'to', 'bn:00084856v', 'the', 'bn:00018345n', ',', 'but', 'they', 'have', 'they', 'bn:00027490n', 'and', 'they', 'bn:00025142n', ',', 'and', 'they', 'bn:00114626r', 'bn:00083195v', 'bn:00114455r', '.', '``']
# ['we', 'have', 'bn:00082844v', 'to', 'bn:00086736v', 'the', 'bn:00018345n', ',', 'but', 'they', 'have', 'they', 'bn:00027491n', 'and', 'they', 'bn:00025145n', ',', 'and', 'they', 'bn:00116053r', 'bn:00087308v', 'bn:00114455r', '.', '``']
#
#
# ['mr.', 'hammond', 'bn:00095829v', 'that', 'bn:00001940n', 'and', 'the', 'bn:00005343n', 'of', 'bn:00073643n', 'will', 'bn:00086417v', 'the', 'bn:00066151n', 'of', 'the', 'east', 'bn:00004138n', 'bn:00041942n', 'that', 'bn:00089384v', 'the', 'aslacton', 'bn:00009727n', 'bn:00091505v', '.']
# ['mr.', 'hammond', 'bn:00095829v', 'that', 'bn:00001940n', 'and', 'the', 'bn:00005343n', 'of', 'bn:00081958n', 'will', 'bn:00086417v', 'the', 'bn:00054281n', 'of', 'the', 'east', 'anglian', 'bn:00041942n', 'that', 'bn:00089384v', 'the', 'aslacton', 'bn:00009727n', 'bn:00091504v', '.']
#
#
# ['bn:00044267n', ',', 'after', 'all', ',', 'be', 'not', 'on', 'he', 'bn:00071431n', '.']
# ['bn:00044267n', ',', 'after', 'all', ',', 'be', 'not', 'on', 'he', 'bn:00063709n', '.']
#
#
# ['accord', 'to', 'a', 'bn:00100565a', 'bn:00074790n', 'bn:00082822v', 'a', 'bn:00078738n', 'bn:00114178r', ',', 'bn:00114079r', 'a', 'third', 'of', 'bn:00030861n', "'s", 'bn:00018995n', 'bn:00009727n', 'be', 'bn:00116348r', 'bn:00116156r', 'bn:00091505v', 'on', 'bn:00028190n', 'because', 'there', 'be', 'no', 'one', 'to', 'bn:00091505v', 'they', '.']
# ['accord', 'to', 'a', 'bn:00100565a', 'bn:00074790n', 'bn:00094730v', 'a', 'bn:00078738n', 'bn:00114178r', ',', 'bn:00114079r', 'a', 'third', 'of', 'bn:00030861n', "'s", 'bn:00018995n', 'bn:00009727n', 'be', 'bn:00116349r', 'bn:00116156r', 'bn:00090125v', 'on', 'bn:00028190n', 'because', 'there', 'be', 'no', 'one', 'to', 'bn:00090125v', 'they', '.']
#
#
# ['it', 'be', 'bn:00101973a', 'to', 'bn:00093430v', 'why', 'the', 'bn:00097066a', 'bn:00005927n', 'be', 'on', 'the', 'rope', '.']
# ['it', 'be', 'bn:00101973a', 'to', 'bn:00092443v', 'why', 'the', 'bn:00097066a', 'bn:00005928n', 'be', 'on', 'the', 'rope', '.']
#
#
# ['the', 'bn:00116104r', 'bn:00100150a', 'bn:00079827n', 'of', 'bn:00091708v', 'bn:00002191n', 'on', 'bn:00009727n', ',', 'as', 'do', 'the', 'bn:00016078n', 'of', 'bn:00100373a', 'bn:00031896n', ',', 'be', 'bn:00083370v', 'by', 'the', 'bn:00030862n', 'to', 'be', 'bn:00099602a', ',', 'bn:00103024a', 'bn:00114626r', 'for', 'bn:00002725n', '.']
# ['the', 'bn:00116104r', 'bn:00100150a', 'bn:00029773n', 'of', 'bn:00091712v', 'bn:00002191n', 'on', 'bn:00009727n', ',', 'as', 'do', 'the', 'bn:00009762n', 'of', 'bn:00100373a', 'bn:00031897n', ',', 'be', 'bn:00085647v', 'by', 'the', 'bn:00030863n', 'to', 'be', 'bn:00099602a', ',', 'bn:00103023a', 'bn:00114234r', 'for', 'bn:00002725n', '.']
#
#
# ['bn:00017671n', ',', 'a', 'bn:00106743a', 'exercise', 'the', 'bn:00030862n', 'bn:00085743v', '380', 'bn:00078738n', 'bn:00114178r', ',', 'bn:00082822v', 'bn:00108566a', 'bn:00026769n', '--', 'some', 'bn:00009727n', 'bn:00095701v', 'bn:00106935a', 'than', 'a', 'bn:00057373n', '--', 'bn:00085313v', 'with', 'bn:00105251a', 'bn:00106601a', 'bn:00021538n', '.']
# ['bn:00017671n', ',', 'a', 'bn:00106743a', 'exercise', 'the', 'bn:00030863n', 'bn:00085743v', '380', 'bn:00078738n', 'bn:00114178r', ',', 'bn:00082822v', 'bn:00108566a', 'bn:00026769n', '--', 'some', 'bn:00009727n', 'bn:00095701v', 'bn:00106935a', 'than', 'a', 'bn:00041874n', '--', 'bn:00085313v', 'with', 'bn:00105251a', 'bn:00106602a', 'bn:00006509n', '.']
#
#
# ['proper', 'bn:00102248a', 'bn:00009727n', 'be', 'bn:00083341v', 'off', 'in', '``', 'bn:00059000n', ',', '``', 'from', 'the', 'bn:00104164a', 'bn:00009727n', 'to', 'the', 'bn:00106205a', '--', 'a', 'bn:00110649a', 'bn:00085356v', 'bn:00069467n', 'bn:00082705v', ',', 'in', 'bn:00098342a', 'bn:00018995n', ',', 'as', 'bn:00106408a', 'as', '12', 'bn:00009727n', '.']
# ['proper', 'bn:00102248a', 'bn:00009727n', 'be', 'bn:00083347v', 'off', 'in', '``', 'bn:00024724n', ',', '``', 'from', 'the', 'bn:00104164a', 'bn:00009727n', 'to', 'the', 'bn:00106209a', '--', 'a', 'bn:00098053a', 'bn:00085356v', 'bn:00056469n', 'bn:00082705v', ',', 'in', 'bn:00098342a', 'bn:00018995n', ',', 'as', 'bn:00106408a', 'as', '12', 'bn:00009727n', '.']
#
#
# ['bn:00114281r', ',', 'at', 'a', 'bn:00071525n', ',', 'the', 'bn:00009757n', 'bn:00083341v', 'bn:00082554v', 'the', 'bn:00059303n', 'in', 'which', 'the', 'bn:00009727n', 'bn:00094053v', 'without', 'bn:00082553v', 'the', 'bn:00111175a', 'bn:00066927n', 'of', 'the', 'bn:00022115n', '.']
# ['bn:00114281r', ',', 'at', 'a', 'bn:00071537n', ',', 'the', 'bn:00009757n', 'bn:00083340v', 'bn:00090926v', 'the', 'bn:00059306n', 'in', 'which', 'the', 'bn:00009727n', 'bn:00088919v', 'without', 'bn:00082554v', 'the', 'bn:00111175a', 'bn:00009396n', 'of', 'the', 'bn:00044275n', '.']
#
#
# ['each', 'bn:00035414n', ',', 'or', 'bn:00017651n', ',', 'can', 'bn:00085337v', 'bn:00114626r', 'bn:00115811r', ',', 'the', 'bn:00066933n', 'bn:00093287v', '.']
# ['each', 'bn:00079588n', ',', 'or', 'bn:00017653n', ',', 'can', 'bn:00085337v', 'bn:00114626r', 'bn:00115811r', ',', 'the', 'bn:00068523n', 'bn:00093287v', '.']
#
#
# ['bn:00009757n', 'bn:00085506v', 'bn:00035908n', 'of', 'bn:00017651n', ',', 'bn:00085261v', 'as', '``', 'bn:00054625n', ',', '``', 'which', 'have', 'odd-sounding', 'bn:00056758n', 'like', 'kent', 'treble', 'bob', 'major', 'or', 'grandsire', 'cater', '.']
# ['bn:00009757n', 'bn:00085506v', 'bn:00035908n', 'of', 'bn:00017653n', ',', 'bn:00090145v', 'as', '``', 'bn:00054625n', ',', '``', 'which', 'have', 'odd-sounding', 'bn:00056758n', 'like', 'kent', 'treble', 'bob', 'major', 'or', 'grandsire', 'cater', '.']
#
#
# ['a', 'bn:00070609n', 'of', '5,000', 'or', 'bn:00117043r', 'bn:00017651n', 'be', 'a', '``', 'peal', '``', 'and', 'bn:00082822v', 'bn:00114079r', 'three', 'bn:00000127n', '.']
# ['a', 'bn:00070609n', 'of', '5,000', 'or', 'bn:00117046r', 'bn:00017653n', 'be', 'a', '``', 'peal', '``', 'and', 'bn:00091131v', 'bn:00114073r', 'three', 'bn:00000127n', '.']
#
#
# ['a', 'bn:00006386n', 'at', 'a', 'bn:00076744n', 'bn:00025236n', 'bn:00061054n', 'at', 'st.', 'mary', 'bn:00000237n', 'bn:00018995n', 'in', 'the', 'kensington', 'bn:00027810n', 'of', 'london', 'bn:00082442v', 'a', 'bn:00045800n', 'of', 'the', 'bn:00062309n', 'bn:00082428v', '.']
# ['a', 'bn:00051968n', 'at', 'a', 'bn:00076744n', 'bn:00025236n', 'bn:00028736n', 'at', 'st.', 'mary', 'abbot', 'bn:00018995n', 'in', 'the', 'kensington', 'bn:00027810n', 'of', 'london', 'bn:00088837v', 'a', 'bn:00005164n', 'of', 'the', 'bn:00081568n', 'bn:00082822v', '.']
#
#
# ['ten', 'shirt-sleeved', 'bn:00009757n', 'bn:00094276v', 'in', 'a', 'bn:00019169n', ',', 'one', 'bn:00035679n', 'bn:00114182r', 'of', 'the', 'other', 'in', 'a', 'bn:00040586n', "'s", 'bn:00073902n', ',', 'each', 'bn:00085426v', 'a', 'bn:00068266n', 'that', 'bn:00086879v', 'through', 'a', 'bn:00106058a', 'bn:00044407n', 'in', 'the', 'bn:00104162a', 'bn:00016974n', 'of', 'the', 'ringing', 'bn:00009495n', '.']
# ['ten', 'shirt-sleeved', 'bn:00009757n', 'bn:00094277v', 'in', 'a', 'bn:00019170n', ',', 'one', 'bn:00035679n', 'bn:00114182r', 'of', 'the', 'other', 'in', 'a', 'bn:00040586n', "'s", 'bn:00073902n', ',', 'each', 'bn:00092138v', 'a', 'bn:00068266n', 'that', 'disappear', 'through', 'a', 'bn:00106058a', 'bn:00044408n', 'in', 'the', 'bn:00104163a', 'bn:00016974n', 'of', 'the', 'ringing', 'bn:00017581n', '.']
#
#
# ['no', 'one', 'bn:00090943v', ',', 'and', 'the', 'bn:00093960v', 'of', 'the', 'bn:00068266n', 'bn:00082690v', 'to', 'bn:00087106v', 'as', 'bn:00106995a', 'bn:00072892n', 'as', 'the', 'bn:00009727n', 'themselves', ',', 'bn:00090972v', 'by', 'the', 'bn:00016974n', '.']
# ['no', 'one', 'bn:00094090v', ',', 'and', 'the', 'bn:00093962v', 'of', 'the', 'bn:00068266n', 'bn:00082690v', 'to', 'bn:00084699v', 'as', 'bn:00106995a', 'bn:00072893n', 'as', 'the', 'bn:00009727n', 'themselves', ',', 'bn:00086264v', 'by', 'the', 'bn:00016974n', '.']
#
#
# ['bn:00114203r', 'bn:00082170v', ',', 'the', 'bn:00009757n', 'bn:00088705v', 'bn:00115029r', 'bn:00114182r', ',', 'bn:00082705v', 'bn:00061625n', '(', 'they', 'bn:00084385v', 'it', '``', 'rope-sight', '``', ')', 'to', 'bn:00095665v', 'the', 'bn:00108011a', 'bn:00068266n', 'and', 'bn:00115635r', 'bn:00085147v', 'they', 'bn:00065158n', '.']
# ['bn:00114203r', 'bn:00082177v', ',', 'the', 'bn:00009757n', 'bn:00088705v', 'bn:00115029r', 'bn:00114182r', ',', 'bn:00082705v', 'bn:00061625n', '(', 'they', 'bn:00084386v', 'it', '``', 'rope-sight', '``', ')', 'to', 'bn:00095665v', 'the', 'bn:00108011a', 'bn:00068266n', 'and', 'bn:00115635r', 'bn:00094970v', 'they', 'bn:00065158n', '.']
#
#
# ['bn:00115322r', 'bn:00114080r', 'in', 'the', 'bn:00009702n', ',', 'the', 'bn:00098905a', 'bn:00013326n', 'bn:00009727n', ',', 'bn:00085120v', 'on', 'bn:00080972n', ',', 'bn:00094678v', 'bn:00115446r', 'through', 'a', 'bn:00102277a', '360', 'bn:00025965n', ',', 'bn:00083341v', 'and', 'bn:00084711v', ',', 'bn:00117190r', ',', 'in', 'the', 'bn:00105379a', ',', 'or', 'mouth-up', 'bn:00061746n', '.']
# ['bn:00115323r', 'bn:00114081r', 'in', 'the', 'bn:00009703n', ',', 'the', 'bn:00098905a', 'bn:00013326n', 'bn:00009727n', ',', 'bn:00090934v', 'on', 'bn:00080972n', ',', 'bn:00094679v', 'bn:00114939r', 'through', 'a', 'bn:00103392a', '360', 'bn:00005380n', ',', 'bn:00083341v', 'and', 'bn:00084711v', ',', 'bn:00117190r', ',', 'in', 'the', 'bn:00105379a', ',', 'or', 'mouth-up', 'bn:00063704n', '.']
#
#
# ['bn:00110711a', 'bn:00009757n', 'bn:00082705v', 'they', 'bn:00006143n', 'to', 'bn:00082397v', 'or', 'bn:00086364v', 'the', 'next', 'bn:00051209n', ',', 'bn:00117043r', 'that', 'one', 'bn:00009727n', 'can', 'bn:00094650v', 'bn:00062699n', 'with', 'another', 'in', 'the', 'following', 'bn:00017651n', '.']
# ['bn:00110711a', 'bn:00009757n', 'bn:00082705v', 'they', 'bn:00006143n', 'to', 'bn:00082398v', 'or', 'bn:00092932v', 'the', 'next', 'bn:00075591n', ',', 'bn:00117044r', 'that', 'one', 'bn:00009727n', 'can', 'bn:00094650v', 'bn:00062709n', 'with', 'another', 'in', 'the', 'following', 'bn:00017653n', '.']
#
#
# ['in', 'a', 'bn:00113790a', 'bn:00026637n', 'bn:00082428v', 'bn:00018995n', 'bn:00009727n', ',', 'bn:00102248a', 'bn:00058205n', 'dorothy', 'l.', 'sayer', 'bn:00082233v', 'ringing', 'as', 'a', '``', 'bn:00014500n', 'that', 'bn:00086708v', 'its', 'bn:00069327n', 'in', 'bn:00106488a', 'bn:00021366n', 'and', 'bn:00106539a', 'bn:00035144n', '.', '``']
# ['in', 'a', 'bn:00106142a', 'bn:00026637n', 'bn:00089894v', 'bn:00018995n', 'bn:00009727n', ',', 'bn:00102248a', 'bn:00058205n', 'dorothy', 'l.', 'sayer', 'bn:00082233v', 'ringing', 'as', 'a', '``', 'bn:00052122n', 'that', 'bn:00088211v', 'its', 'bn:00069327n', 'in', 'bn:00106492a', 'bn:00021366n', 'and', 'bn:00106541a', 'bn:00035144n', '.', '``']
#
#
# ['bn:00009757n', ',', 'she', 'bn:00082317v', ',', 'be', '``', 'bn:00088175v', 'with', 'the', 'bn:00103758a', 'bn:00047259n', 'that', 'bn:00085320v', 'of', 'bn:00105348a', 'bn:00067937n', 'bn:00115345r', 'bn:00091550v', '.', '``', '``']
# ['bn:00009757n', ',', 'she', 'bn:00082318v', ',', 'be', '``', 'bn:00088175v', 'with', 'the', 'bn:00101944a', 'intoxication', 'that', 'bn:00085322v', 'of', 'bn:00105348a', 'bn:00067937n', 'bn:00115345r', 'bn:00087107v', '.', '``', '``']
#
#
# ['ringing', 'do', 'bn:00083293v', 'a', 'bn:00010728n', 'of', 'a', 'bn:00021457n', ',', '``', 'bn:00082267v', 'stephanie', 'pattenden', ',', 'bn:00052664n', 'of', 'the', 'bn:00008280n', 'at', 'st.', 'mary', 'bn:00000237n', 'and', 'one', 'of', 'bn:00030861n', "'s", 'bn:00098274a', 'bn:00034016n', 'bn:00009757n', '.']
# ['ringing', 'do', 'bn:00083294v', 'a', 'bn:00010726n', 'of', 'a', 'bn:00034923n', ',', '``', 'bn:00082267v', 'stephanie', 'pattenden', ',', 'bn:00053714n', 'of', 'the', 'bn:00008280n', 'at', 'st.', 'mary', 'abbot', 'and', 'one', 'of', 'bn:00030861n', "'s", 'bn:00098274a', 'bn:00034017n', 'bn:00009757n', '.']
#
#
# ['it', 'be', 'a', 'bn:00014500n', 'that', 'bn:00114778r', 'bn:00092756v', 'in', 'the', 'bn:00077766n', ',', 'bn:00114216r', '.']
# ['it', 'be', 'a', 'bn:00052122n', 'that', 'bn:00114778r', 'bn:00091562v', 'in', 'the', 'bn:00077766n', ',', 'bn:00114216r', '.']
#
#
# ['bn:00116284r', 'bn:00115452r', 'than', 'not', ',', 'bn:00009757n', 'bn:00092763v', 'the', 'bn:00018995n', 'as', 'something', 'bn:00082437v', 'the', 'bn:00012365n', 'of', 'the', 'bn:00009702n', '.']
# ['bn:00116284r', 'bn:00115452r', 'than', 'not', ',', 'bn:00009757n', 'bn:00087737v', 'the', 'bn:00018995n', 'as', 'something', 'bn:00082437v', 'the', 'bn:00012365n', 'of', 'the', 'bn:00009702n', '.']
#
#
# ['when', 'they', 'bn:00017651n', 'be', 'bn:00085475v', ',', 'and', 'after', 'they', 'have', 'bn:00095826v', 'a', 'bn:00061748n', ',', 'bn:00009757n', 'bn:00115452r', 'bn:00089465v', 'off', 'to', 'the', 'bn:00106108a', 'bn:00040492n', ',', 'bn:00088939v', 'bn:00081651n', 'for', 'other', 'bn:00114401r', '.']
# ['when', 'they', 'bn:00017653n', 'be', 'bn:00085475v', ',', 'and', 'after', 'they', 'have', 'bn:00088793v', 'a', 'bn:00061748n', ',', 'bn:00009757n', 'bn:00115452r', 'bn:00086356v', 'off', 'to', 'the', 'bn:00106109a', 'bn:00040492n', ',', 'bn:00090271v', 'bn:00081651n', 'for', 'other', 'bn:00114527r', '.']
#
#
# ['this', 'do', 'not', 'sit', 'bn:00115530r', 'with', 'some', 'bn:00019026n', '.']
# ['this', 'do', 'not', 'sit', 'bn:00115530r', 'with', 'some', 'bn:00019026n', '.']
#
#
# ['with', 'bn:00054282n', 'of', 'the', 'bn:00004141n', 'bn:00117128r', 'bn:00087445v', ',', 'bn:00111318a', 'bn:00079910n', 'be', 'bn:00087843v', 'bn:00114354r', 'bn:00111318a', 'and', 'bn:00115452r', 'non-religious', 'bn:00009757n', 'to', 'bn:00082907v', 'bn:00070651n', '.']
# ['with', 'bn:00054281n', 'of', 'the', 'bn:00004141n', 'bn:00117128r', 'bn:00087445v', ',', 'bn:00111318a', 'bn:00079912n', 'be', 'bn:00087843v', 'bn:00114354r', 'bn:00111318a', 'and', 'bn:00115452r', 'non-religious', 'bn:00009757n', 'to', 'bn:00082907v', 'bn:00027898n', '.']
#
#
# ['two', 'bn:00078738n', 'bn:00114178r', ',', 'the', 'rev.', 'jeremy', 'hummerstone', ',', 'bn:00079910n', 'of', 'great', 'torrington', ',', 'bn:00026750n', ',', 'bn:00083293v', 'bn:00117043r', 'feed', 'up', 'with', 'bn:00009757n', 'who', 'do', "n't", 'bn:00082907v', 'bn:00070651n', 'he', 'bn:00091776v', 'the', 'bn:00102277a', 'bn:00008280n', ';', 'the', 'bn:00009757n', 'bn:00116719r', 'bn:00089785v', 'a', 'bn:00062246n', 'in', 'bn:00064862n', '.']
# ['two', 'bn:00078738n', 'bn:00114178r', ',', 'the', 'rev.', 'jeremy', 'hummerstone', ',', 'bn:00079912n', 'of', 'great', 'torrington', ',', 'devon', ',', 'bn:00083293v', 'bn:00117043r', 'feed', 'up', 'with', 'bn:00009757n', 'who', 'do', "n't", 'bn:00082907v', 'bn:00027898n', 'he', 'bn:00084451v', 'the', 'bn:00102277a', 'bn:00008280n', ';', 'the', 'bn:00009757n', 'bn:00116719r', 'bn:00087732v', 'a', 'bn:00062246n', 'in', 'bn:00027716n', '.']
#
#
# ['``', 'they', 'be', 'a', 'self-perpetuating', 'bn:00008141n', 'that', 'bn:00087116v', 'the', 'bn:00077766n', 'as', 'bn:00035907n', 'of', 'a', 'bn:00110423a', 'bn:00006558n', ',', '``', 'the', 'bn:00079910n', 'hummerstone', 'bn:00093287v', '.']
# ['``', 'they', 'be', 'a', 'self-perpetuating', 'bn:00020039n', 'that', 'bn:00095141v', 'the', 'bn:00077766n', 'as', 'bn:00072855n', 'of', 'a', 'bn:00110423a', 'bn:00064158n', ',', '``', 'the', 'vicar', 'hummerstone', 'bn:00093290v', '.']
#
#
# ['a', 'entirely', 'bn:00107267a', 'bn:00008280n', 'ring', 'bn:00077462n', 'at', 'great', 'torrington', ',', 'several', 'of', 'whom', 'be', 'bn:00034004n', 'of', 'the', 'bn:00021837n', '.']
# ['a', 'entirely', 'bn:00107270a', 'bn:00008280n', 'ring', 'bn:00077462n', 'at', 'great', 'torrington', ',', 'several', 'of', 'whom', 'be', 'bn:00034004n', 'of', 'the', 'bn:00021837n', '.']
#
#
# ['but', 'there', 'bn:00117138r', 'be', 'not', 'bn:00096447a', 'bn:00009757n', 'to', 'bn:00091505v', 'bn:00106935a', 'than', 'six', 'of', 'the', 'eight', 'bn:00009727n', '.']
# ['but', 'there', 'bn:00117138r', 'be', 'not', 'bn:00096447a', 'bn:00009757n', 'to', 'bn:00090125v', 'bn:00106936a', 'than', 'six', 'of', 'the', 'eight', 'bn:00009727n', '.']
#
#
# ['at', 'st.', 'mary', "'s", 'church', 'in', 'ilminster', ',', 'somerset', ',', 'the', 'bn:00009727n', 'have', 'bn:00087976v', 'bn:00110624a', 'bn:00088421v', 'a', 'bn:00029212n', 'over', 'bn:00018995n', 'bn:00007013n', '.']
# ['at', 'st.', 'mary', "'s", 'church', 'in', 'ilminster', ',', 'somerset', ',', 'the', 'bn:00009727n', 'have', 'bn:00087977v', 'bn:00110624a', 'bn:00085342v', 'a', 'bn:00029212n', 'over', 'bn:00018996n', 'bn:00007013n', '.']
#
#
# ['the', 'bn:00079910n', ',', 'w.d.', 'jone', ',', 'bn:00086391v', 'to', 'bn:00086931v', 'it', ',', 'bn:00093287v', 'it', 'would', '``', 'bn:00092799v', 'the', 'wound', '.', '``']
# ['the', 'bn:00079912n', ',', 'w.d.', 'jone', ',', 'bn:00086391v', 'to', 'bn:00094797v', 'it', ',', 'bn:00093290v', 'it', 'would', '``', 'reopen', 'the', 'wound', '.', '``']
#
#
# ['but', 'c.j.b.', 'marshall', ',', 'bn:00079910n', 'of', 'a', 'bn:00107176a', 'bn:00018995n', ',', 'bn:00088095v', 'the', 'bn:00031485n', 'be', 'in', 'the', 'bn:00073853n', 'from', 'the', 'bn:00009764n', 'that', 'be', 'bn:00090424v', 'bn:00103172a', 'to', 'the', 'bn:00003117n', '.']
# ['but', 'c.j.b.', 'marshall', ',', 'bn:00079912n', 'of', 'a', 'bn:00107176a', 'bn:00018995n', ',', 'bn:00088095v', 'the', 'bn:00033817n', 'be', 'in', 'the', 'bn:00073853n', 'from', 'the', 'bn:00009764n', 'that', 'be', 'bn:00090424v', 'bn:00096455a', 'to', 'the', 'bn:00003117n', '.']
#
#
# ['``', 'bn:00117043r', 'bn:00021278n', ',', 'bn:00021278n', ',', 'bn:00021278n', ',', 'bn:00008250n', ',', 'bn:00008250n', ',', 'bn:00008250n', '--', 'bn:00115639r', 'bn:00085320v', 'the', 'bn:00009757n', 'from', 'bn:00114080r', ',', 'bn:00087106v', 'a', 'bn:00116789r', 'bn:00107706a', 'bn:00032242n', 'while', 'the', 'bn:00021837n', 'be', 'at', 'bn:00064038n', ',', '``', 'he', 'bn:00093287v', '.']
# ['``', 'bn:00114281r', 'bn:00024135n', ',', 'bn:00024135n', ',', 'bn:00024135n', ',', 'bn:00008250n', ',', 'bn:00008250n', ',', 'bn:00008250n', '--', 'bn:00115641r', 'bn:00085319v', 'the', 'bn:00009757n', 'from', 'bn:00114081r', ',', 'bn:00090557v', 'a', 'bn:00116789r', 'bn:00107706a', 'bn:00032243n', 'while', 'the', 'bn:00021837n', 'be', 'at', 'bn:00064038n', ',', '``', 'he', 'bn:00093290v', '.']
#
#
# ['bn:00079910n', 'marshall', 'bn:00082267v', 'to', 'bn:00097622a', 'bn:00009717n', 'about', 'this', 'bn:00047688n', ',', 'since', 'he', 'be', 'both', 'a', 'bn:00079910n', 'and', 'a', 'bn:00096382a', 'bn:00009757n', 'himself', '.']
# ['vicar', 'marshall', 'bn:00082267v', 'to', 'bn:00097622a', 'bn:00033968n', 'about', 'this', 'bn:00047688n', ',', 'since', 'he', 'be', 'both', 'a', 'bn:00079912n', 'and', 'a', 'bn:00096385a', 'bn:00009757n', 'himself', '.']
#
#
# ['``', 'the', 'bn:00072892n', 'of', 'bn:00009727n', 'be', 'a', 'net', 'to', 'bn:00086612v', 'bn:00061450n', 'into', 'the', 'bn:00018995n', ',', '``', 'he', 'bn:00093287v', '.']
# ['``', 'the', 'bn:00072893n', 'of', 'bn:00009727n', 'be', 'a', 'net', 'to', 'bn:00082920v', 'bn:00061450n', 'into', 'the', 'bn:00018995n', ',', '``', 'he', 'bn:00093290v', '.']
#
#
# ['``', 'i', 'bn:00087441v', 'in', 'bn:00044737n', 'that', 'the', 'bn:00009757n', 'themselves', 'will', 'be', 'bn:00086612v', 'into', 'that', 'bn:00102277a', 'bn:00051046n', '.', '``']
# ['``', 'i', 'bn:00090408v', 'in', 'bn:00044736n', 'that', 'the', 'bn:00009757n', 'themselves', 'will', 'be', 'bn:00082920v', 'into', 'that', 'bn:00103391a', 'bn:00051046n', '.', '``']
#
#
# ['the', 'central', 'council', 'of', 'church', 'bell', 'ringer', ',', 'a', 'bn:00035907n', 'of', 'bn:00060708n', 'of', 'ringing', 'bn:00041942n', ',', 'bn:00082491v', 'to', 'bn:00082573v', 'bn:00025569n', 'with', 'bn:00079910n', ',', 'bn:00093287v', 'john', 'c.', 'bn:00008090n', ',', 'bn:00017517n', '.']
# ['the', 'central', 'council', 'of', 'church', 'bell', 'ringer', ',', 'a', 'bn:00072855n', 'of', 'bn:00060708n', 'of', 'ringing', 'bn:00041942n', ',', 'bn:00082491v', 'to', 'bn:00082573v', 'bn:00025569n', 'with', 'bn:00079912n', ',', 'bn:00093287v', 'john', 'c.', 'baldwin', ',', 'bn:00017517n', '.']
#
#
# ['it', 'bn:00086683v', 'to', 'bn:00090943v', 'to', 'bn:00029806n', 'at', 'bn:00111805a', 'bn:00020641n', 'about', 'the', 'bn:00048468n', 'of', 'bn:00009760n', 'and', 'will', 'bn:00114513r', 'bn:00092023v', 'a', 'bn:00012133n', 'for', 'every', 'bn:00079910n', 'in', 'the', 'bn:00023236n', 'bn:00087690v', ',', '``', 'the', 'bn:00009727n', 'in', 'you', 'bn:00016013n', '.', '``']
# ['it', 'bn:00088954v', 'to', 'bn:00094089v', 'to', 'bn:00029806n', 'at', 'bn:00111805a', 'bn:00020642n', 'about', 'the', 'bn:00026047n', 'of', 'bn:00009762n', 'and', 'will', 'bn:00114513r', 'bn:00092023v', 'a', 'bn:00012133n', 'for', 'every', 'bn:00079912n', 'in', 'the', 'bn:00023235n', 'bn:00087691v', ',', '``', 'the', 'bn:00009727n', 'in', 'you', 'bn:00016015n', '.', '``']
#
#
# ['bn:00093287v', 'bn:00055346n', 'bn:00008090n', ',', '``', 'we', 'bn:00082472v', 'that', 'we', 'may', 'bn:00116348r', 'bn:00116156r', 'have', 'as', 'bn:00104162a', 'a', 'bn:00064072n', 'in', 'bn:00018995n', 'bn:00051046n', 'and', 'bn:00032306n', '.', '``']
# ['bn:00093290v', 'bn:00055346n', 'baldwin', ',', '``', 'we', 'bn:00082472v', 'that', 'we', 'may', 'bn:00116349r', 'bn:00116156r', 'have', 'as', 'bn:00102158a', 'a', 'bn:00064072n', 'in', 'bn:00018819n', 'bn:00051045n', 'and', 'bn:00032307n', '.', '``']
#
#
# ['bn:00055346n', 'bn:00008090n', 'be', 'bn:00114246r', 'bn:00082838v', 'the', 'bn:00103782a', 'bn:00048242n', ':', 'bn:00025913n', 'of', 'bn:00009757n', '.']
# ['bn:00055346n', 'baldwin', 'be', 'bn:00114246r', 'bn:00082899v', 'the', 'bn:00103782a', 'bn:00048242n', ':', 'bn:00025913n', 'of', 'bn:00009757n', '.']
#
#
# ['one', 'bn:00074790n', 'bn:00093287v', 'that', 'of', 'the', '100,000', 'bn:00084856v', 'bn:00009757n', 'in', 'bn:00030861n', 'bn:00077462n', ',', 'bn:00114626r', '40,000', 'of', 'they', 'bn:00117138r', 'ring', '.']
# ['one', 'bn:00074790n', 'bn:00082527v', 'that', 'of', 'the', '100,000', 'bn:00091972v', 'bn:00009757n', 'in', 'bn:00030861n', 'bn:00077462n', ',', 'bn:00114626r', '40,000', 'of', 'they', 'bn:00117138r', 'ring', '.']
#
#
# ['bn:00114246r', ',', 'bn:00009757n', 'do', 'not', 'bn:00114250r', 'bn:00087441v', 'where', 'the', 'bn:00009727n', 'bn:00082822v', 'to', 'be', 'bn:00091505v', '--', 'like', 'in', 'bn:00106058a', ',', 'bn:00109997a', 'bn:00060680n', 'and', 'bn:00046819n', 'church', '.']
# ['bn:00114246r', ',', 'bn:00009757n', 'do', 'not', 'bn:00114250r', 'bn:00087441v', 'where', 'the', 'bn:00009727n', 'bn:00091028v', 'to', 'be', 'bn:00090125v', '--', 'like', 'in', 'bn:00106058a', ',', 'bn:00109997a', 'bn:00060680n', 'and', 'bn:00046819n', 'church', '.']
#
#
# ['but', 'the', 'bn:00023119n', "'s", 'bn:00062759n', 'to', 'bn:00082920v', 'and', 'bn:00084856v', 'bn:00009757n', 'be', 'bn:00114626r', 'bn:00116535r', 'bn:00111409a', ',', 'bn:00093287v', 'bn:00055346n', 'bn:00008090n', '.']
# ['but', 'the', 'bn:00023119n', "'s", 'bn:00062759n', 'to', 'bn:00082920v', 'and', 'bn:00086736v', 'bn:00009757n', 'be', 'bn:00114626r', 'bn:00116535r', 'bn:00111409a', ',', 'bn:00093287v', 'bn:00055346n', 'baldwin', '.']
#
#
# ['``', 'bn:00114946r', 'bn:00116381r', ',', 'we', 'be', 'bn:00106250a', 'if', 'after', 'five', 'bn:00078738n', 'we', 'bn:00089384v', 'one', 'bn:00107267a', 'bn:00009757n', 'out', 'of', '10', ',', '``', 'he', 'bn:00082317v', '.']
# ['``', 'bn:00116860r', 'bn:00116382r', ',', 'we', 'be', 'bn:00106250a', 'if', 'after', 'five', 'bn:00078738n', 'we', 'bn:00089407v', 'one', 'bn:00107268a', 'bn:00009757n', 'out', 'of', '10', ',', '``', 'he', 'bn:00082318v', '.']
#
#
# ['one', 'bn:00098857a', 'bn:00071525n', 'be', 'that', 'a', 'bn:00089083v', 'bn:00058285n', 'of', 'bn:00001530n', 'have', 'bn:00085363v', 'the', 'bn:00115811r', 'male-dominated', 'bn:00034267n', ';', 'bn:00106935a', 'than', 'a', 'bn:00058990n', 'of', 'the', 'bn:00009757n', 'bn:00077462n', 'be', 'bn:00001530n', '.']
# ['one', 'bn:00098866a', 'bn:00053450n', 'be', 'that', 'a', 'bn:00089083v', 'bn:00034394n', 'of', 'bn:00001530n', 'have', 'bn:00087677v', 'the', 'bn:00114423r', 'male-dominated', 'bn:00007985n', ';', 'bn:00106936a', 'than', 'a', 'bn:00058990n', 'of', 'the', 'bn:00009757n', 'bn:00077462n', 'be', 'bn:00001530n', '.']
#
#
# ['they', 'be', 'not', 'bn:00082197v', 'bn:00114212r', ',', 'bn:00114216r', '.']
# ['they', 'be', 'not', 'bn:00082201v', 'bn:00114212r', ',', 'bn:00114216r', '.']
#
#
# ['the', 'oldest', 'bn:00009760n', 'bn:00041942n', 'in', 'the', 'bn:00023236n', ',', 'the', 'ancient', 'society', 'of', 'college', 'youth', ',', 'bn:00083141v', 'in', '1637', ',', 'bn:00092756v', 'male-only', ',', 'a', 'bn:00032654n', 'that', "'", 'bn:00115235r', 'bn:00097147a', 'to', 'bn:00001530n', 'because', 'the', 'bn:00041942n', 'be', 'the', 'sole', 'bn:00009635n', 'of', 'bn:00009757n', 'for', 'bn:00013173n', "'s", 'bn:00106953a', 'bn:00102406a', 'bn:00018995n', ',', 'st.', 'paul', "'s", 'cathedral', 'and', 'westminster', 'abbey', '.']
# ['the', 'oldest', 'bn:00009762n', 'bn:00041942n', 'in', 'the', 'bn:00023235n', ',', 'the', 'ancient', 'society', 'of', 'college', 'youth', ',', 'bn:00085671v', 'in', '1637', ',', 'bn:00092756v', 'male-only', ',', 'a', 'bn:00032654n', 'that', "'", 'bn:00115235r', 'bn:00097147a', 'to', 'bn:00001530n', 'because', 'the', 'bn:00041942n', 'be', 'the', 'sole', 'bn:00072944n', 'of', 'bn:00009757n', 'for', 'bn:00013173n', "'s", 'bn:00106953a', 'bn:00102406a', 'bn:00018995n', ',', 'st.', 'paul', "'s", 'cathedral', 'and', 'westminster', 'abbey', '.']
#
#
# ['this', 'be', 'bn:00013173n', ',', 'no', 'bn:00001530n', 'have', 'bn:00088165v', 'a', 'bn:00031278n', 'bn:00075103n', ',', 'but', 'the', 'bn:00032426n', 'of', 'the', 'bn:00048242n', 'bn:00085373v', 'this', 'bn:00075151n', 'in', 'a', 'bn:00070609n', 'of', 'bn:00050802n', 'to', '``', 'the', 'ringing', 'world', ',', '``', 'a', 'bn:00080821n', 'bn:00057563n', 'for', 'bn:00009757n', '.']
# ['this', 'be', 'bn:00013173n', ',', 'no', 'bn:00001530n', 'have', 'bn:00088164v', 'a', 'bn:00031278n', 'bn:00016403n', ',', 'but', 'the', 'bn:00032425n', 'of', 'the', 'bn:00048242n', 'bn:00085373v', 'this', 'bn:00075151n', 'in', 'a', 'bn:00070609n', 'of', 'bn:00050802n', 'to', '``', 'the', 'ringing', 'world', ',', '``', 'a', 'bn:00104076a', 'bn:00057563n', 'for', 'bn:00009757n', '.']
#
#
# ['one', 'bn:00007287n', ',', 'bn:00092379v', 'he', 'bn:00050802n', 'as', '``', 'bn:00103397a', ',', 'bn:00097992a', 'bn:00052967n', ',', '``', 'bn:00090740v', 'on', 'the', '``', 'bn:00036471n', 'of', 'bn:00001530n', 'bn:00085620v', 'in', 'peal', ',', '``', 'and', 'bn:00082417v', 'that', 'they', '``', 'bn:00093535v', 'bn:00114473r', 'into', 'they', 'bn:00112043a', 'bn:00017749n', 'of', 'bn:00087106v', 'bn:00076264n', 'at', 'bn:00041948n', '.', '``']
# ['one', 'bn:00081711n', ',', 'bn:00093731v', 'he', 'bn:00050802n', 'as', '``', 'bn:00103397a', ',', 'bn:00097992a', 'bn:00052968n', ',', '``', 'bn:00085415v', 'on', 'the', '``', 'bn:00036471n', 'of', 'bn:00001530n', 'bn:00085620v', 'in', 'peal', ',', '``', 'and', 'bn:00082417v', 'that', 'they', '``', 'bn:00093540v', 'bn:00114472r', 'into', 'they', 'bn:00112044a', 'bn:00068130n', 'of', 'bn:00085784v', 'bn:00076264n', 'at', 'bn:00020931n', '.', '``']
#
#
# ['in', 'the', 'bn:00020012n', 'of', 'bn:00004451n', 'that', 'bn:00088421v', ',', 'one', 'bn:00001530n', 'bn:00009757n', 'from', 'solihull', 'bn:00086708v', 'that', '``', 'the', 'bn:00097854a', 'bn:00106354a', 'bn:00009757n', 'bn:00088939v', 'bn:00116771r', 'a', 'bn:00008985n', 'to', 'be', 'bn:00086682v', ':', 'bn:00114486r', 'bn:00087291v', ',', 'bn:00082386v', 'with', 'bn:00000944n', 'and', 'a', 'bn:00098342a', 'beer-belly', ',', 'bn:00115452r', 'bn:00100095a', 'and', 'bn:00117381r', 'bn:00103078a', 'in', 'peal', '.', '``']
# ['in', 'the', 'bn:00026093n', 'of', 'bn:00004451n', 'that', 'bn:00088020v', ',', 'one', 'bn:00001530n', 'bn:00009757n', 'from', 'solihull', 'bn:00090740v', 'that', '``', 'the', 'bn:00097855a', 'bn:00106355a', 'bn:00009757n', 'bn:00082540v', 'bn:00116771r', 'a', 'bn:00008985n', 'to', 'be', 'bn:00086682v', ':', 'bn:00114486r', 'bn:00087293v', ',', 'bn:00082387v', 'with', 'bn:00000944n', 'and', 'a', 'bn:00098342a', 'beer-belly', ',', 'bn:00115452r', 'bn:00113379a', 'and', 'bn:00117381r', 'bn:00100000a', 'in', 'peal', '.', '``']
#
#
# ['another', 'bn:00001530n', 'bn:00085489v', 'from', 'bn:00070991n', 'to', 'bn:00093287v', 'that', 'in', 'she', '60', 'bn:00078738n', 'of', 'ringing', ',', '``', 'i', 'have', 'bn:00116326r', 'bn:00085261v', 'a', 'bn:00049666n', 'to', 'bn:00085620v', 'in', 'the', 'bn:00009702n', '.']
# ['another', 'bn:00001530n', 'bn:00095848v', 'from', 'sheffield', 'to', 'bn:00093287v', 'that', 'in', 'she', '60', 'bn:00078738n', 'of', 'ringing', ',', '``', 'i', 'have', 'bn:00116326r', 'bn:00087862v', 'a', 'bn:00049666n', 'to', 'bn:00085620v', 'in', 'the', 'bn:00009703n', '.']
#
#
# ['i', 'have', 'bn:00093430v', 'one', 'or', 'two', 'bn:00001533n', 'bn:00084343v', ',', 'bn:00083599v', 'they', '.']
# ['i', 'have', 'bn:00093430v', 'one', 'or', 'two', 'bn:00001533n', 'bn:00084343v', ',', 'bn:00083600v', 'they', '.']
#
#
# ['bn:00106554a', 'bn:00069680n', 'be', 'bn:00083341v', 'to', 'bn:00084097v', 'a', 'bn:00034888n', 'of', 'bn:00019262n', 'which', ',', 'if', 'bn:00086261v', ',', 'bn:00090300v', 'the', 'bn:00099526a', 'bn:00026697n', 'of', 'bn:00017027n', 'that', 'bn:00084800v', 'bn:00015180n', '.']
# ['bn:00106554a', 'bn:00069680n', 'be', 'bn:00083340v', 'to', 'uncover', 'a', 'bn:00042807n', 'of', 'bn:00019262n', 'which', ',', 'if', 'bn:00086261v', ',', 'bn:00090300v', 'the', 'bn:00099527a', 'bn:00041982n', 'of', 'bn:00017027n', 'that', 'bn:00084800v', 'bn:00015180n', '.']
#
#
# ['bn:00069680n', 'bn:00093287v', 'the', 'bn:00027529n', 'of', 'these', 'bn:00019262n', 'in', 'bn:00109521a', 'bn:00014710n', 'be', 'bn:00087782v', 'a', 'bn:00107267a', 'and', 'bn:00111157a', 'picture', 'of', 'how', 'bn:00015180n', 'bn:00086733v', '.']
# ['bn:00069680n', 'bn:00082527v', 'the', 'bn:00027529n', 'of', 'these', 'bn:00019262n', 'in', 'bn:00105752a', 'bn:00014710n', 'be', 'bn:00087782v', 'a', 'bn:00103328a', 'and', 'bn:00111157a', 'picture', 'of', 'how', 'bn:00015180n', 'bn:00086738v', '.']
#
#
# ['a', 'bn:00087561v', 'bn:00005134n', 'of', 'the', 'bn:00019262n', 'be', 'bn:00082665v', 'to', 'bn:00084082v', 'a', 'bn:00005869n', 'of', 'bn:00107267a', 'bn:00069579n', 'for', 'bn:00103449a', 'bn:00015180n', 'bn:00042823n', 'and', 'bn:00008467n', '.']
# ['a', 'bn:00087563v', 'bn:00005134n', 'of', 'the', 'bn:00019262n', 'be', 'bn:00082665v', 'to', 'bn:00084069v', 'a', 'bn:00005870n', 'of', 'bn:00103328a', 'bn:00069579n', 'for', 'bn:00103450a', 'bn:00015180n', 'bn:00047235n', 'and', 'bn:00008467n', '.']
#
#
# ['that', 'be', 'for', 'the', 'bn:00036941n', '.']
# ['that', 'be', 'for', 'the', 'bn:00036941n', '.']
#
#
# ['bn:00114245r', ',', 'bn:00069680n', 'be', 'bn:00086733v', 'bn:00076647n', 'bn:00083141v', 'on', 'the', 'bn:00115453r', 'bn:00089574v', 'bn:00019262n', 'that', ',', 'for', 'the', 'bn:00103006a', 'bn:00019848n', ',', 'can', 'bn:00082668v', 'whether', 'a', 'bn:00116477r', 'bn:00104025a', 'bn:00046516n', 'be', 'bn:00105981a', 'to', 'bn:00083293v', 'bn:00015180n', '.']
# ['bn:00114245r', ',', 'bn:00069680n', 'be', 'bn:00086733v', 'bn:00068548n', 'bn:00083141v', 'on', 'the', 'bn:00115453r', 'bn:00086663v', 'bn:00019262n', 'that', ',', 'for', 'the', 'bn:00103007a', 'bn:00019848n', ',', 'can', 'bn:00082929v', 'whether', 'a', 'bn:00116477r', 'bn:00104025a', 'bn:00046516n', 'be', 'bn:00105981a', 'to', 'bn:00085727v', 'bn:00015180n', '.']
#
#
# ['``', 'it', "'", 'a', 'super-exciting', 'bn:00070696n', 'of', 'bn:00027529n', ',', '``', 'bn:00093287v', 'bert', 'vogelstein', ',', 'a', 'john', 'hopkin', 'university', 'bn:00047356n', 'who', 'have', 'bn:00114626r', 'bn:00086708v', 'a', 'bn:00019262n', 'bn:00108638a', 'to', 'the', 'bn:00082306v', 'of', 'bn:00020701n', 'bn:00015180n', '.']
# ['``', 'it', "'", 'a', 'super-exciting', 'bn:00070696n', 'of', 'bn:00027529n', ',', '``', 'bn:00093290v', 'bert', 'vogelstein', ',', 'a', 'john', 'hopkin', 'university', 'bn:00047356n', 'who', 'have', 'bn:00116052r', 'bn:00086934v', 'a', 'bn:00019262n', 'bn:00108638a', 'to', 'the', 'bn:00082306v', 'of', 'bn:00020701n', 'bn:00015180n', '.']
#
#
# ['``', 'bn:00114626r', 'a', 'bn:00025646n', 'bn:00114178r', 'bn:00015180n', 'be', 'a', 'black', 'box', 'about', 'which', 'we', 'bn:00085261v', 'bn:00007146n', 'at', 'the', 'bn:00106855a', 'bn:00025965n', '.']
# ['``', 'bn:00116451r', 'a', 'bn:00025646n', 'bn:00114178r', 'bn:00015180n', 'be', 'a', 'black', 'box', 'about', 'which', 'we', 'bn:00085261v', 'bn:00007146n', 'at', 'the', 'bn:00106855a', 'bn:00025966n', '.']
#
#
# ['bn:00077462n', ',', 'we', 'bn:00085261v', 'that', 'the', 'bn:00000766n', 'of', 'several', 'of', 'these', 'bn:00082553v', 'bn:00019262n', 'can', 'bn:00089745v', 'a', 'bn:00015180n', 'and', ',', 'bn:00114281r', ',', 'bn:00089614v', 'it', 'into', 'a', 'bn:00100969a', 'bn:00074009n', '.', '``']
# ['bn:00077462n', ',', 'we', 'bn:00085261v', 'that', 'the', 'bn:00000766n', 'of', 'several', 'of', 'these', 'bn:00082553v', 'bn:00019262n', 'can', 'bn:00089743v', 'a', 'bn:00015180n', 'and', ',', 'bn:00114281r', ',', 'bn:00089614v', 'it', 'into', 'a', 'bn:00100973a', 'bn:00074009n', '.', '``']
#
#
# ['bn:00069680n', 'bn:00084385v', 'the', 'bn:00107267a', 'bn:00019479n', 'of', 'bn:00019262n', 'tumor-suppressor', ',', 'or', 'bn:00114626r', 'bn:00097220a', 'bn:00019262n', '.']
# ['bn:00069680n', 'bn:00084385v', 'the', 'bn:00103328a', 'bn:00016733n', 'of', 'bn:00019262n', 'tumor-suppressor', ',', 'or', 'bn:00116623r', 'bn:00097220a', 'bn:00019262n', '.']
#
#
# ['when', 'bn:00088629v', 'bn:00114778r', ',', 'they', 'bn:00087106v', 'bn:00064855n', 'that', 'bn:00089240v', 'a', 'bn:00017027n', "'s", 'bn:00026697n', 'in', 'check', '.']
# ['when', 'bn:00088629v', 'bn:00114778r', ',', 'they', 'bn:00086008v', 'bn:00064855n', 'that', 'bn:00089384v', 'a', 'bn:00017027n', "'s", 'bn:00026697n', 'in', 'check', '.']
#
#
# ['but', 'if', 'the', 'bn:00019262n', 'be', 'bn:00086261v', '--', 'bn:00116211r', 'by', 'bn:00065874n', ',', 'a', 'bn:00018096n', 'or', 'through', 'a', 'bn:00099330a', 'bn:00000690n', 'in', 'bn:00017027n', 'bn:00027911n', '--', 'they', 'growth-suppressing', 'bn:00064855n', 'no', 'bn:00116156r', 'bn:00087128v', ',', 'and', 'bn:00017027n', 'bn:00114778r', 'under', 'control', 'bn:00095233v', 'bn:00106363a', '.']
# ['but', 'if', 'the', 'bn:00019262n', 'be', 'bn:00086261v', '--', 'bn:00116211r', 'by', 'bn:00065874n', ',', 'a', 'bn:00018096n', 'or', 'through', 'a', 'bn:00099330a', 'bn:00000691n', 'in', 'bn:00017027n', 'bn:00027913n', '--', 'they', 'growth-suppressing', 'bn:00064855n', 'no', 'bn:00116156r', 'bn:00088629v', ',', 'and', 'bn:00017027n', 'bn:00114778r', 'under', 'control', 'bn:00089082v', 'bn:00106363a', '.']
#
#
# ['the', 'bn:00115453r', 'bn:00089574v', 'bn:00019262n', 'bn:00086797v', 'from', 'a', 'bn:00032893n', 'of', 'bn:00019262n', 'bn:00086708v', 'in', 'the', 'bn:00101935a', '1980', 'bn:00084385v', 'bn:00058964n', '.']
# ['the', 'bn:00115453r', 'bn:00086663v', 'bn:00019262n', 'bn:00086797v', 'from', 'a', 'bn:00016733n', 'of', 'bn:00019262n', 'bn:00086663v', 'in', 'the', 'bn:00101935a', '1980', 'bn:00084385v', 'bn:00058964n', '.']
#
#
# ['bn:00058964n', 'must', 'be', 'bn:00108978a', 'for', 'a', 'bn:00017027n', 'to', 'bn:00083293v', 'bn:00106363a', ',', 'but', 'bn:00047356n', 'have', 'bn:00086708v', 'they', 'in', 'bn:00107587a', 'as', 'well', 'as', 'in', 'bn:00099180a', 'bn:00017027n', ',', 'bn:00082417v', 'that', 'bn:00058964n', 'do', "n't", 'bn:00084699v', 'bn:00015180n', 'by', 'themselves', '.']
# ['bn:00058964n', 'must', 'be', 'bn:00108978a', 'for', 'a', 'bn:00017027n', 'to', 'bn:00083293v', 'bn:00106363a', ',', 'but', 'bn:00047356n', 'have', 'bn:00086708v', 'they', 'in', 'bn:00107587a', 'as', 'well', 'as', 'in', 'bn:00099180a', 'bn:00017027n', ',', 'bn:00089856v', 'that', 'bn:00058964n', 'do', "n't", 'bn:00084699v', 'bn:00015180n', 'by', 'themselves', '.']
#
#
# ['in', 'bn:00109521a', 'bn:00014710n', ',', 'bn:00047356n', 'have', 'bn:00085320v', 'to', 'bn:00083369v', 'the', 'two', 'bn:00078798n', 'of', 'bn:00015180n', 'bn:00019262n', 'bn:00087128v', 'bn:00115794r', ':', 'a', 'bn:00058964n', 'may', 'bn:00095233v', 'bn:00092061v', 'bn:00017027n', 'bn:00106363a', 'bn:00114626r', 'after', 'the', 'tumor-suppressor', 'bn:00019262n', 'have', 'be', 'bn:00086261v', '.']
# ['in', 'bn:00105752a', 'bn:00014710n', ',', 'bn:00047356n', 'have', 'bn:00085321v', 'to', 'bn:00083369v', 'the', 'two', 'bn:00078798n', 'of', 'bn:00015180n', 'bn:00019262n', 'bn:00088629v', 'bn:00115794r', ':', 'a', 'bn:00058964n', 'may', 'bn:00095240v', 'bn:00092062v', 'bn:00017027n', 'bn:00106363a', 'bn:00116450r', 'after', 'the', 'tumor-suppressor', 'bn:00019262n', 'have', 'be', 'bn:00086261v', '.']
#
#
# ['like', 'all', 'bn:00019262n', ',', 'tumor-suppressor', 'bn:00019262n', 'be', 'bn:00089736v', 'in', 'two', 'bn:00022525n', ',', 'one', 'from', 'each', 'bn:00060643n', '.']
# ['like', 'all', 'bn:00019262n', ',', 'tumor-suppressor', 'bn:00019262n', 'be', 'bn:00089738v', 'in', 'two', 'bn:00022526n', ',', 'one', 'from', 'each', 'bn:00060643n', '.']
#
#
# ['either', 'bn:00022525n', 'can', 'bn:00087106v', 'the', 'bn:00064855n', 'bn:00082822v', 'to', 'bn:00085404v', 'bn:00017027n', 'bn:00026697n', ',', 'so', 'for', 'bn:00015180n', 'to', 'bn:00082761v', ',', 'both', 'bn:00022525n', 'must', 'be', 'bn:00089610v', '.']
# ['either', 'bn:00022526n', 'can', 'bn:00086008v', 'the', 'bn:00064855n', 'bn:00082822v', 'to', 'bn:00084850v', 'bn:00017027n', 'bn:00026697n', ',', 'so', 'for', 'bn:00015180n', 'to', 'bn:00082757v', ',', 'both', 'bn:00022526n', 'must', 'be', 'bn:00104623a', '.']
#
#
# ['a', 'bn:00046516n', 'who', 'be', 'bn:00083227v', 'with', 'one', 'bn:00101072a', 'bn:00022525n', 'of', 'a', 'bn:00075347n', ',', 'or', 'in', 'whom', 'one', 'bn:00022525n', 'be', 'bn:00086261v', 'bn:00115153r', 'in', 'bn:00051046n', ',', 'be', 'bn:00115235r', 'prone', 'to', 'bn:00015180n', 'because', 'he', 'bn:00082822v', 'bn:00114626r', 'bn:00090485v', 'the', 'bn:00108011a', 'bn:00022525n', 'for', 'a', 'bn:00015180n', 'to', 'bn:00086733v', '.']
# ['a', 'bn:00046516n', 'who', 'be', 'bn:00083222v', 'with', 'one', 'bn:00097979a', 'bn:00022526n', 'of', 'a', 'bn:00075347n', ',', 'or', 'in', 'whom', 'one', 'bn:00022526n', 'be', 'bn:00086261v', 'bn:00115153r', 'in', 'bn:00051049n', ',', 'be', 'bn:00115235r', 'prone', 'to', 'bn:00015180n', 'because', 'he', 'bn:00091029v', 'bn:00114626r', 'bn:00090485v', 'the', 'bn:00108011a', 'bn:00022526n', 'for', 'a', 'bn:00015180n', 'to', 'bn:00082757v', '.']
#
#
# ['bn:00087561v', 'bn:00102757a', 'bn:00076647n', 'will', 'be', 'bn:00096151a', 'to', 'bn:00086664v', 'bn:00111411a', 'cancer-susceptible', 'bn:00046516n', ',', 'bn:00089648v', 'what', 'some', 'bn:00069680n', 'bn:00083369v', 'be', 'a', 'bn:00107267a', 'bn:00001936n', 'of', 'bn:00108932a', 'bn:00015180n', 'bn:00026805n', '.']
# ['bn:00102155a', 'bn:00103524a', 'bn:00068548n', 'will', 'be', 'bn:00096151a', 'to', 'bn:00086664v', 'bn:00111411a', 'cancer-susceptible', 'bn:00046516n', ',', 'bn:00089648v', 'what', 'some', 'bn:00069680n', 'bn:00083370v', 'be', 'a', 'bn:00107269a', 'bn:00001937n', 'of', 'bn:00108932a', 'bn:00015180n', 'bn:00026805n', '.']
#
#
# ['bill', 'and', 'bonnie', 'quinlan', 'be', 'among', 'the', 'bn:00103006a', 'bn:00009896n', 'of', 'the', 'bn:00107267a', 'bn:00026650n', '.']
# ['bill', 'and', 'bonnie', 'quinlan', 'be', 'among', 'the', 'bn:00103006a', 'bn:00009902n', 'of', 'the', 'bn:00103328a', 'bn:00034551n', '.']
#
#
# ['the', 'dedham', ',', 'mas.', ',', 'bn:00023268n', 'bn:00085261v', 'bn:00115244r', 'bn:00114512r', 'bonnie', 'bn:00083293v', 'bn:00108940a', 'in', '1987', 'that', 'any', 'bn:00018345n', 'of', 'theirs', 'have', 'a', '50', '%', 'bn:00017621n', 'of', 'be', 'at', 'bn:00030747n', 'for', 'bn:00067452n', ',', 'a', 'bn:00032512n', 'bn:00015180n', 'that', 'bn:00085337v', 'bn:00114079r', 'bn:00115811r', 'every', '20,000', 'bn:00010663n', '.']
# ['the', 'dedham', ',', 'mas.', ',', 'bn:00023269n', 'bn:00085261v', 'bn:00115244r', 'bn:00114512r', 'bonnie', 'bn:00083293v', 'bn:00108940a', 'in', '1987', 'that', 'any', 'bn:00018346n', 'of', 'theirs', 'have', 'a', '50', '%', 'bn:00017624n', 'of', 'be', 'at', 'bn:00030747n', 'for', 'bn:00067452n', ',', 'a', 'bn:00032512n', 'bn:00015180n', 'that', 'bn:00091132v', 'bn:00114073r', 'bn:00115811r', 'every', '20,000', 'bn:00010664n', '.']
#
#
# ['mr.', 'quinlan', ',', '30', 'year', 'old', ',', 'bn:00085261v', 'he', 'bn:00084554v', 'a', 'bn:00086261v', 'bn:00019262n', ',', 'have', 'bn:00090485v', 'a', 'bn:00032512n', 'to', 'the', 'bn:00109440a', 'bn:00057267n', 'when', 'he', 'be', 'bn:00114626r', 'two', 'month', 'old', '--', 'after', 'he', 'bn:00034027n', 'have', 'bn:00094573v', 'the', 'bn:00110075a', 'bn:00026603n', 'when', 'she', 'be', 'a', 'bn:00007630n', '.']
# ['mr.', 'quinlan', ',', '30', 'year', 'old', ',', 'bn:00085261v', 'he', 'bn:00084568v', 'a', 'bn:00100882a', 'bn:00019262n', ',', 'have', 'bn:00090485v', 'a', 'bn:00032512n', 'to', 'the', 'bn:00109441a', 'bn:00057267n', 'when', 'he', 'be', 'bn:00114626r', 'two', 'month', 'old', '--', 'after', 'he', 'bn:00034027n', 'have', 'bn:00090727v', 'the', 'bn:00110076a', 'bn:00026603n', 'when', 'she', 'be', 'a', 'bn:00007630n', '.']
#
#
# ['because', 'of', 'the', 'bn:00047644n', 'of', 'the', 'bn:00067452n', 'tumor-suppressor', 'bn:00019262n', ',', 'it', 'bn:00083293v', 'bn:00108829a', 'bn:00105739a', 'bn:00047960n', 'to', 'bn:00086933v', 'what', 'bn:00054311n', 'the', 'quinlan', 'bn:00007630n', 'bn:00085596v', '.']
# ['because', 'of', 'the', 'bn:00019967n', 'of', 'the', 'bn:00067452n', 'tumor-suppressor', 'bn:00019262n', ',', 'it', 'bn:00083293v', 'bn:00108829a', 'bn:00105739a', 'bn:00047960n', 'to', 'bn:00082813v', 'what', 'bn:00054311n', 'the', 'quinlan', 'bn:00007630n', 'bn:00085596v', '.']
#
#
# ['a', 'bn:00076647n', 'bn:00082705v', 'bn:00107267a', '``', 'bn:00102757a', 'probe', '``', 'bn:00086567v', 'that', 'bn:00106059a', 'will', 'quinlan', 'have', 'not', 'bn:00089736v', 'a', 'bn:00086261v', 'bn:00067452n', 'bn:00075347n', 'and', ',', 'bn:00115635r', ',', 'bn:00085596v', 'no', 'bn:00106935a', 'bn:00030747n', 'than', 'bn:00108011a', 'bn:00018345n', 'of', 'bn:00086733v', 'the', 'bn:00109440a', 'bn:00015180n', '.']
# ...
# ['bn:00016433n', 'each', 'bn:00107137a', 'bn:00067181n', 'bn:00085499v', 'a', 'bn:00063673n', 'of', 'between', '25', 'and', '30', 'bn:00034797n', 'which', 'best', 'bn:00090234v', 'bn:00063329n', 'and', 'bn:00061054n', 'to', 'bn:00082573v', 'the', 'bn:00030933n', ',', 'bn:00041853n', 'and', 'bn:00026695n', 'of', 'bn:00082449v', 'bn:00081593n', 'in', 'both', 'the', 'bn:00030625n', 'bn:00062700n', 'and', 'the', 'bn:00021248n', '.']
#
#
# ['for', 'each', 'bn:00023236n', ',', 'two', 'or', 'three', 'bn:00034797n', 'have', 'be', 'bn:00084931v', 'for', 'bn:00102794a', 'in', 'bn:00025827n', 'bn:00016433n', '.']
# ['for', 'each', 'bn:00023235n', ',', 'two', 'or', 'three', 'bn:00034797n', 'have', 'be', 'bn:00084931v', 'for', 'bn:00102794a', 'in', 'bn:00026418n', 'bn:00016433n', '.']
#
#
# ['these', 'bn:00016433n', 'bn:00082596v', 'the', 'bn:00007781n', 'of', 'the', 'bn:00034797n', ',', 'they', 'bn:00046064n', 'on', 'bn:00030627n', 'bn:00035908n', 'and', 'bn:00062309n', 'bn:00059480n', 'and', 'bn:00082720v', 'the', 'bn:00009905n', 'and', 'bn:00048242n', 'of', 'the', 'bn:00034797n', '.']
# ['these', 'bn:00016433n', 'bn:00082597v', 'the', 'bn:00007786n', 'of', 'the', 'bn:00034797n', ',', 'they', 'bn:00046065n', 'on', 'bn:00030626n', 'bn:00061055n', 'and', 'bn:00081568n', 'bn:00001423n', 'and', 'bn:00082720v', 'the', 'bn:00009905n', 'and', 'bn:00048242n', 'of', 'the', 'bn:00034797n', '.']
#
#
# ['bn:00080111n', 'and', 'bn:00047238n', 'with', 'bn:00099258a', 'bn:00035770n', 'be', 'bn:00114246r', 'bn:00082906v', '.']
# ['bn:00080113n', 'and', 'bn:00047238n', 'with', 'bn:00099258a', 'bn:00035770n', 'be', 'bn:00114246r', 'bn:00094722v', '.']
#
#
# ['these', 'bn:00107136a', 'bn:00074790n', 'will', 'bn:00088489v', 'the', 'bn:00008786n', 'of', 'a', 'bn:00102440a', 'bn:00000739n', 'which', 'bn:00094713v', 'bn:00108083a', 'bn:00061054n', '.']
# ['these', 'bn:00107137a', 'bn:00074790n', 'will', 'bn:00085670v', 'the', 'bn:00008790n', 'of', 'a', 'bn:00102440a', 'bn:00067181n', 'which', 'bn:00094713v', 'bn:00108083a', 'bn:00061054n', '.']
#
#
# ['the', 'bn:00000739n', 'and', 'a', 'bn:00016435n', 'of', 'bn:00034797n', 'will', 'be', 'bn:00092023v', 'in', '1996', 'and', 'bn:00088643v', 'the', 'backdrop', 'for', 'a', 'bn:00021721n', 'to', 'be', 'bn:00082779v', 'in', 'bn:00007406n', ',', '1996', '.']
# ['the', 'bn:00067181n', 'and', 'a', 'bn:00016435n', 'of', 'bn:00034797n', 'will', 'be', 'bn:00092023v', 'in', '1996', 'and', 'bn:00084692v', 'the', 'backdrop', 'for', 'a', 'bn:00021721n', 'to', 'be', 'bn:00082779v', 'in', 'bn:00007406n', ',', '1996', '.']
#
#
# ['the', 'bn:00036063n', 'bn:00082491v', 'to', 'bn:00087137v', 'the', 'bn:00017761n', 'of', 'bn:00001936n', 'bn:00008713n', 'in', 'bn:00018756n', 'bn:00030933n', 'and', 'bn:00041853n', 'and', 'to', 'bn:00082596v', 'they', 'bn:00016850n', '.']
# ['the', 'bn:00036064n', 'bn:00082486v', 'to', 'bn:00087137v', 'the', 'bn:00017762n', 'of', 'bn:00001936n', 'bn:00008714n', 'in', 'bn:00014138n', 'bn:00030933n', 'and', 'bn:00041853n', 'and', 'to', 'bn:00082597v', 'they', 'bn:00016850n', '.']
#
#
# ['the', 'bn:00061746n', 'of', 'the', 'bn:00110842a', 'partner', 'be', 'bn:00114246r', 'be', 'bn:00082596v', ',', 'with', 'bn:00108295a', 'bn:00007020n', 'bn:00091493v', 'to', 'bn:00064776n', 'for', 'bn:00092783v', 'bn:00001936n', 'bn:00008713n', '.']
# ['the', 'bn:00061746n', 'of', 'the', 'bn:00110842a', 'partner', 'be', 'bn:00114246r', 'be', 'bn:00082596v', ',', 'with', 'bn:00102398a', 'bn:00007020n', 'bn:00088817v', 'to', 'bn:00064776n', 'for', 'bn:00088783v', 'bn:00001936n', 'bn:00008714n', '.']
#
#
# ['bn:00117283r', ',', 'the', 'bn:00049573n', 'document', 'and', 'bn:00082720v', 'bn:00034797n', ',', 'in', 'both', 'the', 'bn:00109211a', 'and', 'bn:00109026a', 'bn:00070205n', 'which', 'combat', 'bn:00001936n', 'bn:00008713n', ',', 'bn:00115235r', 'for', 'bn:00107786a', 'bn:00081593n', '.']
# ['bn:00117283r', ',', 'the', 'bn:00064665n', 'document', 'and', 'bn:00082720v', 'bn:00034797n', ',', 'in', 'both', 'the', 'bn:00109212a', 'and', 'bn:00104973a', 'bn:00070206n', 'which', 'combat', 'bn:00001936n', 'bn:00008714n', ',', 'bn:00115235r', 'for', 'bn:00107786a', 'bn:00081593n', '.']
#
#
# ['bn:00093452v', 'bn:00003132n', 'to', 'bn:00101935a', 'bn:00067456n', 'and', 'bn:00066743n', ',', 'the', 'bn:00049573n', 'be', 'bn:00114714r', 'bn:00083240v', 'with', 'the', 'bn:00044396n', ',', 'bn:00092717v', 'and', 'bn:00092953v', 'of', 'bn:00107786a', 'bn:00081593n', '.']
# ['bn:00090460v', 'bn:00003132n', 'to', 'bn:00101935a', 'bn:00067456n', 'and', 'bn:00066743n', ',', 'the', 'bn:00064665n', 'be', 'bn:00114714r', 'bn:00083240v', 'with', 'the', 'bn:00044396n', ',', 'bn:00092717v', 'and', 'bn:00092954v', 'of', 'bn:00107786a', 'bn:00081593n', '.']
#
#
# ['the', 'bn:00037633n', 'and', 'bn:00100762a', 'bn:00007781n', 'of', 'bn:00081593n', 'and', 'how', 'these', 'bn:00083240v', 'to', 'bn:00001936n', 'bn:00027538n', 'be', 'bn:00082596v', '.']
# ['the', 'bn:00037634n', 'and', 'bn:00100762a', 'bn:00007781n', 'of', 'bn:00081593n', 'and', 'how', 'these', 'bn:00082868v', 'to', 'bn:00001936n', 'bn:00027538n', 'be', 'bn:00082596v', '.']
#
#
# ['the', 'bn:00049573n', 'bn:00114246r', 'bn:00083370v', 'bn:00034797n', 'to', 'combat', 'bn:00001936n', 'bn:00027538n', 'in', 'bn:00023237n', 'and', 'in', 'bn:00106058a', 'and', 'medium', 'size', 'bn:00030751n', '.']
# ['the', 'bn:00064665n', 'bn:00114246r', 'bn:00085651v', 'bn:00034797n', 'to', 'combat', 'bn:00001936n', 'bn:00027538n', 'in', 'bn:00023237n', 'and', 'in', 'bn:00106773a', 'and', 'medium', 'size', 'bn:00031008n', '.']
#
#
# ['seven', 'bn:00034004n', 'bn:00074009n', 'be', 'bn:00085903v', 'by', 'the', 'bn:00049573n', ':', 'belgium', ',', 'france', ',', 'germany', ',', 'greece', ',', 'italy', ',', 'the', 'netherland', 'and', 'the', 'bn:00112908a', 'bn:00049171n', '.']
# ['seven', 'bn:00054277n', 'bn:00023236n', 'be', 'bn:00085497v', 'by', 'the', 'bn:00064665n', ':', 'belgium', ',', 'france', ',', 'germany', ',', 'greece', ',', 'italy', ',', 'the', 'netherland', 'and', 'the', 'bn:00112908a', 'bn:00049168n', '.']
#
#
# ['this', 'bn:00028015n', 'be', 'a', 'bn:00075142n', 'of', 'the', 'bn:00102440a', 'bn:00109211a', 'bn:00005120n', 'bn:00000739n', '.']
# ['this', 'bn:00028015n', 'be', 'a', 'bn:00075142n', 'of', 'the', 'bn:00102440a', 'bn:00109211a', 'bn:00005120n', 'bn:00067181n', '.']
#
#
# ['it', 'bn:00087869v', 'how', 'the', 'bn:00021015n', 'for', 'bn:00106556a', 'bn:00054416n', 'for', 'bn:00079883n', 'bn:00030627n', '(', 'cvmp', ')', 'bn:00082720v', 'the', 'bn:00074790n', 'bn:00091550v', ',', 'to', 'bn:00082226v', 'they', 'bn:00066562n', 'on', 'how', 'to', 'bn:00082705v', 'the', 'bn:00054128n', '.']
# ['it', 'bn:00087870v', 'how', 'the', 'bn:00021015n', 'for', 'bn:00106556a', 'bn:00064584n', 'for', 'bn:00079883n', 'bn:00030627n', '(', 'cvmp', ')', 'bn:00082720v', 'the', 'bn:00074790n', 'bn:00087107v', ',', 'to', 'bn:00088789v', 'they', 'bn:00066562n', 'on', 'how', 'to', 'bn:00082705v', 'the', 'bn:00054128n', '.']
#
#
# ['what', 'be', 'cerenia', '?']
# ['what', 'be', 'cerenia', '?']
#
#
# ['cerenia', 'bn:00085499v', 'the', 'bn:00096382a', 'bn:00074985n', 'maropitant', 'and', 'be', 'bn:00097846a', 'as', 'bn:00075830n', 'or', 'as', 'bn:00072760n', 'for', 'bn:00046786n', '.']
# ['cerenia', 'bn:00085499v', 'the', 'bn:00096387a', 'bn:00074985n', 'maropitant', 'and', 'be', 'bn:00097846a', 'as', 'bn:00052222n', 'or', 'as', 'bn:00072760n', 'for', 'bn:00046787n', '.']
#
#
# ['the', 'bn:00075830n', 'be', 'pale-orange', 'and', 'bn:00089240v', 'a', 'bn:00056470n', 'bn:00014138n', 'on', 'both', 'bn:00071431n', 'bn:00117043r', 'that', 'they', 'can', 'be', 'bn:00089157v', '.']
# ['the', 'bn:00052222n', 'be', 'pale-orange', 'and', 'bn:00089240v', 'a', 'bn:00069754n', 'bn:00023645n', 'on', 'both', 'bn:00071433n', 'bn:00117049r', 'that', 'they', 'can', 'be', 'bn:00089157v', '.']
#
#
# ['each', 'bn:00075830n', 'be', 'bn:00090151v', 'with', 'the', 'pfizer', 'bn:00051872n', 'on', 'one', 'bn:00071431n', 'and', 'with', 'the', 'bn:00050802n', 'mpt', 'and', 'the', 'bn:00003603n', 'of', 'maropitant', 'on', 'the', 'bn:00108011a', 'bn:00071431n', '.']
# ['each', 'bn:00052222n', 'be', 'bn:00090663v', 'with', 'the', 'pfizer', 'bn:00051872n', 'on', 'one', 'bn:00071433n', 'and', 'with', 'the', 'bn:00003057n', 'mpt', 'and', 'the', 'bn:00003603n', 'of', 'maropitant', 'on', 'the', 'bn:00108011a', 'bn:00071433n', '.']
#
#
# ['what', 'be', 'cerenia', 'bn:00082705v', 'for', '?']
# ['what', 'be', 'cerenia', 'bn:00082705v', 'for', '?']
#
#
# ['cerenia', 'be', 'a', 'bn:00004656n', ',', 'this', 'bn:00087672v', 'that', 'it', 'bn:00084710v', 'bn:00083115v', '.']
# ['cerenia', 'be', 'a', 'bn:00004656n', ',', 'this', 'bn:00089805v', 'that', 'it', 'bn:00094398v', 'bn:00083115v', '.']
#
#
# ['it', 'be', 'bn:00082705v', 'in', 'bn:00015267n', 'to', 'bn:00088454v', 'bn:00083115v', 'such', 'as', 'bn:00083115v', 'bn:00084699v', 'by', 'bn:00018141n', '(', 'bn:00054128n', 'bn:00082705v', 'for', 'the', 'bn:00042823n', 'of', 'bn:00015180n', ',', 'some', 'of', 'which', 'be', 'bn:00085261v', 'to', 'bn:00084699v', 'bn:00083115v', ')', '.']
# ['it', 'be', 'bn:00082705v', 'in', 'bn:00015267n', 'to', 'bn:00088454v', 'bn:00083115v', 'such', 'as', 'bn:00083115v', 'bn:00084699v', 'by', 'bn:00018141n', '(', 'bn:00054128n', 'bn:00082705v', 'for', 'the', 'bn:00047235n', 'of', 'bn:00015180n', ',', 'some', 'of', 'which', 'be', 'bn:00090142v', 'to', 'bn:00084699v', 'bn:00083115v', ')', '.']
#
#
# ['in', 'bn:00020872n', 'with', 'bn:00111492a', 'bn:00054019n', 'such', 'as', 'bn:00108011a', 'bn:00113583a', 'bn:00042823n', 'or', 'a', 'bn:00108295a', 'bn:00027011n', ',', 'cerenia', 'can', 'bn:00114246r', 'be', 'bn:00082705v', 'in', 'the', 'bn:00042823n', 'of', 'bn:00027565n', '(', 'either', 'as', 'bn:00046786n', 'or', 'as', 'bn:00046786n', 'bn:00088421v', 'by', 'bn:00075830n', ')', '.']
# ['in', 'bn:00020872n', 'with', 'bn:00111492a', 'bn:00054018n', 'such', 'as', 'bn:00108011a', 'bn:00113583a', 'bn:00047235n', 'or', 'a', 'bn:00110996a', 'bn:00027011n', ',', 'cerenia', 'can', 'bn:00114246r', 'be', 'bn:00082705v', 'in', 'the', 'bn:00047235n', 'of', 'bn:00027565n', '(', 'either', 'as', 'bn:00046787n', 'or', 'as', 'bn:00046787n', 'bn:00088425v', 'by', 'bn:00052222n', ')', '.']
#
#
# ['for', 'these', 'bn:00002178n', ',', 'cerenia', 'can', 'be', 'bn:00082442v', 'for', 'up', 'to', 'five', 'bn:00000086n']
# ['for', 'these', 'bn:00002178n', ',', 'cerenia', 'can', 'be', 'bn:00088826v', 'for', 'up', 'to', 'five', 'bn:00025419n']
#
#
# ['how', 'do', 'cerenia', 'work', '?']
# ['how', 'do', 'cerenia', 'work', '?']
#
#
# ['cerenia', 'bn:00083623v', 'a', 'neurokinin', '1', '(', 'nk1', ')', 'bn:00066514n', ',', 'which', 'bn:00082291v', 'in', 'the', 'bn:00017184n', '.']
# ['cerenia', 'bn:00083622v', 'a', 'neurokinin', '1', '(', 'nk1', ')', 'bn:00066514n', ',', 'which', 'bn:00082285v', 'in', 'the', 'bn:00017184n', '.']
#
#
# ['how', 'have', 'cerenia', 'be', 'bn:00082596v', '?']
# ['how', 'have', 'cerenia', 'be', 'bn:00082596v', '?']
#
#
# ['a', 'bn:00009055n', 'of', 'bn:00074790n', 'with', 'cerenia', 'be', 'bn:00082225v', 'either', 'in', 'bn:00049551n', 'bn:00015267n', 'or', 'in', 'animal', 'bn:00061017n', 'at', 'bn:00113583a', 'bn:00091912v', 'in', 'bn:00110469a', 'bn:00031903n', 'and', 'in', 'the', 'bn:00003341n', '.']
# ['a', 'bn:00009055n', 'of', 'bn:00074790n', 'with', 'cerenia', 'be', 'bn:00082225v', 'either', 'in', 'bn:00049551n', 'bn:00015267n', 'or', 'in', 'animal', 'bn:00061017n', 'at', 'bn:00113583a', 'practise', 'in', 'bn:00110469a', 'bn:00031903n', 'and', 'in', 'the', 'usa', '.']
#
#
# ['what', 'bn:00009905n', 'have', 'cerenia', 'bn:00086567v', 'during', 'the', 'bn:00074790n', '?']
# ['what', 'bn:00009905n', 'have', 'cerenia', 'bn:00083245v', 'during', 'the', 'bn:00074790n', '?']
#
#
# ['the', 'bn:00021961n', 'of', 'the', 'bn:00074790n', 'bn:00086567v', 'that', 'cerenia', 'be', 'bn:00116284r', 'bn:00102038a', 'than', 'the', 'bn:00062717n', ':', 'bn:00105886a', 'bn:00027565n', 'be', 'bn:00093430v', 'in', 'bn:00015267n', 'that', 'bn:00087863v', 'the', 'bn:00054128n', 'than', 'in', 'bn:00015267n', 'that', 'bn:00087863v', 'a', 'bn:00062717n', ',', 'both', 'in', 'the', 'bn:00042823n', 'or', 'in', 'the', 'bn:00008467n', 'of', 'bn:00027565n', '.']
# ['the', 'bn:00034520n', 'of', 'the', 'bn:00074790n', 'bn:00083245v', 'that', 'cerenia', 'be', 'bn:00116284r', 'bn:00102038a', 'than', 'the', 'bn:00062717n', ':', 'bn:00105886a', 'bn:00027565n', 'be', 'bn:00082813v', 'in', 'bn:00015267n', 'that', 'bn:00087863v', 'the', 'bn:00054128n', 'than', 'in', 'bn:00015267n', 'that', 'bn:00087863v', 'a', 'bn:00062717n', ',', 'both', 'in', 'the', 'bn:00047235n', 'or', 'in', 'the', 'bn:00008467n', 'of', 'bn:00027565n', '.']
#
#
# ['the', 'bn:00042823n', 'of', 'a', 'bn:00027565n', 'bn:00015267n', 'should', 'be', 'bn:00083341v', 'with', 'the', 'bn:00046786n', ',', 'since', 'bn:00027565n', 'bn:00004222n', 'might', 'bn:00116360r', 'be', 'bn:00096151a', 'to', 'keep', 'a', 'bn:00075830n', 'down', '(', 'as', 'they', 'might', 'throw', 'the', 'bn:00102278a', 'bn:00075830n', 'up', 'bn:00114171r', ')', '.']
# ['the', 'bn:00047235n', 'of', 'a', 'bn:00027565n', 'bn:00015267n', 'should', 'be', 'bn:00083347v', 'with', 'the', 'bn:00046787n', ',', 'since', 'bn:00027565n', 'bn:00004222n', 'might', 'bn:00116360r', 'be', 'bn:00096153a', 'to', 'keep', 'a', 'bn:00052222n', 'down', '(', 'as', 'they', 'might', 'throw', 'the', 'bn:00105231a', 'bn:00052222n', 'up', 'bn:00114171r', ')', '.']
#
#
# ['for', 'bn:00035626n', 'bn:00042823n', ',', 'the', 'animal', 'bn:00059953n', 'can', 'bn:00082362v', 'the', 'bn:00075830n', 'to', 'the', 'bn:00015267n', '.']
# ['for', 'bn:00035627n', 'bn:00047235n', ',', 'the', 'animal', 'bn:00059954n', 'can', 'bn:00082365v', 'the', 'bn:00052222n', 'to', 'the', 'bn:00015267n', '.']
#
#
# ['bn:00114246r', ',', 'the', 'bn:00042823n', 'of', 'bn:00027565n', 'should', 'bn:00114626r', 'be', 'bn:00114766r', 'bn:00108011a', 'bn:00111492a', 'bn:00054019n', 'or', 'bn:00108011a', 'bn:00113583a', 'bn:00076843n', 'while', 'bn:00082332v', 'the', 'bn:00095360v', 'bn:00016850n', 'of', 'the', 'bn:00027565n', '.']
# ['bn:00114246r', ',', 'the', 'bn:00047235n', 'of', 'bn:00027565n', 'should', 'bn:00114234r', 'be', 'bn:00114766r', 'bn:00108011a', 'bn:00111492a', 'bn:00054018n', 'or', 'bn:00108011a', 'bn:00113583a', 'bn:00076843n', 'while', 'bn:00082336v', 'the', 'bn:00095360v', 'bn:00016850n', 'of', 'the', 'bn:00027565n', '.']
#
#
# ['what', 'be', 'the', 'bn:00030747n', 'bn:00082868v', 'with', 'cerenia', '?']
# ['what', 'be', 'the', 'bn:00030747n', 'bn:00082868v', 'with', 'cerenia', '?']
#
#
# ['cerenia', 'be', 'bn:00114634r', 'bn:00115530r', 'bn:00082138v', 'when', 'bn:00082362v', 'bn:00114917r', 'at', 'bn:00028319n', 'up', 'to', '5', 'bn:00019848n', 'the', 'bn:00082418v', 'bn:00028319n', 'for', 'a', 'bn:00101795a', 'bn:00061605n', '(', 'up', 'to', '3', 'bn:00019848n', 'the', 'recommend', 'bn:00106517a', 'bn:00022191n', 'of', 'bn:00042823n', ')', '.']
# ['cerenia', 'be', 'bn:00115495r', 'bn:00115530r', 'bn:00095008v', 'when', 'bn:00082365v', 'bn:00114917r', 'at', 'bn:00028320n', 'up', 'to', '5', 'bn:00019848n', 'the', 'bn:00082418v', 'bn:00028320n', 'for', 'a', 'bn:00101795a', 'bn:00061605n', '(', 'up', 'to', '3', 'bn:00019848n', 'the', 'recommend', 'bn:00106517a', 'bn:00022191n', 'of', 'bn:00047235n', ')', '.']
#
#
# ['what', 'be', 'the', 'bn:00042049n', 'for', 'the', 'bn:00046516n', 'who', 'bn:00082442v', 'the', 'bn:00054128n', 'or', 'bn:00085354v', 'bn:00022112n', 'with', 'the', 'bn:00004222n', '?']
# ['what', 'be', 'the', 'bn:00042049n', 'for', 'the', 'bn:00046516n', 'who', 'bn:00088826v', 'the', 'bn:00054128n', 'or', 'bn:00085354v', 'bn:00022113n', 'with', 'the', 'bn:00004222n', '?']
#
#
# ['cerenia', 'do', 'bn:00116360r', 'bn:00092837v', 'a', 'bn:00108295a', 'bn:00030747n', 'for', 'bn:00061450n', '.']
# ['cerenia', 'do', 'bn:00116360r', 'bn:00083187v', 'a', 'bn:00102398a', 'bn:00030747n', 'for', 'bn:00044382n', '.']

# %% [markdown]
# **- setting file addresses for reading data and writing new files**

# %% [markdown]
# **- function for parsing large xml file and getting needed data from that.**
