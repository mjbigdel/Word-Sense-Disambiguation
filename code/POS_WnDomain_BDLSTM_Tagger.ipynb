# %%
# !pip install tensorflow 
# TensorFlow and tf.keras
# its just working with tensorflow 1.13.1, with others has problem
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.14.0

# %% [markdown]
# **- goolge Colab Configuration**

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **- Setting root address to project in Google Drive**

# %%
# !ls "/content/gdrive/My Drive/NLPHW3"
root_path = '/content/gdrive/My Drive/NLPHW3'
# Out:
#  allWordsSensesembeddings.vec
#  BackUpCodes
# 'Basic BDLSTM '
#  BASIC_BDLSTM_Tagger.ipynb
#  Basic_Tagger_Prediction.ipynb
#  Data_Prepare_PKL_Format.ipynb
#  Evaluation_Datasets
# 'LEX BDLSTM'
#  LEX_BDLSTM_Tagger.ipynb
#  Lex_Tagger_Prediction.ipynb
#  Mask_LSTM_Model1.ipynb
#  MFS_Tagger.ipynb
# 'POS BDLSTM'
#  POS_BDLSTM_Tagger.ipynb
# 'POS_LEX BDLSTM'
#  POS_LEX_BDLSTM_models_48.75846501128668
#  POS_LEX_BDLSTM_Tagger.ipynb
#  POS_LEX_Tagger_Prediction.ipynb
# 'POS_LEX_WNDOMAIN BDLSTM '
#  POS_LEX_WnDomain_BDLSTM_Tagger.ipynb
#  POS_LEX_WnDomain_models_47.629796839729124
#  POS_LEX_WnDomain_Tagger_Prediction.ipynb
#  POS_Tagger_Prediction.ipynb
# 'POS_WNDOMAIN BDLSTM'
#  POS_WnDomain_BDLSTM_Tagger.ipynb
#  POS_WnDomain_SenseEmbed_models_48.53273137697517
#  POS_WnDomain_Tagger_Prediction.ipynb
#  resources
#  semcor
#  semcor+omsti
#  Training_Corpora
# 'WNDOMAIN BDLSTM'
#  WnDomain_BDLSTM_Tagger.ipynb
#  WnDomain_Tagger_Prediction.ipynb
#  WSD_Evaluation_Framework

# %%
# Imports
from collections import Counter
import codecs
import xml.etree.cElementTree as etree
import pickle
import nltk
nltk.download('wordnet')
import numpy as np
import copy
from nltk.corpus import wordnet as wn


# Added Chars to dictionaries
UNK = "<UNK>"
PAD = "<PAD>"


RESOURCE_PATH = root_path+'/resources/'

MAP_WN2BN_FILE = RESOURCE_PATH + 'babelnet2wordnet.tsv'
MAP_BN2WNDOMAIN_FILE = RESOURCE_PATH + 'babelnet2wndomains.tsv'
MAP_BN2LEXNAMES_FILE = RESOURCE_PATH + 'babelnet2lexnames.tsv'
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
all_dict_data = pickle.load(open(root_path+'/semcor/semcor/all_dict_data.pkl', "rb"))

RawWords2id = all_dict_data["RawWords2id"]
SenseWords2id = all_dict_data["SenseWords2id"] 
pos2id = all_dict_data["pos2id"] 
lex2id = all_dict_data["lex2id"] 
wnDomain2id = all_dict_data["wnDomain2id"]

print(len(pos2id))
print(len(SenseWords2id))
# Out:
# 12
# 60919

# %%
# ===-----------------------------------------------------------------------===
# Trainig Section
# ===-----------------------------------------------------------------------===

# function for add padding for train_y in every batch based on maximum length of sentence in that batch
# this method boost the performance of running.
def padding(X,padding_word):
	max_len = 0
	for x in X:
		if len(x) > max_len:
			max_len = len(x)
	padded_X = np.ones((len(X), max_len), dtype=np.int32) * padding_word
	for i in range(len(X)):
		for j in range(len(X[i])):
			padded_X[i, j] = X[i][j]
	return padded_X


# padding function for train_x
def padding3(X,padding_word):
	max_len = 0
	for x in X:
		if len(x) > max_len:
			max_len = len(x)
	padded_X = np.ones((len(X), max_len), dtype=np.int32) * padding_word
	for i in range(len(X)):
		for j in range(len(X[i])):
			padded_X[i, j] = X[i][j]
	return padded_X

# function for calculating umber of hits and number of all predictions.
def number_of_batch_hits(y_batch_pred,y_batch_true):
    num_hits = 0
    num_all_chars = 0    
    for i in range(len(y_batch_true)):
        for j in range(len(y_batch_true[i])):
            num_all_chars = num_all_chars+1
            if y_batch_pred[i][j] == y_batch_true[i][j]:
                num_hits = num_hits+1    
    return num_hits, num_all_chars

# function for calculating umber of hits and number of all predictions.
def number_of_batch_sense_hits(y_batch_pred,y_batch_true):
    num_hits = 0
    num_all_chars = 0    
    for i in range(len(y_batch_true)):
        for j in range(len(y_batch_true[i])):
            if id2Sensewords[y_batch_true[i][j]].startswith('bn'):
                num_all_chars = num_all_chars+1
                if y_batch_pred[i][j] == y_batch_true[i][j]:
                    num_hits = num_hits+1    
    return num_hits, num_all_chars

# ----------------- Add Summary Function ------------------------------------------
def add_summary(writer, name, value, global_step):
    summary = tf.Summary(value=[tf.Summary.Value(tag=name, simple_value=value)])
    writer.add_summary(summary, global_step=global_step)                                 
    

## ----------------------------------------------------------------------------
def mask_lemmaToSenses_batch(x_Raw_Sent_batch, y_allSenses_Sent_batch, y_allSenses_Sent_id_batch, SenseWords2id):
     
    max_len = 0    
    for inp in x_Raw_Sent_batch:
        if len(inp) > max_len:
            max_len = len(inp)
            
    mask_lemma2sense_batch = [0]*np.ones(shape = (len(x_Raw_Sent_batch), max_len, len(SenseWords2id)))
            
    for i in range(len(x_Raw_Sent_batch)):
        for j in range(len(x_Raw_Sent_batch[i])):
            for k in range(len(y_allSenses_Sent_batch[i][j])):            
#                 if SenseWords2id.get(y_allSenses_Sent_batch[i][j][k]) is not None:
                mask_lemma2sense_batch[i][j][y_allSenses_Sent_id_batch[i][j][k]] = 1    
#                    mask_lemma2sense_batch[rawWords_batch2id[x_Raw_Sent_batch[i][j]]][y_allSenses_Sent_id_batch[i][j][k]] = 1    
#                 else:
#                     print('not in dictionary sense is : ', y_allSenses_Sent_batch[i][j][k])
            
    return mask_lemma2sense_batch    

#x_Raw_Sent_batch = x_Raw_Sent[:12]
#y_allSenses_Sent_batch = y_allSenses_Sent[:12]
#y_allSenses_Sent_id_batch = y_allSenses_Sent_id[:12]
#
#mask_lemma2sense_batch = mask_lemmaToSenses_batch(x_Raw_Sent_batch, y_allSenses_Sent_batch, y_allSenses_Sent_id_batch, SenseWords2id)    

# use pretrained embeddings function, for chars we are using pretrain file and for bigram, trigram 
# and fourgram we are using mean of embeddings of all unigrams of them
def reading_pretrained_sense_embeddings(filename, RawWords2id):
    # Reading Pretrained Embeddings from file
    pretrain_embeddigs = {}
    with codecs.open(filename, "r", "utf-8") as f:
        for line in f:
            pre_train = line.split()
            if len(pre_train) > 2:
                word = pre_train[0]
                if word in RawWords2id:
                    vec = pre_train[1:]
                    pretrain_embeddigs[word] = vec                
    
    print("pretrained embeddings files reading finished ...")
    # making embeddings for all RawWords2id.
    embedding_dim = len(next(iter(pretrain_embeddigs.values())))
    out_of_vocab = 0
    out = np.ones((len(RawWords2id), embedding_dim))*0.001
    for word in RawWords2id.keys():
        if len(word) == 1:
            if word in pretrain_embeddigs.keys():        
                out[RawWords2id[word]]=np.array(pretrain_embeddigs[word])
            else:                
                out_of_vocab+=1
                np.random.uniform(-1.0, 1.0, embedding_dim)
        
    return out,out_of_vocab

# %%
PAD_ID = RawWords2id[PAD]
id2Sensewords = dict(zip(SenseWords2id.values(), SenseWords2id.keys()))

sense_embeddings, out_of_vocab = reading_pretrained_sense_embeddings(root_path + '/allWordsSensesembeddings.vec', RawWords2id)
print('sense_embeddings: ', len(sense_embeddings))
print('out_of_vocab: ', out_of_vocab)

# we are using pretrained embedding - len(words2id)
VOCAB_SIZE =  len(RawWords2id)
WORD_EMBEDDING_DIM = 100
print('WORD_EMBEDDING_DIM: ', WORD_EMBEDDING_DIM)
print('VOCAB_SIZE: ', VOCAB_SIZE)

# some Basic Hyper parameters
NUM_EPOCHS = 5
BATCH_SIZE = 4
HIDDEN_LAYER_DIM = 256
LEARNING_RATE = 1
NUM_CLASSES = len(SenseWords2id)
print('num sense classes: ', NUM_CLASSES)
L2_REGU_LAMBDA=0.0001
NUM_LAYERS = 2
CLIP=10
crf_lambda = 0.05
num_sense_pos = len(pos2id)
print('num_sense_pos: ', num_sense_pos)
num_sense_lex = len(lex2id)
print('num_sense_lex: ', num_sense_lex)
num_sense_wnDomain = len(wnDomain2id)
print('num_sense_wnDomain: ', num_sense_wnDomain)
VERY_BIG_NUMBER = 1e30


summaries = []
# Out:
# pretrained embeddings files reading finished ...
# sense_embeddings:  32893
# out_of_vocab:  5
# WORD_EMBEDDING_DIM:  100
# VOCAB_SIZE:  32893
# num sense classes:  60919
# num_sense_pos:  12
# num_sense_lex:  46
# num_sense_wnDomain:  160

# %%
# --------------------- Tensorflow part ---------------------------------------------------
import tensorflow as tf
from tensorflow.contrib import layers
from tensorflow.contrib import crf

def create_tensorflow_model(vocab_size, embedding_dim, hidden_layer_dim, sense_embed_bool = False, total_loss = 0):
    print("Creating TENSORFLOW model")
     
    # Inputs have (batch_size, timesteps) shape.
    input_ = tf.placeholder(dtype = tf.int32, shape=[None, None], name='input_x')   
    # Labels have (batch_size,) shape.
    labels = tf.placeholder(dtype = tf.int32, shape=[None, None], name='labels_BN')
    
    y_pos = tf.placeholder(dtype = tf.int32, shape=[None, None], name='pos_tag')
        
    y_wnDomain = tf.placeholder(dtype = tf.int32, shape=[None, None],name='wnDomain_tag')        
    
    # dropout_keep_prob is a scalar.
    dropout_keep_prob = tf.placeholder(dtype = tf.float32, name='dropout_keep_prob')
    
    seq_length = tf.reduce_sum(tf.cast( tf.not_equal(input_[:,:], tf.ones_like(input_[:,:] ) * PAD_ID ), tf.int32), 1)    
    print('seq_length: ', seq_length)
    
    max_sent_size = tf.size(input_[0,:])    
    print('max_sent_size: ', max_sent_size)
    
    batch_size = tf.size(input_[:,0])    
    print('batch_size: ', batch_size)
            
    mask_RawTosense_batch = tf.placeholder(dtype = tf.bool, shape=[None, None, None], name='mask_Raw2Senses')    
    print('mask_RawTosense_batch: ', mask_RawTosense_batch)
    
    mask_pos2sense = tf.placeholder(dtype = tf.bool, shape=[None, None], name='mask_Raw2Senses')    
    print('mask_pos2sense: ', mask_pos2sense)
    mask_matrix_pos = tf.tile(tf.expand_dims(mask_pos2sense, 0), [batch_size, 1, 1])     
    print('mask_matrix_pos: ', mask_matrix_pos)
    
    mask_wnDomain2sense = tf.placeholder(dtype = tf.bool, shape=[None, None], name='mask_Raw2Senses')    
    print('mask_wnDomain2sense: ', mask_wnDomain2sense)
    mask_matrix_wnDomain = tf.tile(tf.expand_dims(mask_wnDomain2sense, 0), [batch_size, 1, 1])     
    print('mask_matrix_wnDomain: ', mask_matrix_wnDomain)
    
    x_mask = tf.not_equal(input_[:,:], tf.ones_like(input_[:,:] ) * PAD_ID )    
    print('x_mask: ', x_mask)
    
    attention_mask = (tf.cast(x_mask, 'float') -1) * VERY_BIG_NUMBER     
    print('attention_mask: ', attention_mask)

    # initialize weights randomly from a Gaussian distribution
    weight_initer = tf.truncated_normal_initializer(mean=0.0, stddev=0.01)
            
## ---------------------------- embedding Block --------------------------------------------
## -----------------------------------------------------------------------------------------  
    # if the sense_embed_bool is True we are using pre trained sense embedding as embedding layer
    with tf.variable_scope('embeddings', reuse=tf.AUTO_REUSE):
        if sense_embed_bool:
            embedding_matrix = tf.Variable(sense_embeddings, dtype=tf.float32, name='embedding')
        else:
            embedding_matrix = tf.get_variable("embeddings", shape=[vocab_size, embedding_dim])
        
        embeddings = tf.nn.embedding_lookup(embedding_matrix, input_)        
        print('embeddings: ', embeddings)
        
        embeddings = tf.reshape(embeddings,[batch_size, max_sent_size, embedding_dim]) #         
        print('embeddings: ', embeddings)

        embeddings=tf.nn.dropout(tf.cast(embeddings, tf.float32), dropout_keep_prob) #     embeddings shape (batch size, sentence length with padding, 100) 

        print ('embeddings is ok \n')
                
    
## --------------------------- POS Block ---------------------------------------------------
## -----------------------------------------------------------------------------------------  
    with tf.variable_scope('rnn_cell_pos', reuse=tf.AUTO_REUSE):
            print ('lstm_cell_pos is is ok ... ')
            def lstm_cell1():
                return tf.nn.rnn_cell.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(hidden_layer_dim), output_keep_prob=dropout_keep_prob)

            stacked_fw_lstm_pos = tf.nn.rnn_cell.MultiRNNCell(
                [lstm_cell1() for _ in range(NUM_LAYERS)])

            stacked_bw_lstm_pos = tf.nn.rnn_cell.MultiRNNCell(
                [lstm_cell1() for _ in range(NUM_LAYERS)])

    with tf.variable_scope('rnn_pos', reuse=tf.AUTO_REUSE):                        
        (forward_output_pos, backword_output_pos), _ = tf.nn.bidirectional_dynamic_rnn(
            cell_fw = stacked_fw_lstm_pos,
            cell_bw = stacked_bw_lstm_pos,
            inputs = embeddings,
            sequence_length = seq_length,
            dtype=tf.float32
        )                        
        outputBD_pos = tf.concat([forward_output_pos, backword_output_pos], axis=2)
        print('outputBD_pos: ', outputBD_pos) # shape is batch*max_len*(2*hidden_layer_size)                         

        print ('outputBD_pos is ok \n')

    with tf.variable_scope("softmax_layer_pos", reuse=tf.AUTO_REUSE):
        W_pos = tf.get_variable("W_pos", shape=[2*hidden_layer_dim, num_sense_pos], initializer = weight_initer)
        b_pos = tf.get_variable("b_pos", shape=[num_sense_pos], initializer=tf.zeros_initializer())

        flat_softmax_pos = tf.reshape(outputBD_pos, [-1, tf.shape(outputBD_pos)[2]]) # shape is (batch*max_len)*(2*hidden_layer_size)
        print('flat_softmax_pos: ', flat_softmax_pos)

        drop_flat_softmax_pos = tf.nn.dropout(flat_softmax_pos, dropout_keep_prob) # shape is (batch*max_len)*(2*hidden_layer_size)
        print('drop_flat_softmax_pos: ', drop_flat_softmax_pos)

        flat_pos_logits = tf.matmul(drop_flat_softmax_pos, W_pos) + b_pos # shape is (batch*max_len)*num_sense_pos
        print('flat_pos_logits: ', flat_pos_logits)

        pos_logits = tf.reshape(flat_pos_logits, [batch_size, max_sent_size, num_sense_pos]) # shape is batch*max_len*num_sense_pos ->3D
        print('pos_logits: ', pos_logits)

        predict_pos = tf.argmax(pos_logits , axis=2)

        loss_pos = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels= y_pos, logits= pos_logits))

        total_loss = total_loss + loss_pos
        
#         we are adding pos mask to filter possible results for candidate synsets for our Sense logit probabilities
        float_mask_matrix_pos = tf.cast(mask_matrix_pos, dtype=tf.float32)
        print('float_mask_matrix_pos: ', float_mask_matrix_pos)

        pos_masked_senses = tf.matmul(pos_logits, float_mask_matrix_pos) #mask_mat = 2*11*56 or batch*pos_num*NUM_CLASSES
        print('pos_masked_senses: ', pos_masked_senses)  # size is: batch*max_len*NUM_CLASSES

        print ('softmax_layer_pos is ok \n')


## --------------------------- wnDomain Block ------------------------------------------------
## -------------------------------------------------------------------------------------------
    with tf.variable_scope('rnn_cell_wnDomain', reuse=tf.AUTO_REUSE):
        print ('lstm_cell_wnDomain is is ok ... ')
        def lstm_cell1():
            return tf.nn.rnn_cell.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(hidden_layer_dim), output_keep_prob=dropout_keep_prob)

        stacked_fw_lstm_wnDomain = tf.nn.rnn_cell.MultiRNNCell(
            [lstm_cell1() for _ in range(NUM_LAYERS)])

        stacked_bw_lstm_wnDomain = tf.nn.rnn_cell.MultiRNNCell(
        [lstm_cell1() for _ in range(NUM_LAYERS)])
    
    with tf.variable_scope('rnn_wnDomain', reuse=tf.AUTO_REUSE):                        
        # we are feeding the output of POS LSTM to WnDomain LSTM to make our LSTM's on top of each other to possible better results.
            (forward_output_wnDomain, backword_output_wnDomain), _ = tf.nn.bidirectional_dynamic_rnn(
                cell_fw = stacked_fw_lstm_wnDomain,
                cell_bw = stacked_bw_lstm_wnDomain,
                inputs = outputBD_pos,
                sequence_length = seq_length,
                dtype=tf.float32
            )

            outputBD_wnDomain = tf.concat([forward_output_wnDomain, backword_output_wnDomain], axis=2)
            print('outputBD_wnDomain: ', outputBD_wnDomain) # shape is batch*max_len*(2*hidden_layer_size) 

            print ('outputBD_wnDomain is ok \n')         

    with tf.variable_scope("softmax_layer_wnDomain", reuse=tf.AUTO_REUSE):
        W_wnDomain = tf.get_variable("W_wnDomain", shape=[2*hidden_layer_dim, num_sense_wnDomain], initializer = weight_initer)
        b_wnDomain = tf.get_variable("b_wnDomain", shape=[num_sense_wnDomain], initializer=tf.zeros_initializer())

        flat_softmax_wnDomain = tf.reshape(outputBD_wnDomain, [-1, tf.shape(outputBD_wnDomain)[2]]) # shape is (batch*max_len)*(2*hidden_layer_size)
        print('flat_softmax_wnDomain: ', flat_softmax_wnDomain)

        drop_flat_softmax_wnDomain = tf.nn.dropout(flat_softmax_wnDomain, dropout_keep_prob) # shape is (batch*max_len)*(2*hidden_layer_size)
        print('drop_flat_softmax_wnDomain: ', drop_flat_softmax_wnDomain)

        flat_wnDomain_logits = tf.matmul(drop_flat_softmax_wnDomain, W_wnDomain) + b_wnDomain # shape is (batch*max_len)*num_sense_lex
        print('flat_wnDomain_logits: ', flat_wnDomain_logits)

        wnDomain_logits = tf.reshape(flat_wnDomain_logits, [batch_size, max_sent_size, num_sense_wnDomain]) # shape is batch*max_len*num_sense_lex ->3D
        print('wnDomain_logits: ', wnDomain_logits)

        predict_wnDomain = tf.argmax(wnDomain_logits , axis=2)

        loss_wnDomain = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels= y_wnDomain, logits= wnDomain_logits))
        total_loss = total_loss + loss_wnDomain

        float_mask_matrix_wnDomain = tf.cast(mask_matrix_wnDomain, dtype=tf.float32)
        print('float_mask_matrix_wnDomain: ', float_mask_matrix_wnDomain)
#         we are adding pos mask to filter possible results for candidate synsets for our Sense logit probabilities
        wnDomain_masked_senses = tf.matmul(wnDomain_logits, float_mask_matrix_wnDomain) #mask_mat = 2*11*56 or batch*lex_num*NUM_CLASSES
        print('wnDomain_masked_senses: ', wnDomain_masked_senses)  # size is: batch*max_len*NUM_CLASSES

        print ('softmax_layer_wnDomain is ok \n')                         

    input_rnn_sense = outputBD_wnDomain

        
## --------------------------- SENSE Block ------------------------------------------------   
## ----------------------------------------------------------------------------------------   
    with tf.variable_scope('rnn_cell_sense', reuse=tf.AUTO_REUSE):
            print ('lstm_sense is ok')
            def lstm_cell():
                return tf.nn.rnn_cell.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(hidden_layer_dim), output_keep_prob=dropout_keep_prob)
        
            stacked_fw_lstm_Sense = tf.nn.rnn_cell.MultiRNNCell(
                [lstm_cell() for _ in range(NUM_LAYERS)])
            
            stacked_bw_lstm_Sense = tf.nn.rnn_cell.MultiRNNCell(
                [lstm_cell() for _ in range(NUM_LAYERS)])
            
    with tf.variable_scope('rnn_sense', reuse=tf.AUTO_REUSE):   
        # we are feeding the output of WnDomain LSTM to Sense LSTM to make our LSTM's on top of each other to possible better results.
            (forward_output_Sense, backword_output_Sense), _ = tf.nn.bidirectional_dynamic_rnn(
                cell_fw = stacked_fw_lstm_Sense,
                cell_bw = stacked_bw_lstm_Sense,
                inputs = input_rnn_sense,
                sequence_length = seq_length,
                dtype=tf.float32
            )
            
            outputBD_Sense = tf.concat([forward_output_Sense, backword_output_Sense], axis=2)            
            print('outputBD_Sense: ', outputBD_Sense) # shape is batch*max_len*(2*hidden_layer_size) 
            
            print ('outputBD_Sense is ok \n')   

            
## --------------------------- attention_layer --------------------------------------------------
    with tf.variable_scope("attention_layer", reuse=tf.AUTO_REUSE):
#         this is attention layer we implement this like the one that proposed in reference paper: Raganato and Navigli
        W_attention_L = tf.get_variable("W_attention_L", shape=[2*hidden_layer_dim, 1], initializer = weight_initer )
        flat_outputBD_Sense = tf.reshape(outputBD_Sense, [batch_size*max_sent_size, tf.shape(outputBD_Sense)[2]])        
        print('flat_outputBD_Sense: ', flat_outputBD_Sense) # shape is  shape is (batch*max_length*(2*hidden_layer_size)).(51(2*hidden_layer_size)2*1) = (batch*max_length)*1 ->2D
        
        flat_outputBD_Sense_tanh = tf.tanh(flat_outputBD_Sense)
        
        u_flat_outputBD_Sense_tanh = tf.matmul(flat_outputBD_Sense_tanh, W_attention_L) # shape is batch*max_length -> 2D
        print('u_flat: ', u_flat_outputBD_Sense_tanh)
        
        u = tf.reshape(u_flat_outputBD_Sense_tanh, [batch_size, max_sent_size]) + attention_mask #
        print('u: ', u)
        
        u_softmax = tf.nn.softmax(u, 1)
        
        a = tf.expand_dims(u_softmax, 2) # shape is expand to batch*max_len*1 -> 3D
        print('a: ', a)
        
        c = tf.reduce_sum(tf.multiply(outputBD_Sense, a), axis=1) # shape is batch*max_len*(2*hidden_layer_size) and then reduce_sum with axis 1 to: batch*(2*hidden_layer_size)
        print('c: ', c)
        
        tiled_c = tf.tile(tf.expand_dims(c, 1), [1, max_sent_size, 1]) # shape is batch*max_len*(2*hidden_layer_size)
        print('tiled_c: ', tiled_c)
        
        attention_output = tf.concat([tiled_c, outputBD_Sense], 2) # batch*max_len*(2*hidden_layer_size) "concat with" batch*max_len*(2*hidden_layer_size) -> batch*max_len*(4*hidden_layer_size)
        print('attention_output: ', attention_output)
        
        flat_attention_output = tf.reshape(attention_output, [batch_size*max_sent_size, tf.shape(attention_output)[2]]) # reshape to (batch*max_len)*(4*hidden_layer_size) -> 2D
        print('flat_attention_output: ', flat_attention_output)

        print ('global_attention is ok \n') 
        
## --------------------------- hidden_layer Sense ------------------------------------------------------------
#     hidden layer to change attention layer output to better format to feed in Softmax layer
    with tf.variable_scope("hidden_layer", reuse=tf.AUTO_REUSE):
        W = tf.get_variable("W", shape=[4*hidden_layer_dim, 2*hidden_layer_dim], initializer = weight_initer)
        b = tf.get_variable("b", shape=[2*hidden_layer_dim], initializer = tf.zeros_initializer())
        
        drop_flat_attention_output = tf.nn.dropout(flat_attention_output, dropout_keep_prob) # shape is (batch*max_len)*(4*hidden_layer_size) -> 2D
        print('drop_flat_attention_output: ', drop_flat_attention_output)
        
        hidden_layer_output = tf.matmul(drop_flat_attention_output, W) + b  # shape is (batch*max_len)*(2*hidden_layer_size) -> 2D
        print('hidden_layer_output: ', hidden_layer_output)
                
        print ('hidden_layer is ok \n') 
        
## --------------------------- softmax_layer Sense ------------------------------------------------------------
# we are defined the weights and bias and apply our masking of WnDomain and POS to our sense logits, then we applied the
# candidate synsets mask that we extract from Wordnet to make our prediction just among Synsets of the target word.
    with tf.variable_scope("softmax_layer", reuse=tf.AUTO_REUSE):
        W_sense = tf.get_variable("W_sense", shape=[2*hidden_layer_dim, NUM_CLASSES], initializer = weight_initer)
        b_sense = tf.get_variable("b_sense", shape=[NUM_CLASSES], initializer=tf.zeros_initializer())
        
        drop_hidden_layer_output = tf.nn.dropout(hidden_layer_output, dropout_keep_prob)
        print('drop_hidden_layer_output: ', drop_hidden_layer_output)
        
        flat_sense_logits = tf.matmul(drop_hidden_layer_output, W_sense) + b_sense
        print('flat_sense_logits: ', flat_sense_logits)
        
        sense_logits = tf.reshape(flat_sense_logits, [batch_size, max_sent_size, NUM_CLASSES])
        print('sense_logits: ', sense_logits)
        
#         WnDomain and POS masking applied
        masked_sense_logits = tf.multiply(sense_logits, tf.multiply(pos_masked_senses, wnDomain_masked_senses))
        print('masked_sense_logits: ', masked_sense_logits)  

#         Candydate synsets masking applied       
        float_mask_RawTosense_batch = tf.cast(mask_RawTosense_batch, dtype=tf.float32)
        print('float_mask_RawTosense_batch: ', float_mask_RawTosense_batch)
        
        final_sense_logits = tf.multiply(masked_sense_logits, float_mask_RawTosense_batch)
        print('final_sense_logits: ', final_sense_logits)

        predictions = tf.argmax(final_sense_logits , axis=2)
        print('predictions: ', predictions)
        loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels= labels, logits= final_sense_logits))
        total_loss = total_loss + loss
        print ('softmax_layer is ok \n')
        
              
## --------------------------- train_op Block ----------------------------------------------
## -----------------------------------------------------------------------------------------          
    with tf.variable_scope('train_op', reuse=tf.AUTO_REUSE):
        # we used optimizer like referenced paper                
        optimizer = tf.train.AdadeltaOptimizer(LEARNING_RATE)
        print ('AdamOptimizer is ok .... \n')
        
        tvars=tf.trainable_variables()
        print ('tvars is ok ....')
    
        l2_loss = tf.add_n([tf.nn.l2_loss(v) for v in tvars if v.get_shape().ndims > 1])
        print ('l2_loss is ok ....')
        
        total_loss = total_loss + L2_REGU_LAMBDA*l2_loss             
        print ('total_loss is ok ....')
        
        summaries.append(tf.summary.scalar("loss", loss))
        summaries.append(tf.summary.scalar("total_loss", total_loss))
        
        grads,_ = tf.clip_by_global_norm(tf.gradients(total_loss,tvars),CLIP)
        print ('grads is ok ....')
        
        train_op = optimizer.apply_gradients(zip(grads,tvars))
        print ('train_op apply_gradients is ok ....')
                               
    return input_, labels, y_pos, y_wnDomain, mask_RawTosense_batch, train_op, predictions, dropout_keep_prob, total_loss, seq_length, mask_pos2sense, mask_wnDomain2sense

# %%
# create tensorflow model without sense embedding and just basic LSTM
input_, labels, y_pos, y_wnDomain, mask_RawTosense_batch, train_op, predictions, dropout_keep_prob, total_loss, seq_length,\
    mask_pos2sense, mask_wnDomain2sense = create_tensorflow_model(VOCAB_SIZE, WORD_EMBEDDING_DIM, HIDDEN_LAYER_DIM, sense_embed_bool = True, total_loss = 0)
# Out:
# Creating TENSORFLOW model
# seq_length:  Tensor("Sum:0", shape=(?,), dtype=int32)
# max_sent_size:  Tensor("Size:0", shape=(), dtype=int32)
# batch_size:  Tensor("Size_1:0", shape=(), dtype=int32)
# mask_RawTosense_batch:  Tensor("mask_Raw2Senses:0", shape=(?, ?, ?), dtype=bool)
# mask_pos2sense:  Tensor("mask_Raw2Senses_1:0", shape=(?, ?), dtype=bool)
# mask_matrix_pos:  Tensor("Tile:0", shape=(?, ?, ?), dtype=bool)
# mask_wnDomain2sense:  Tensor("mask_Raw2Senses_2:0", shape=(?, ?), dtype=bool)
# mask_matrix_wnDomain:  Tensor("Tile_1:0", shape=(?, ?, ?), dtype=bool)
# x_mask:  Tensor("NotEqual_1:0", shape=(?, ?), dtype=bool)
# attention_mask:  Tensor("mul_2:0", shape=(?, ?), dtype=float32)
# embeddings:  Tensor("embeddings/embedding_lookup/Identity:0", shape=(?, ?, 100), dtype=float32)
# embeddings:  Tensor("embeddings/Reshape:0", shape=(?, ?, 100), dtype=float32)
# WARNING:tensorflow:From <ipython-input-7-dc51ab3270a8>:65: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# embeddings is ok
#
# lstm_cell_pos is is ok ...
# WARNING:tensorflow:From <ipython-input-7-dc51ab3270a8>:75: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-7-dc51ab3270a8>:78: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-7-dc51ab3270a8>:89: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn_cell_impl.py:961: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:244: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# outputBD_pos:  Tensor("rnn_pos/concat:0", shape=(?, ?, 512), dtype=float32)
# outputBD_pos is ok
#
# flat_softmax_pos:  Tensor("softmax_layer_pos/Reshape:0", shape=(?, ?), dtype=float32)
# drop_flat_softmax_pos:  Tensor("softmax_layer_pos/dropout/mul_1:0", shape=(?, ?), dtype=float32)
# flat_pos_logits:  Tensor("softmax_layer_pos/add:0", shape=(?, 12), dtype=float32)
# pos_logits:  Tensor("softmax_layer_pos/Reshape_1:0", shape=(?, ?, 12), dtype=float32)
# float_mask_matrix_pos:  Tensor("softmax_layer_pos/Cast:0", shape=(?, ?, ?), dtype=float32)
# pos_masked_senses:  Tensor("softmax_layer_pos/MatMul_1:0", shape=(?, ?, ?), dtype=float32)
# softmax_layer_pos is ok
#
# lstm_cell_wnDomain is is ok ...
# outputBD_wnDomain:  Tensor("rnn_wnDomain/concat:0", shape=(?, ?, 512), dtype=float32)
# outputBD_wnDomain is ok
#
# flat_softmax_wnDomain:  Tensor("softmax_layer_wnDomain/Reshape:0", shape=(?, ?), dtype=float32)
# drop_flat_softmax_wnDomain:  Tensor("softmax_layer_wnDomain/dropout/mul_1:0", shape=(?, ?), dtype=float32)
# flat_wnDomain_logits:  Tensor("softmax_layer_wnDomain/add:0", shape=(?, 160), dtype=float32)
# wnDomain_logits:  Tensor("softmax_layer_wnDomain/Reshape_1:0", shape=(?, ?, 160), dtype=float32)
# float_mask_matrix_wnDomain:  Tensor("softmax_layer_wnDomain/Cast:0", shape=(?, ?, ?), dtype=float32)
# wnDomain_masked_senses:  Tensor("softmax_layer_wnDomain/MatMul_1:0", shape=(?, ?, ?), dtype=float32)
# softmax_layer_wnDomain is ok
#
# lstm_sense is ok
# outputBD_Sense:  Tensor("rnn_sense/concat:0", shape=(?, ?, 512), dtype=float32)
# outputBD_Sense is ok
#
# flat_outputBD_Sense:  Tensor("attention_layer/Reshape:0", shape=(?, ?), dtype=float32)
# u_flat:  Tensor("attention_layer/MatMul:0", shape=(?, 1), dtype=float32)
# u:  Tensor("attention_layer/add:0", shape=(?, ?), dtype=float32)
# a:  Tensor("attention_layer/ExpandDims:0", shape=(?, ?, 1), dtype=float32)
# c:  Tensor("attention_layer/Sum:0", shape=(?, 512), dtype=float32)
# tiled_c:  Tensor("attention_layer/Tile:0", shape=(?, ?, 512), dtype=float32)
# attention_output:  Tensor("attention_layer/concat:0", shape=(?, ?, 1024), dtype=float32)
# flat_attention_output:  Tensor("attention_layer/Reshape_2:0", shape=(?, ?), dtype=float32)
# global_attention is ok
#
# drop_flat_attention_output:  Tensor("hidden_layer/dropout/mul_1:0", shape=(?, ?), dtype=float32)
# hidden_layer_output:  Tensor("hidden_layer/add:0", shape=(?, 512), dtype=float32)
# hidden_layer is ok
#
# drop_hidden_layer_output:  Tensor("softmax_layer/dropout/mul_1:0", shape=(?, 512), dtype=float32)
# flat_sense_logits:  Tensor("softmax_layer/add:0", shape=(?, 60919), dtype=float32)
# sense_logits:  Tensor("softmax_layer/Reshape:0", shape=(?, ?, 60919), dtype=float32)
# masked_sense_logits:  Tensor("softmax_layer/Mul_1:0", shape=(?, ?, 60919), dtype=float32)
# float_mask_RawTosense_batch:  Tensor("softmax_layer/Cast:0", shape=(?, ?, ?), dtype=float32)
# final_sense_logits:  Tensor("softmax_layer/Mul_2:0", shape=(?, ?, 60919), dtype=float32)
# predictions:  Tensor("softmax_layer/ArgMax:0", shape=(?, ?), dtype=int64)
# softmax_layer is ok
#
# AdamOptimizer is ok ....
#
# tvars is ok ....
# l2_loss is ok ....
# total_loss is ok ....
# grads is ok ....
# train_op apply_gradients is ok ....

# %%
# subset_train = 50 # Put number of subset data you want for train
# subset_dev= 50
# subset_test= 50


train_path =  root_path + '/semcor/semcor/'
dev_path = root_path + '/semcor/semeval2007/'
test_path = root_path + '/semcor/semeval2013/'


x_train_Raw_Sent_id = pickle.load(open(train_path + 'x_Raw_Sent_id.pkl', "rb"))
y_train_BNsense_Sent_id = pickle.load(open(train_path + 'y_BNsense_Sent_id.pkl', "rb"))
y_train_POS_Sent_id = pickle.load(open(train_path + 'y_POS_Sent_id.pkl', "rb"))
y_train_WnDomain_Sent_id = pickle.load(open(train_path + 'y_WnDomain_Sent_id.pkl', "rb"))
y_train_allSenses_Sent = pickle.load(open(train_path + 'y_allSenses_Sent.pkl', "rb"))
y_train_allSenses_Sent_id = pickle.load(open(train_path + 'y_allSenses_Sent_id.pkl', "rb"))

mask_train_wnDomain2sense = pickle.load(open(train_path + 'mask_wnDomain2sense.pkl', "rb"))
mask_train_pos2sense = pickle.load(open(train_path + 'mask_pos2sense.pkl', "rb"))

# x_train_Raw_Sent_id = x_train_Raw_Sent_id[slice(0, subset_train)]
# y_train_BNsense_Sent_id = y_train_BNsense_Sent_id[slice(0, subset_train)]  
# y_train_POS_Sent_id = y_train_POS_Sent_id[slice(0, subset_train)]
# y_train_WnDomain_Sent_id = y_train_WnDomain_Sent_id[slice(0, subset_train)]
# y_train_allSenses_Sent = y_train_allSenses_Sent[slice(0, subset_train)]
# y_train_allSenses_Sent_id = y_train_allSenses_Sent_id[slice(0, subset_train)]

print(len(x_train_Raw_Sent_id))
print(len(x_train_Raw_Sent_id[0]))
print(len(y_train_BNsense_Sent_id[0]))

print('train data is ok ......... ')

x_dev_Raw_Sent = pickle.load(open(dev_path + 'x_Raw_Sent.pkl', "rb"))
x_dev_Raw_Sent_id = pickle.load(open(dev_path + 'x_Raw_Sent_id.pkl', "rb"))
y_dev_BNsense_Sent_id = pickle.load(open(dev_path + 'y_BNsense_Sent_id.pkl', "rb"))
y_dev_POS_Sent_id = pickle.load(open(dev_path + 'y_POS_Sent_id.pkl', "rb"))
y_dev_WnDomain_Sent_id = pickle.load(open(dev_path + 'y_WnDomain_Sent_id.pkl', "rb"))
y_dev_allSenses_Sent = pickle.load(open(dev_path + 'y_allSenses_Sent.pkl', "rb"))
y_dev_allSenses_Sent_id = pickle.load(open(dev_path + 'y_allSenses_Sent_id.pkl', "rb"))

mask_dev_wnDomain2sense = pickle.load(open(dev_path + 'mask_wnDomain2sense.pkl', "rb"))
mask_dev_pos2sense = pickle.load(open(dev_path + 'mask_pos2sense.pkl', "rb"))
 
# x_dev_Raw_Sent_id = x_dev_Raw_Sent_id[slice(0, subset_dev)]
# y_dev_BNsense_Sent_id = y_dev_BNsense_Sent_id[slice(0, subset_dev)]  
# y_dev_POS_Sent_id = y_dev_POS_Sent_id[slice(0, subset_dev)]
# y_dev_WnDomain_Sent_id = y_dev_WnDomain_Sent_id[slice(0, subset_dev)]
# y_dev_allSenses_Sent = y_dev_allSenses_Sent[slice(0, subset_dev)]
# y_dev_allSenses_Sent_id = y_dev_allSenses_Sent_id[slice(0, subset_dev)]

print(len(x_dev_Raw_Sent_id))
print(len(x_dev_Raw_Sent_id[0]))
print(len(y_dev_BNsense_Sent_id[0]))

print('dev data is ok ......... ')

x_test_Raw_Sent = pickle.load(open(test_path + 'x_Raw_Sent.pkl', "rb"))
x_test_Raw_Sent_id = pickle.load(open(test_path + 'x_Raw_Sent_id.pkl', "rb"))
y_test_BNsense_Sent_id = pickle.load(open(test_path + 'y_BNsense_Sent_id.pkl', "rb"))
y_test_POS_Sent_id = pickle.load(open(test_path + 'y_POS_Sent_id.pkl', "rb"))
y_test_allSenses_Sent = pickle.load(open(test_path + 'y_allSenses_Sent.pkl', "rb"))
y_test_allSenses_Sent_id = pickle.load(open(test_path + 'y_allSenses_Sent_id.pkl', "rb"))

mask_test_wnDomain2sense = pickle.load(open(test_path + 'mask_wnDomain2sense.pkl', "rb"))
mask_test_pos2sense = pickle.load(open(test_path + 'mask_pos2sense.pkl', "rb"))
 
    
# x_test_Raw_Sent_id = x_test_Raw_Sent_id[slice(0, subset_test)]
# y_test_BNsense_Sent_id = y_test_BNsense_Sent_id[slice(0, subset_test)]  
# y_test_POS_Sent_id = y_test_POS_Sent_id[slice(0, subset_test)]
# y_test_allSenses_Sent = y_test_allSenses_Sent[slice(0, subset_test)]
# y_test_allSenses_Sent_id = y_test_allSenses_Sent_id[slice(0, subset_test)]

print(len(x_test_Raw_Sent_id))
print(len(x_test_Raw_Sent_id[0]))
print(len(y_test_BNsense_Sent_id[0]))

print('test data is ok ......... ')
# Out:
# 37176
# 17
# 17
# train data is ok .........
# 135
# 36
# 36
# dev data is ok .........
# 306
# 7
# 7
# test data is ok .........

# %%
SUBSET_MODEL_ADD = root_path+'/POS_WnDomain_SenseEmbed_models_48.53273137697517/.'
print(SUBSET_MODEL_ADD)
# Out:
# /content/gdrive/My Drive/NLPHW3/POS_WnDomain_SenseEmbed_models_48.53273137697517/.

# %%
# -----------------------------------------------------------------------------
def WN_to_BN_dic(mapping_file):
    print('WN_to_BN_dic is started ....')
    BN_ID = []
    WN_ID = []
    with codecs.open(mapping_file,'rb') as f:        
        for line in f:            
            line_synsets = line.decode().strip().split('\t')
            BN_ID.append(line_synsets[0])
            WN_ID.append(line_synsets[1])    
    WN2BN_map_dic = dict(zip(WN_ID,BN_ID))
    print('WN_to_BN_dic is done ....')

    return WN2BN_map_dic


WN2BN_map_dic = WN_to_BN_dic(MAP_WN2BN_FILE)
print(len(WN2BN_map_dic))

## ----------------------------------------------------------------------------
# function to return MFS based on WordNet in Babelnet Id format
def getMFS_(word, WN2BN_map_dic):
#     print('no prediction for: ', word)
    all_synsets = wn.synsets(word)

    # check if the word has synsets or not!
    if len(all_synsets) == 0 or all_synsets is None:
        return word
    
    synset = all_synsets[0]
    MFS_wnId = "wn:" + str(synset.offset()).zfill( 8) + synset.pos()
    if WN2BN_map_dic.get(MFS_wnId) is not None:
        MFS_bnId = WN2BN_map_dic.get(MFS_wnId)
        
    return MFS_bnId
# Out:
# WN_to_BN_dic is started ....
# WN_to_BN_dic is done ....
# 117659

# %%
# Run tensorflow model
saver = tf.train.Saver()


with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess: 
    # I couln't use tensorboard because it causes my colab session to crash for big datasets.
    #train_writer = tf.summary.FileWriter(root_path+'logging/tensorflow_model', sess.graph)
    
    if SUBSET_MODEL_ADD is not None:
        saver = tf.train.Saver()
        saver.restore(sess, tf.train.latest_checkpoint(SUBSET_MODEL_ADD))
        print('model restored')
    else:
        sess.run(tf.global_variables_initializer())             
        print('global variable initialized')
        
    print ('start session is ok ....')
        
    for epoch in range(NUM_EPOCHS):        
        #train
        train_loss=[]    
        for i in range(0, len(x_train_Raw_Sent_id), BATCH_SIZE):
            # slice dataset for padding

            batch_x_Raw = x_train_Raw_Sent_id[slice(i, i + BATCH_SIZE)]
            batch_y_BN = y_train_BNsense_Sent_id[slice(i, i + BATCH_SIZE)]
            batch_y_POS = y_train_POS_Sent_id[slice(i, i + BATCH_SIZE)]            
            batch_y_WND = y_train_WnDomain_Sent_id[slice(i, i + BATCH_SIZE)]
            
            y_train_allSenses_Sent_batch = y_train_allSenses_Sent[slice(i, i + BATCH_SIZE)]
            y_train_allSenses_Sent_id_batch = y_train_allSenses_Sent_id[slice(i, i + BATCH_SIZE)]
            mask_lemma2Sense_b = mask_lemmaToSenses_batch(batch_x_Raw, y_train_allSenses_Sent_batch, y_train_allSenses_Sent_id_batch, SenseWords2id)
                        
            batch_x_Raw = padding3(batch_x_Raw, PAD_ID)
            batch_y_BN = padding(batch_y_BN, PAD_ID)
            batch_y_POS = padding(batch_y_POS, PAD_ID)            
            batch_y_WND = padding(batch_y_WND, PAD_ID)
            
            # runnig training session ang getting train loss for every batch and append in epoch loss
            _, loss_other = sess.run(
                [train_op, total_loss], feed_dict = { input_ : batch_x_Raw, labels : batch_y_BN, y_pos : batch_y_POS, y_wnDomain : batch_y_WND,\
                                                     mask_RawTosense_batch : mask_lemma2Sense_b, mask_pos2sense: mask_train_pos2sense,\
                                                      mask_wnDomain2sense: mask_train_wnDomain2sense, dropout_keep_prob : 0.3 })
            
            train_loss.append(loss_other)            
            
            if i % (BATCH_SIZE * 200) == 0:                
                print ('Train batch %d loss %f' % (i, loss_other))
                
        train_loss=np.mean(train_loss,dtype=float)                
        print ('Train Epoch %d loss %f' % (epoch+1, train_loss))        
        print('--------------------------------') 
        
                                       
#         #Dev
        dev_loss=[]
        dev_pred=[]
        dev_hit_all=0
        dev_all_char=0        
        for i in range(0, len(x_dev_Raw_Sent_id), BATCH_SIZE):            
            batch_x_Lemma = x_dev_Raw_Sent[slice(i, i + BATCH_SIZE)]
            batch_x_Raw = x_dev_Raw_Sent_id[slice(i, i + BATCH_SIZE)]
            batch_y_BN = y_dev_BNsense_Sent_id[slice(i, i + BATCH_SIZE)]
            batch_y_POS = y_dev_POS_Sent_id[slice(i, i + BATCH_SIZE)]            
            batch_y_WND = y_dev_WnDomain_Sent_id[slice(i, i + BATCH_SIZE)]
            
            y_dev_allSenses_Sent_batch = y_dev_allSenses_Sent[slice(i, i + BATCH_SIZE)]
            y_dev_allSenses_Sent_id_batch = y_dev_allSenses_Sent_id[slice(i, i + BATCH_SIZE)]            
            mask_lemma2Sense_b = mask_lemmaToSenses_batch(batch_x_Raw, y_dev_allSenses_Sent_batch, y_dev_allSenses_Sent_id_batch, SenseWords2id)
                        
            batch_x_Raw = padding3(batch_x_Raw, PAD_ID)
            batch_y_BN = padding(batch_y_BN, PAD_ID)
            batch_y_POS = padding(batch_y_POS, PAD_ID)
            batch_y_WND = padding(batch_y_WND, PAD_ID)
            
            # lengths is length of every sentence(number of words), unary_scores is sentences with padding and
            # transition_param_dev is probabilities matrix
            loss_other, lengths, predict = sess.run(
                [total_loss, seq_length, predictions], feed_dict = {input_ : batch_x_Raw, labels : batch_y_BN, y_pos : batch_y_POS, y_wnDomain : batch_y_WND,\
                                                                    mask_RawTosense_batch : mask_lemma2Sense_b, mask_pos2sense: mask_dev_pos2sense ,\
                                                                    mask_wnDomain2sense: mask_dev_wnDomain2sense, dropout_keep_prob: 1.0 })
            
            batch_true = y_dev_BNsense_Sent_id[slice(i, i + BATCH_SIZE)]
        
            pred_sense = []
            true_sense = []            
            for p in range(len(predict)):
                pr = []
                tr = []
                for L_ in range(lengths[p]):
                    # if our prediction is UNK means that word is not in our dictionary and we can't predict anything for that, so we put BackOff plan and MFS as our prediction.
                    if id2Sensewords[predict[p][L_]] != UNK:
                        pr.append(id2Sensewords[predict[p][L_]])
                    else:
                        pr.append(getMFS_(batch_x_Lemma[p][L_], WN2BN_map_dic))
#                         print(getMFS_(batch_x_Lemma[p][L_], WN2BN_map_dic))                        
                                                        
                    tr.append(id2Sensewords[batch_true[p][L_]])
                print(pr)
                print(tr)
                print('\n')
                pred_sense.append(pr)
                true_sense.append(tr)
                        
            batch_pred = []
            for p in range(len(predict)):                
                dev_pred.append(predict[p][:lengths[p]])
                batch_pred.append(predict[p][:lengths[p]])
                
#             print('\n')
            dev_batch_hit, dev_batch_char = number_of_batch_sense_hits(batch_pred, batch_true)            
            print('dev batch %d loss %f dev_batch_hit:%d dev_batch_char:%d batch_accuracy:%f' % (i, loss_other, dev_batch_hit, dev_batch_char, (dev_batch_hit/dev_batch_char)*100 ))
            dev_loss.append(loss_other)            
            dev_hit_all+=dev_batch_hit
            dev_all_char+=dev_batch_char
                
        dev_loss=np.mean(dev_loss,dtype=float)
        dev_acc = (dev_hit_all/dev_all_char)*100
        print('Valid Epoch %d loss %f' % (epoch+1,dev_loss))        
        print('dev_hit_all:%d dev_all_char:%d accuracy:%f' % (dev_hit_all,dev_all_char,dev_acc ))
        print('--------------------------------')

        
        save_path = saver.save(sess, root_path+'/POS_WnDomain_SenseEmbed_models_{}/model.ckpt'.format(dev_acc))
        print("Model saved in path: %s" % save_path)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/NLPHW3/POS_WnDomain_SenseEmbed_models_48.53273137697517/model.ckpt
# model restored
# start session is ok ....
# Train batch 0 loss 7.797009
# Train batch 800 loss 7.834213
# Train batch 1600 loss 7.087600
# Train batch 2400 loss 5.913235
# Train batch 3200 loss 8.057261
# Train batch 4000 loss 7.275396
# Train batch 4800 loss 7.405457
# Train batch 5600 loss 6.836295
# Train batch 6400 loss 5.646729
# Train batch 7200 loss 7.564816
# Train batch 8000 loss 6.993417
# Train batch 8800 loss 7.936648
# Train batch 9600 loss 7.019842
# Train batch 10400 loss 7.439202
# Train batch 11200 loss 5.357411
# Train batch 12000 loss 7.397336
# Train batch 12800 loss 7.666131
# Train batch 13600 loss 7.039035
# Train batch 14400 loss 7.817557
# Train batch 15200 loss 8.641890
# Train batch 16000 loss 7.146187
# Train batch 16800 loss 7.486683
# Train batch 17600 loss 6.120180
# Train batch 18400 loss 7.777731
# Train batch 19200 loss 7.135867
# Train batch 20000 loss 7.690373
# Train batch 20800 loss 5.216501
# Train batch 21600 loss 5.083764
# Train batch 22400 loss 5.337212
# Train batch 23200 loss 5.416583
# Train batch 24000 loss 7.499081
# Train batch 24800 loss 6.197228
# Train batch 25600 loss 6.137515
# Train batch 26400 loss 5.804582
# Train batch 27200 loss 7.241736
# Train batch 28000 loss 6.695217
# Train batch 28800 loss 5.767326
# Train batch 29600 loss 6.655498
# Train batch 30400 loss 5.170220
# Train batch 31200 loss 6.991626
# Train batch 32000 loss 4.605868
# Train batch 32800 loss 5.882963
# Train batch 33600 loss 5.735866
# Train batch 34400 loss 5.785118
# Train batch 35200 loss 7.050655
# Train batch 36000 loss 6.788910
# Train batch 36800 loss 5.992135
# Train Epoch 1 loss 6.843267
# --------------------------------
# ['you', 'oct.', '6', 'editorial', '``', 'the', 'ill', 'bn:00044535n', '``', 'bn:00083240v', 'to', 'bn:00067280n', 'by', 'we', 'and', 'six', 'of', 'we', 'colleague', 'that', 'be', 'bn:00082233v', 'bn:00046209n', 'the', 'sept.', '8', 'issue', 'of', 'the', 'journal', 'of', 'the', 'american', 'bn:00018021n', 'association', '.']
# ['you', 'oct.', '6', 'editorial', '``', 'the', 'ill', '<UNK>', '``', 'bn:00082412v', 'to', 'bn:00067280n', 'by', 'we', 'and', 'six', 'of', 'we', 'colleague', 'that', 'be', 'bn:00092823v', 'in', 'the', 'sept.', '8', 'issue', 'of', 'the', 'journal', 'of', 'the', 'american', 'medical', 'association', '.']
#
#
# ['you', 'bn:00020977n', 'bn:00085636v', 'we', 'have', 'bn:00086708v', 'that', 'the', '``', 'principal', 'bn:00016850n', '``', 'of', 'bn:00044537n', 'be', 'to', 'be', 'bn:00086708v', 'bn:00046209n', 'the', 'large', 'number', 'of', 'mentally', 'ill', 'and', 'substance-abusing', 'people', 'bn:00046209n', 'the', 'bn:00044535n', 'population', '.']
# ['you', 'bn:00020977n', 'bn:00085636v', 'we', 'have', 'bn:00086933v', 'that', 'the', '``', 'principal', 'bn:00016850n', '``', 'of', '<UNK>', 'be', 'to', 'be', 'bn:00086708v', 'in', 'the', 'large', 'number', 'of', 'mentally', 'ill', 'and', '<UNK>', 'people', 'in', 'the', '<UNK>', 'population', '.']
#
#
# ['we', 'have', 'bn:00087106v', 'no', 'such', 'bn:00074033n', '.']
# ['we', 'have', 'bn:00090557v', 'no', 'such', 'bn:00001768n', '.']
#
#
# ['it', 'be', 'clear', 'that', 'most', 'mentally', 'ill', 'people', 'and', 'most', 'alcoholic', 'do', 'not', 'bn:00083293v', 'bn:00044535n', '.']
# ['it', 'be', 'clear', 'that', 'most', 'mentally', 'ill', 'people', 'and', 'most', 'alcoholic', 'do', 'not', 'bn:00083293v', '<UNK>', '.']
#
#
# dev batch 0 loss 7.258508 dev_batch_hit:6 dev_batch_char:11 batch_accuracy:54.545455
# ['the', '``', 'bn:00015051n', '``', 'of', 'bn:00044537n', 'be', 'poorly', 'bn:00095375v', 'and', 'complex', 'bn:00046209n', 'any', 'individual', 'case', '.']
# ['the', '``', 'bn:00016850n', '``', 'of', '<UNK>', 'be', 'poorly', 'bn:00095375v', 'and', 'complex', 'in', 'any', 'individual', 'case', '.']
#
#
# ['bn:00046209n', 'bn:00085007v', 'from', 'we', 'research', 'you', 'bn:00082195v', 'the', 'high', 'prevalance', 'of', 'mental', 'illness', 'and', 'bn:00002523n', '.']
# ['in', 'bn:00085008v', 'from', 'we', 'research', 'you', 'bn:00082195v', 'the', 'high', '<UNK>', 'of', 'mental', 'illness', 'and', '<UNK>', '.']
#
#
# ['you', 'do', 'not', 'bn:00090740v', 'that', 'the', 'bn:00044535n', 'bn:00061450n', 'we', 'bn:00082596v', 'bn:00089240v', 'a', 'bn:00009055n', 'of', 'physical', 'disorder', 'bn:00046209n', 'addition', 'to', 'they', 'psychiatric', 'problem', 'and', 'substance', 'abuse', '.']
# ['you', 'do', 'not', 'bn:00090740v', 'that', 'the', '<UNK>', 'bn:00061450n', 'we', 'bn:00087787v', 'bn:00089245v', 'a', 'bn:00009055n', 'of', 'physical', 'disorder', 'in', 'addition', 'to', 'they', 'psychiatric', 'problem', 'and', 'substance', 'abuse', '.']
#
#
# ['they', 'bn:00094573v', 'from', 'malnutrition', ',', 'chest', 'disease', ',', 'bn:00099263a', 'disorder', ',', 'skin', 'problem', ',', 'infectious', 'disease', 'and', 'the', 'bn:00001867n', 'of', 'assault', 'and', 'rape', '.']
# ['they', 'bn:00088745v', 'from', 'malnutrition', ',', 'chest', 'disease', ',', '<UNK>', 'disorder', ',', 'skin', 'problem', ',', 'infectious', 'disease', 'and', 'the', '<UNK>', 'of', 'assault', 'and', 'rape', '.']
#
#
# dev batch 4 loss 7.475982 dev_batch_hit:4 dev_batch_char:10 batch_accuracy:40.000000
# ['bn:00044535n', 'bn:00061450n', 'not', 'only', 'bn:00090161v', 'safety', ',', 'privacy', 'and', 'bn:00071019n', ',', 'they', 'also', 'bn:00090161v', 'the', 'elementary', 'bn:00057131n', 'of', 'nutrition', ',', 'bn:00019650n', 'and', 'basic', 'health', 'care', '.']
# ['<UNK>', 'bn:00061450n', 'not', 'only', 'bn:00090161v', 'safety', ',', 'privacy', 'and', 'bn:00064840n', ',', 'they', 'also', 'bn:00090161v', 'the', 'elementary', 'bn:00031631n', 'of', 'nutrition', ',', '<UNK>', 'and', 'basic', 'health', 'care', '.']
#
#
# ['bn:00046209n', 'a', 'recent', 'report', ',', 'the', 'institute', 'of', 'medicine', 'bn:00085415v', 'that', 'certain', 'health', 'bn:00048242n', 'may', 'bn:00091943v', 'a', 'bn:00046516n', 'to', 'bn:00044537n', ',', 'other', 'may', 'be', 'a', 'consequence', 'of', 'it', ',', 'and', 'a', 'third', 'bn:00016733n', 'be', 'bn:00085487v', 'of', 'disorder', 'whose', 'treatment', 'be', 'difficult', 'or', 'impossible', 'if', 'a', 'person', 'bn:00090161v', 'adequate', 'bn:00071019n', '.']
# ['in', 'a', 'recent', 'report', ',', 'the', 'institute', 'of', 'medicine', 'bn:00085415v', 'that', 'certain', 'health', 'bn:00048242n', 'may', '<UNK>', 'a', 'bn:00046516n', 'to', '<UNK>', ',', 'other', 'may', 'be', 'a', 'consequence', 'of', 'it', ',', 'and', 'a', 'third', 'bn:00016733n', 'be', 'bn:00085487v', 'of', 'disorder', 'whose', 'treatment', 'be', 'difficult', 'or', 'impossible', 'if', 'a', 'person', 'bn:00090161v', 'adequate', 'bn:00064840n', '.']
#
#
# ['the', 'bn:00047052n', 'between', 'health', 'and', 'bn:00044537n', 'be', 'complex', ',', 'bn:00086491v', 'sweeping', 'bn:00037671n', 'as', 'to', '``', 'cause', '``', 'or', '``', 'effect', '.', '``']
# ['the', 'bn:00047052n', 'between', 'health', 'and', '<UNK>', 'be', 'complex', ',', 'bn:00086491v', 'sweeping', 'bn:00037670n', 'as', 'to', '``', 'cause', '``', 'or', '``', 'effect', '.', '``']
#
#
# ['if', 'we', 'bn:00082669v', 'the', 'bn:00036941n', ',', 'bn:00088454v', 'bn:00044537n', 'be', 'a', 'important', 'bn:00002179n', '.']
# ['if', 'we', 'bn:00090466v', 'the', 'future', ',', 'bn:00088454v', '<UNK>', 'be', 'a', 'important', 'objective', '.']
#
#
# dev batch 8 loss 8.625610 dev_batch_hit:12 dev_batch_char:17 batch_accuracy:70.588235
# ['this', 'will', 'bn:00082820v', 'we', 'to', 'bn:00082282v', 'a', 'much', 'more', 'sophisticated', 'bn:00005134n', 'of', 'the', 'dynamics', 'of', 'bn:00044537n', 'than', 'we', 'currently', 'bn:00091873v', ',', 'a', 'understanding', 'that', 'can', 'be', 'bn:00082282v', 'only', 'through', 'careful', 'study', 'and', 'research', '.']
# ['this', 'will', 'bn:00082822v', 'we', 'to', 'bn:00082282v', 'a', 'much', 'more', 'sophisticated', 'bn:00005134n', 'of', 'the', 'dynamics', 'of', '<UNK>', 'than', 'we', 'currently', 'bn:00091873v', ',', 'a', 'understanding', 'that', 'can', 'be', 'bn:00082282v', 'only', 'through', 'careful', 'study', 'and', 'research', '.']
#
#
# ['william', 'r.', 'breakey', 'm.d.', 'pamelum', 'j.', 'bn:00034814n', 'm.d.', 'department', 'of', 'psychiatry', 'john', 'hopkin', 'university', 'school', 'of', 'medicine', 'baltimore']
# ['william', 'r.', '<UNK>', '<UNK>', '<UNK>', 'j.', '<UNK>', '<UNK>', 'department', 'of', 'psychiatry', 'john', '<UNK>', 'university', 'school', 'of', 'medicine', 'baltimore']
#
#
# ['a', 'bn:00074790n', 'by', 'tulane', 'prof.', 'jame', 'wright', 'bn:00093287v', 'bn:00044537n', 'be', 'due', 'to', 'a', 'complex', 'array', 'of', 'problem', ',', 'with', 'the', 'common', 'thread', 'of', 'poverty', '.']
# ['a', 'bn:00067181n', 'by', 'tulane', 'prof.', '<UNK>', 'wright', 'bn:00082527v', '<UNK>', 'be', 'due', 'to', 'a', 'complex', 'array', 'of', 'problem', ',', 'with', 'the', 'common', 'thread', 'of', 'poverty', '.']
#
#
# ['the', 'bn:00074790n', 'bn:00086557v', 'that', 'nearly', '40', '%', 'of', 'the', 'bn:00044535n', 'population', 'be', 'bn:00085527v', 'of', 'woman', 'and', 'child', 'and', 'that', 'only', '25', '%', 'of', 'the', 'bn:00044535n', 'bn:00087013v', 'bn:00110911a', 'bn:00020872n', 'of', 'drug', ',', 'alcohol', 'and', 'mental', 'problem', '.']
# ['the', 'bn:00067181n', 'bn:00086567v', 'that', 'nearly', '40', '%', 'of', 'the', '<UNK>', 'population', 'be', 'bn:00083187v', 'of', 'woman', 'and', 'child', 'and', 'that', 'only', '25', '%', 'of', 'the', '<UNK>', 'bn:00087841v', 'some', 'bn:00020872n', 'of', 'drug', ',', 'alcohol', 'and', 'mental', 'problem', '.']
#
#
# dev batch 12 loss 5.388601 dev_batch_hit:5 dev_batch_char:12 batch_accuracy:41.666667
# ['accord', 'to', 'dr.', 'wright', ',', 'bn:00044537n', 'be', '``', 'simultaneously', 'a', 'housing', 'bn:00048242n', ',', 'a', 'employment', 'problem', ',', 'a', 'demographic', 'problem', ',', 'a', 'problem', 'of', 'social', 'disaffiliation', ',', 'a', 'mental', 'health', 'problem', ',', 'a', 'family', 'violence', 'problem', ',', 'a', 'problem', 'bn:00086008v', 'by', 'the', 'cutback', 'bn:00046209n', 'social', 'welfare', 'spending', ',', 'a', 'problem', 'bn:00087671v', 'from', 'the', 'decay', 'of', 'the', 'traditional', 'nuclear', 'family', ',', 'and', 'a', 'problem', 'intimately', 'bn:00082868v', 'to', 'the', 'recent', 'increase', 'bn:00046209n', 'the', 'number', 'of', 'bn:00046516n', 'bn:00087441v', 'below', 'the', 'poverty', 'level', '.', '``']
# ['accord', 'to', 'dr.', 'wright', ',', '<UNK>', 'be', '``', 'simultaneously', 'a', 'housing', 'bn:00048242n', ',', 'a', 'employment', 'problem', ',', 'a', 'demographic', 'problem', ',', 'a', 'problem', 'of', 'social', '<UNK>', ',', 'a', 'mental', 'health', 'problem', ',', 'a', 'family', 'violence', 'problem', ',', 'a', 'problem', 'bn:00086008v', 'by', 'the', 'cutback', 'in', 'social', 'welfare', 'spending', ',', 'a', 'problem', 'bn:00090243v', 'from', 'the', 'decay', 'of', 'the', 'traditional', 'nuclear', 'family', ',', 'and', 'a', 'problem', 'intimately', 'bn:00082868v', 'to', 'the', 'recent', 'increase', 'in', 'the', 'number', 'of', 'bn:00046516n', 'bn:00090408v', 'below', 'the', 'poverty', 'level', '.', '``']
#
#
# ['leighton', 'e.', 'cluff', 'm.d.', 'president', 'robert', 'wood', 'johnson', 'foundation', 'princeton', ',', 'n.j', '.']
# ['leighton', 'e.', '<UNK>', '<UNK>', 'president', 'robert', 'wood', 'johnson', 'foundation', 'princeton', ',', '<UNK>', '.']
#
#
# ['to', 'bn:00085007v', 'the', 'highly', 'bn:00085647v', 'bn:00027366n', 'of', 'a', 'privately', 'fund', 'drop-in', 'bn:00017120n', 'for', 'the', 'bn:00044535n', 'bn:00046209n', 'bn:00107267a', 'york', ':', '``', 'if', 'you', 'be', 'bn:00044535n', ',', 'you', 'do', "n't", 'bn:00084684v', 'for', 'fear', 'of', 'be', 'bn:00093070v', 'or', 'murder', '.']
# ['to', 'bn:00085007v', 'the', 'highly', '<UNK>', 'bn:00027366n', 'of', 'a', 'privately', 'fund', '<UNK>', 'bn:00017122n', 'for', 'the', '<UNK>', 'in', 'new', 'york', ':', '``', 'if', 'you', 'be', '<UNK>', ',', 'you', 'do', '<UNK>', 'bn:00084684v', 'for', 'fear', 'of', 'be', 'bn:00093070v', 'or', 'murder', '.']
#
#
# ['after', 'you', 'first', 'three', 'week', 'of', 'sleep', 'bn:00026415n', ',', 'you', 'be', 'scarcely', 'bn:00046209n', 'touch', 'with', 'reality', 'bn:00097285a', 'more', ';', 'without', 'psychiatric', 'treatment', ',', 'you', 'may', 'well', 'be', 'unable', 'to', 'bn:00088120v', 'for', 'yourself', 'ever', 'again', '.', '``']
# ['after', 'you', 'first', 'three', 'week', 'of', 'sleep', '<UNK>', ',', 'you', 'be', 'scarcely', 'in', 'touch', 'with', 'reality', 'any', 'more', ';', 'without', 'psychiatric', 'treatment', ',', 'you', 'may', 'well', 'be', 'unable', 'to', '<UNK>', 'for', 'yourself', 'ever', 'again', '.', '``']
#
#
# dev batch 16 loss 8.650011 dev_batch_hit:8 dev_batch_char:11 batch_accuracy:72.727273
# ['bn:00110911a', 'of', 'the', 'bn:00044535n', ',', 'obviously', ',', 'bn:00089240v', 'bn:00108893a', 'mental', 'illness', 'or', 'bn:00001287n', '.']
# ['some', 'of', 'the', '<UNK>', ',', 'obviously', ',', 'bn:00089245v', '<UNK>', 'mental', 'illness', 'or', 'bn:00001287n', '.']
#
#
# ['but', 'many', 'other', 'have', 'bn:00087976v', 'through', 'crack', 'bn:00046209n', 'the', 'economy', 'into', 'the', 'grim', ',', 'brutal', 'world', 'of', 'we', 'city', 'street', '.']
# ['but', 'many', 'other', 'have', 'bn:00087976v', 'through', 'crack', 'in', 'the', 'economy', 'into', 'the', 'grim', ',', 'brutal', 'world', 'of', 'we', 'city', 'street', '.']
#
#
# ['once', 'there', ',', 'what', 'bn:00033729n', 'of', 'escape', 'be', 'bn:00019658n', 'to', 'they', 'other', 'than', 'drink', ',', 'drug', 'or', 'bn:00046865n', '?']
# ['once', 'there', ',', 'what', 'way', 'of', 'escape', 'be', 'open', 'to', 'they', 'other', 'than', 'drink', ',', 'drug', 'or', '<UNK>', '?']
#
#
# ['maxwell', 'r.d.', 'vo', 'brooklyn', ',', 'n.y', '.']
# ['maxwell', '<UNK>', '<UNK>', 'brooklyn', ',', '<UNK>', '.']
#
#
# dev batch 20 loss 9.934023 dev_batch_hit:1 dev_batch_char:3 batch_accuracy:33.333333
# ['you', 'bn:00084160v', 'as', '``', 'sentimental', '``', 'the', 'bn:00061746n', 'that', 'the', 'bn:00025780n', 'of', 'federal', 'housing-assistance', 'program', 'by', '77', '%', 'might', 'have', 'bn:00091708v', 'a', 'significant', 'bn:00017749n', 'bn:00046209n', 'the', 'increase', 'bn:00058285n', 'of', 'man', 'and', 'bn:00001530n', 'sleep', 'on', 'we', 'city', 'street', 'during', 'the', 'reagan-bush', 'year', '.']
# ['you', 'bn:00084160v', 'as', '``', 'sentimental', '``', 'the', 'bn:00061746n', 'that', 'the', 'bn:00025780n', 'of', 'federal', '<UNK>', 'program', 'by', '77', '%', 'might', 'have', 'bn:00091709v', 'a', 'significant', 'bn:00036823n', 'in', 'the', 'increase', 'bn:00034394n', 'of', 'man', 'and', 'bn:00001530n', 'sleep', 'on', 'we', 'city', 'street', 'during', 'the', '<UNK>', 'year', '.']
#
#
# ['there', 'be', 'no', 'sign', 'that', 'you', 'bn:00083809v', 'to', 'bn:00083370v', 'the', 'bn:00047338n', 'of', 'you', 'logic', ':', 'namely', ',', 'that', 'mental', 'illness', 'and', 'substance', 'abuse', 'might', 'be', 'to', 'bn:00110911a', 'degree', 'consequence', 'rather', 'than', 'cause', 'of', 'bn:00044537n', '.']
# ['there', 'be', 'no', 'sign', 'that', 'you', 'bn:00083808v', 'to', 'bn:00085648v', 'the', 'inverse', 'of', 'you', 'logic', ':', 'namely', ',', 'that', 'mental', 'illness', 'and', 'substance', 'abuse', 'might', 'be', 'to', 'some', 'degree', 'consequence', 'rather', 'than', 'cause', 'of', '<UNK>', '.']
#
#
# ['you', 'bn:00067280n', 'bn:00084711v', 'when', 'a', 'convenient', 'bn:00006496n', 'could', 'be', 'bn:00087106v', '.']
# ['you', 'bn:00067280n', 'bn:00084711v', 'when', 'a', 'convenient', 'bn:00001768n', 'could', 'be', 'bn:00090557v', '.']
#
#
# ['robert', 's.', 'jenkin', 'cambridge', ',', 'bn:00053662n', '.']
# ['robert', 's.', '<UNK>', 'cambridge', ',', 'mass', '.']
#
#
# dev batch 24 loss 8.089883 dev_batch_hit:6 dev_batch_char:13 batch_accuracy:46.153846
# ['of', 'the', 'approximately', '200', 'sponsor', 'of', 'the', 'recent', 'bn:00053318n', 'bn:00046209n', 'washington', 'for', 'the', 'bn:00044535n', ',', 'you', 'bn:00084932v', 'to', 'bn:00085007v', 'such', 'bn:00041942n', 'as', 'the', 'bn:00056915n', 'association', 'of', 'bn:00000356n', 'builder', 'and', 'the', 'bn:00047146n', 'union', 'of', 'bn:00013057n', 'and', 'bn:00082549v', 'craftsman', ',', 'bn:00089772v', 'that', 'the', 'march', 'bn:00083293v', 'its', 'major', 'bn:00075330n', 'from', 'bn:00110337a', 'group', 'that', '``', 'bn:00085261v', 'a', 'good', 'bn:00076921n', 'when', 'they', 'bn:00093430v', 'it', ',', '``', 'and', 'that', 'the', 'bn:00015051n', 'be', 'bn:00083141v', 'on', 'bn:00041630n', 'or', 'the', 'profit', 'motive', '.']
# ['of', 'the', 'approximately', '200', 'sponsor', 'of', 'the', 'recent', 'bn:00053354n', 'in', 'washington', 'for', 'the', '<UNK>', ',', 'you', 'bn:00084933v', 'to', 'bn:00082412v', 'such', 'bn:00041942n', 'as', 'the', 'national', 'association', 'of', 'home', 'builder', 'and', 'the', 'international', 'union', 'of', '<UNK>', 'and', 'allied', 'craftsman', ',', 'bn:00082393v', 'that', 'the', 'march', 'bn:00082276v', 'its', 'major', 'bn:00007799n', 'from', '<UNK>', 'group', 'that', '``', 'bn:00090146v', 'a', 'good', 'bn:00001734n', 'when', 'they', 'bn:00088205v', 'it', ',', '``', 'and', 'that', 'the', 'bn:00015051n', 'be', 'bn:00083141v', 'on', '<UNK>', 'or', 'the', 'profit', 'motive', '.']
#
#
# ['but', 'be', "n't", 'the', 'desire', 'for', 'profit', 'the', 'drive', 'bn:00035768n', 'behind', 'those', 'who', 'bn:00093731v', 'to', ',', 'and', 'bn:00082413v', 'bn:00046209n', ',', 'you', 'paper', '?']
# ['but', 'be', '<UNK>', 'the', 'desire', 'for', 'profit', 'the', 'drive', 'bn:00035767n', 'behind', 'those', 'who', 'bn:00094547v', 'to', ',', 'and', 'bn:00082414v', 'in', ',', 'you', 'paper', '?']
#
#
# ['why', 'do', "n't", 'you', 'bn:00082412v', 'the', 'ymca', 'or', 'the', 'ywca', 'or', 'bn:00016776n', 'charity', 'bn:00003341n', 'or', 'a', 'hundred', 'other', 'nonprofit', 'bn:00059480n', 'that', 'bn:00091451v', 'bn:00046209n', 'the', 'march', '?']
# ['why', 'do', '<UNK>', 'you', 'bn:00082412v', 'the', '<UNK>', 'or', 'the', '<UNK>', 'or', 'catholic', 'charity', '<UNK>', 'or', 'a', 'hundred', 'other', 'nonprofit', 'bn:00059480n', 'that', 'bn:00091451v', 'in', 'the', 'march', '?']
#
#
# ['as', 'for', 'the', 'finding', 'on', 'the', '203', 'baltimore', 'bn:00044535n', 'who', 'bn:00095355v', 'psychiatric', 'bn:00032093n', ',', 'i', 'bn:00082417v', 'you', 'bn:00084593v', 'you', 'own', 'bn:00074790n', '.']
# ['as', 'for', 'the', 'finding', 'on', 'the', '<UNK>', 'baltimore', '<UNK>', 'who', '<UNK>', 'psychiatric', 'bn:00032093n', ',', 'i', 'bn:00082417v', 'you', 'bn:00084593v', 'you', 'own', 'bn:00074790n', '.']
#
#
# dev batch 28 loss 10.065688 dev_batch_hit:10 dev_batch_char:22 batch_accuracy:45.454545
# ['bn:00084932v', '203', 'business', 'bn:00032179n', ',', 'bn:00089660v', ',', 'perhaps', ',', 'someone', 'from', 'you', 'own', 'staff', ',', 'and', 'bn:00092204v', 'they', 'out', 'bn:00107820a', 'the', 'street', ',', 'to', 'be', 'bn:00086636v', 'for', 'one', 'month', 'of', 'they', 'bn:00000356n', ',', 'family', 'and', 'income', '.']
# ['bn:00084931v', '<UNK>', 'business', 'bn:00032179n', ',', 'bn:00089660v', ',', 'perhaps', ',', 'someone', 'from', 'you', 'own', 'staff', ',', 'and', 'bn:00090224v', 'they', 'out', 'on', 'the', 'street', ',', 'to', 'be', 'bn:00086637v', 'for', 'one', 'month', 'of', 'they', 'home', ',', 'family', 'and', 'income', '.']
#
#
# ['i', 'would', 'bn:00082668v', 'that', 'within', 'a', 'short', 'time', 'most', 'of', 'they', 'would', 'bn:00086708v', 'bn:00077125n', 'a', 'satisfactory', 'bn:00067170n', 'for', 'chiva', 'regal', 'and', 'that', 'they', '``', 'normal', '``', 'bn:00062000n', ',', 'anxiety', ',', 'depression', 'and', 'substance', 'abuse', 'would', 'bn:00089666v', 'dramatically', '.']
# ['i', 'would', 'bn:00082668v', 'that', 'within', 'a', 'short', 'time', 'most', 'of', 'they', 'would', 'bn:00088095v', '<UNK>', 'a', 'satisfactory', 'substitute', 'for', '<UNK>', 'regal', 'and', 'that', 'they', '``', 'normal', '``', '<UNK>', ',', 'anxiety', ',', 'depression', 'and', 'substance', 'abuse', 'would', 'bn:00089666v', 'dramatically', '.']
#
#
# ['ruth', 'k.', 'nelson', 'cullowhee', ',', 'n.c', '.']
# ['ruth', 'k.', 'nelson', '<UNK>', ',', '<UNK>', '.']
#
#
# ['``', 'feeding', 'frenzy', '``', '(', 'henry', 'holt', ',', '326', 'page', ',', '$', '19.95', ')', ',', 'a', 'highly', 'detailed', 'bn:00000741n', 'of', 'the', 'wedtech', 'scandal', ',', 'bn:00083341v', 'on', 'a', 'bn:00082880v', 'note', '.']
# ['``', 'feeding', 'frenzy', '``', '(', 'henry', '<UNK>', ',', '<UNK>', 'page', ',', '$', '<UNK>', ')', ',', 'a', 'highly', 'detailed', 'bn:00000738n', 'of', 'the', '<UNK>', 'scandal', ',', 'bn:00083346v', 'on', 'a', '<UNK>', 'note', '.']
#
#
# dev batch 32 loss 6.660028 dev_batch_hit:4 dev_batch_char:10 batch_accuracy:40.000000
# ['right', 'up', 'bn:00035855n', 'bn:00046209n', 'the', 'bn:00035883n', ',', 'bn:00085210v', 'william', 'sternberg', 'bn:00082442v', 'we', 'a', 'bn:00016401n', 'of', 'he', 'own', 'integrity', '.']
# ['right', 'up', 'front', 'in', 'the', '<UNK>', ',', '<UNK>', 'william', '<UNK>', 'bn:00088816v', 'we', 'a', 'bn:00032099n', 'of', 'he', 'own', 'integrity', '.']
#
#
# ['when', 'bn:00091135v', 'a', 'bn:00036334n', 'bn:00078318n', 'from', 'the', 'bronx', ',', 'wedtech', "'s", 'bn:00000356n', ',', 'to', 'washington', ',', 'd.c.', ',', 'by', 'one', 'of', 'wedtech', "'s", 'principal', ',', 'he', 'bn:00093287v', 'the', 'bn:00066365n', ',', '``', 'mindful', 'of', 'bn:00082197v', 'anything', 'of', 'value', 'from', 'those', 'i', 'be', 'bn:00095851v', ',', 'i', 'bn:00086391v', '.', '``']
# ['when', 'bn:00091136v', 'a', 'free', 'bn:00078318n', 'from', 'the', 'bronx', ',', '<UNK>', "'s", 'home', ',', 'to', 'washington', ',', 'd.c.', ',', 'by', 'one', 'of', '<UNK>', "'s", 'principal', ',', 'he', 'bn:00091011v', 'the', 'bn:00066367n', ',', '``', 'mindful', 'of', 'bn:00082198v', 'anything', 'of', 'value', 'from', 'those', 'i', 'be', 'bn:00095851v', ',', 'i', 'bn:00086390v', '.', '``']
#
#
# ['bn:00097285a', 'bn:00030951n', 'as', 'to', 'why', 'a', 'bn:00007287n', 'would', 'bn:00083369v', 'this', 'plaintive', ',', 'high-minded', 'note', 'of', 'assurance', 'be', 'necessary', 'be', 'bn:00082646v', 'by', 'bn:00092424v', 'this', 'bn:00012059n', 'about', 'bn:00103638a', 'finger', 'and', 'sweaty', 'bn:00018547n', '.']
# ['any', 'bn:00030951n', 'as', 'to', 'why', 'a', 'bn:00007287n', 'would', 'bn:00083370v', 'this', 'plaintive', ',', 'high-minded', 'note', 'of', 'assurance', 'be', 'necessary', 'be', 'bn:00082649v', 'by', 'bn:00092424v', 'this', 'bn:00012059n', 'about', '<UNK>', 'finger', 'and', 'sweaty', '<UNK>', '.']
#
#
# ['bn:00013043n', 'by', 'bn:00013043n', ',', 'mr.', 'sternberg', 'and', 'he', 'bn:00085210v', ',', 'matthew', 'c.', 'harrison', 'jr.', ',', 'bn:00090246v', 'we', 'along', 'the', 'bn:00061006n', 'wedtech', 'bn:00088912v', ',', 'from', 'its', 'inception', 'as', 'a', 'small', 'manufacturing', 'bn:00021286n', 'to', 'the', 'status', 'of', 'full-fledged', 'defense', 'bn:00022240n', ',', 'bn:00085428v', 'with', 'the', 'task', 'of', 'bn:00084082v', 'vital', 'equipment', 'for', 'the', 'army', 'and', 'navy', '.']
# ['<UNK>', 'by', '<UNK>', ',', 'mr.', '<UNK>', 'and', 'he', '<UNK>', ',', 'matthew', 'c.', 'harrison', 'jr.', ',', 'bn:00085567v', 'we', 'along', 'the', 'bn:00061005n', '<UNK>', 'bn:00089994v', ',', 'from', 'its', 'inception', 'as', 'a', 'small', 'manufacturing', 'bn:00021286n', 'to', 'the', 'status', 'of', 'full-fledged', 'defense', 'bn:00022240n', ',', 'bn:00085428v', 'with', 'the', 'task', 'of', 'bn:00086013v', 'vital', 'equipment', 'for', 'the', 'army', 'and', 'navy', '.']
#
#
# dev batch 36 loss 8.551917 dev_batch_hit:9 dev_batch_char:22 batch_accuracy:40.909091
# ['the', 'bn:00012059n', 'bn:00084725v', 'john', 'mariotta', ',', 'the', 'founder', 'of', 'the', 'company', ',', 'and', 'fred', 'neuberger', ',', 'who', 'bn:00083293v', 'he', 'bn:00010161n', 'soon', 'after', 'wedtech', "'s", 'creation', '.']
# ['the', 'bn:00012059n', 'bn:00084725v', 'john', '<UNK>', ',', 'the', 'founder', 'of', 'the', 'company', ',', 'and', 'fred', 'neuberger', ',', 'who', 'bn:00083294v', 'he', 'bn:00020592n', 'soon', 'after', '<UNK>', "'s", 'creation', '.']
#
#
# ['although', 'bn:00083341v', 'bn:00046209n', '1965', ',', 'wedtech', 'do', "n't", 'really', 'bn:00083293v', 'bn:00084629v', 'until', '1975', ',', 'when', 'mr.', 'neuberger', 'bn:00086933v', 'the', 'federal', 'government', "'s", 'section', '8', 'a', 'minority', 'business', 'bn:00062759n', '.']
# ['although', 'bn:00089743v', 'in', '1965', ',', '<UNK>', 'do', '<UNK>', 'really', 'bn:00083340v', 'bn:00093082v', 'until', '<UNK>', ',', 'when', 'mr.', 'neuberger', 'bn:00082902v', 'the', 'federal', 'government', "'s", 'section', '8', 'a', 'minority', 'business', 'bn:00064646n', '.']
#
#
# ['this', 'be', 'a', 'johnson-era', ',', 'bn:00041551n', 'society', 'bn:00021550n', 'that', 'bn:00090617v', 'certain', 'government', 'bn:00022227n', 'be', 'bn:00082966v', 'bn:00116362r', 'to', 'minority', 'business', '.']
# ['this', 'be', 'a', '<UNK>', ',', 'great', 'society', 'bn:00023653n', 'that', 'bn:00090618v', 'certain', 'government', 'bn:00022227n', 'be', 'bn:00082966v', '<UNK>', 'to', 'minority', 'business', '.']
#
#
# ['mr.', 'neuberger', 'bn:00082472v', 'that', ',', 'although', 'of', 'italian', 'ancestry', ',', 'mr.', 'mariotta', 'still', 'could', 'bn:00090717v', 'as', 'a', 'minority', 'person', 'since', 'he', 'be', 'bear', 'bn:00046209n', 'puerto', 'rico', '.']
# ['mr.', 'neuberger', 'bn:00082472v', 'that', ',', 'although', 'of', 'italian', 'ancestry', ',', 'mr.', '<UNK>', 'still', 'could', 'bn:00090717v', 'as', 'a', 'minority', 'person', 'since', 'he', 'be', 'bear', 'in', 'puerto', 'rico', '.']
#
#
# dev batch 40 loss 6.165520 dev_batch_hit:6 dev_batch_char:15 batch_accuracy:40.000000
# ['the', 'two', 'bn:00010161n', 'merely', 'bn:00089240v', 'to', 'bn:00087056v', 'the', 'true', 'bn:00059957n', 'of', 'the', 'corporation', '.']
# ['the', 'two', 'bn:00020592n', 'merely', 'bn:00084700v', 'to', 'bn:00085786v', 'the', 'true', 'bn:00059957n', 'of', 'the', 'corporation', '.']
#
#
# ['instead', 'of', '50/50', 'it', 'bn:00083293v', ',', 'bn:00107820a', 'paper', 'only', ',', 'bn:00078778n', 'mariotta', ',', 'bn:00058990n', 'neuberger', ',', 'and', 'they', 'be', 'bn:00046209n', 'the', 'program', 'and', 'off', 'to', 'the', 'race', '.']
# ['instead', 'of', '<UNK>', 'it', 'bn:00083294v', ',', 'on', 'paper', 'only', ',', '<UNK>', '<UNK>', ',', 'one-third', 'neuberger', ',', 'and', 'they', 'be', 'in', 'the', 'program', 'and', 'off', 'to', 'the', 'race', '.']
#
#
# ['besides', 'be', 'a', '``', 'minority-owned', 'company', '``', 'wedtech', 'be', 'bn:00090424v', 'bn:00046209n', 'the', 'bn:00072960n', 'bronx', ',', 'a', 'bn:00083603v', 'bn:00005513n', ',', 'bn:00087106v', 'famous', 'by', 'jimmy', 'carter', 'bn:00046209n', 'he', '1976', 'presidential', 'campaign', '.']
# ['besides', 'be', 'a', '``', '<UNK>', 'company', '``', '<UNK>', 'be', 'bn:00090425v', 'in', 'the', 'south', 'bronx', ',', 'a', '<UNK>', 'bn:00005513n', ',', 'bn:00088736v', 'famous', 'by', 'jimmy', 'carter', 'in', 'he', '1976', 'presidential', 'campaign', '.']
#
#
# ['the', 'bn:00021286n', 'plug', 'itself', 'right', 'into', 'carter', 'campaign', 'rhetoric', 'about', 'bn:00092471v', 'the', 'bn:00072960n', 'bronx', 'and', 'bn:00089384v', 'bn:00082705v', 'the', 'minority', '--', 'bn:00072960n', 'bronx', 'bn:00004117n', 'through', 'the', 'bn:00064236n', "'80", '.']
# ['the', 'bn:00021286n', 'plug', 'itself', 'right', 'into', 'carter', 'campaign', 'rhetoric', 'about', 'bn:00092471v', 'the', 'south', 'bronx', 'and', 'bn:00085714v', 'bn:00095474v', 'the', 'minority', '<UNK>', 'south', 'bronx', 'bn:00004118n', 'through', 'the', '<UNK>', '<UNK>', '.']
#
#
# dev batch 44 loss 7.733924 dev_batch_hit:4 dev_batch_char:13 batch_accuracy:30.769231
# ['bn:00083341v', 'with', 'congressman', 'mario', 'biaggus', 'now', 'bn:00093511v', 'a', 'jail', 'bn:00070528n', ',', 'the', 'bn:00021286n', 'bn:00083341v', 'a', 'bn:00014839n', 'of', 'bn:00084040v', 'federal', ',', 'state', 'and', 'local', 'public', 'bn:00036837n', 'and', 'those', 'close', 'to', 'public', 'official', ',', 'right', 'up', 'to', 'and', 'bn:00089660v', 'e.', 'robert', 'wallach', ',', 'close', 'friend', 'and', 'adviser', 'to', 'former', 'attorney', 'bn:00036772n', 'ed', 'meese', '.']
# ['bn:00083340v', 'with', 'congressman', 'mario', '<UNK>', 'now', 'bn:00087111v', 'a', 'jail', 'bn:00064472n', ',', 'the', 'bn:00021286n', 'bn:00083342v', 'a', 'bn:00016019n', 'of', 'bn:00084040v', 'federal', ',', 'state', 'and', 'local', 'public', 'bn:00036837n', 'and', 'those', 'close', 'to', 'public', 'official', ',', 'right', 'up', 'to', 'and', 'bn:00089660v', 'e.', 'robert', '<UNK>', ',', 'close', 'friend', 'and', 'adviser', 'to', 'former', 'attorney', 'general', 'ed', '<UNK>', '.']
#
#
# ['wedtech', 'do', "n't", 'just', 'bn:00082705v', 'old', 'fashion', 'bn:00013045n', '.']
# ['<UNK>', 'do', '<UNK>', 'just', 'bn:00082705v', 'old', 'fashion', '<UNK>', '.']
#
#
# ['it', 'bn:00087106v', 'ample', 'bn:00030627n', 'of', 'the', 'modern', 'technique', 'of', 'influence', 'bn:00043196n', ',', 'bn:00092928v', 'politically', 'connect', '``', 'respectable', '``', 'law', 'bn:00014160n', ',', 'investment', 'banker', 'and', 'political', 'consultant', ',', 'bn:00089660v', 'bn:00064236n', 'bn:00021740n', 'lyn', 'nofzinger', '.']
# ['it', 'bn:00087106v', 'ample', 'bn:00030627n', 'of', 'the', 'modern', 'technique', 'of', 'influence', '<UNK>', ',', 'bn:00085716v', 'politically', 'connect', '``', 'respectable', '``', 'law', 'firm', ',', 'investment', 'banker', 'and', 'political', 'consultant', ',', 'bn:00089660v', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '.']
#
#
# ['when', 'necessary', ',', 'it', 'bn:00093452v', 'and', 'bn:00092490v', 'bn:00002155n', 'from', 'organize', 'crime', '.']
# ['when', 'necessary', ',', 'it', 'bn:00093452v', 'and', 'bn:00089246v', 'bn:00002155n', 'from', 'organize', 'crime', '.']
#
#
# dev batch 48 loss 8.659115 dev_batch_hit:10 dev_batch_char:17 batch_accuracy:58.823529
# ['sometimes', 'the', 'bn:00013043n', 'bn:00083293v', 'bn:00010161n', 'bn:00046209n', 'the', 'company', '.']
# ['sometimes', 'the', '<UNK>', 'bn:00083294v', 'bn:00020592n', 'in', 'the', 'company', '.']
#
#
# ['wedtech', 'bn:00053116n', 'bn:00082705v', 'the', 'merit', 'bn:00075760n', '.']
# ['<UNK>', 'bn:00053116n', 'bn:00082705v', 'the', 'merit', 'bn:00075761n', '.']
#
#
# ['if', 'you', 'be', 'especially', 'helpful', 'bn:00046209n', 'a', 'corrupt', 'scheme', 'you', 'bn:00092490v', 'not', 'just', 'cash', 'bn:00046209n', 'a', 'bag', ',', 'but', 'bn:00031334n', '.']
# ['if', 'you', 'be', 'especially', 'helpful', 'in', 'a', 'corrupt', 'scheme', 'you', 'bn:00089246v', 'not', 'just', 'cash', 'in', 'a', 'bag', ',', 'but', 'bn:00031333n', '.']
#
#
# ['if', 'you', 'be', 'not', 'a', 'effective', 'bn:00023815n', ',', 'you', 'bn:00086708v', 'yourself', 'out', 'bn:00046209n', 'the', 'bn:00020534n', ',', 'a', 'bn:00026603n', 'that', 'eventually', 'bn:00083285v', 'mr.', 'mariotta', ',', 'the', 'bn:00014160n', "'s", 'bn:00110372a', '``', 'minority', '``', 'bn:00046516n', '.']
# ['if', 'you', 'be', 'not', 'a', 'effective', '<UNK>', ',', 'you', 'bn:00088209v', 'yourself', 'out', 'in', 'the', 'cold', ',', 'a', 'bn:00026603n', 'that', 'eventually', 'bn:00083285v', 'mr.', '<UNK>', ',', 'the', 'firm', "'s", '<UNK>', '``', 'minority', '``', 'bn:00046516n', '.']
#
#
# dev batch 52 loss 9.242208 dev_batch_hit:5 dev_batch_char:11 batch_accuracy:45.454545
# ['but', 'despite', 'the', 'bn:00110403a', 'nature', 'of', 'the', 'revelation', 'and', 'the', 'breezy', ',', 'easy-to-read', 'bn:00075800n', 'writing', 'style', ',', '``', 'feeding', 'frenzy', '``', 'often', 'bn:00085380v', 'of', 'grip', 'reading', '.']
# ['but', 'despite', 'the', '<UNK>', 'nature', 'of', 'the', 'revelation', 'and', 'the', 'breezy', ',', '<UNK>', 'tabloid', 'writing', 'style', ',', '``', 'feeding', 'frenzy', '``', 'often', 'bn:00085380v', 'of', 'grip', 'reading', '.']
#
#
# ['none', 'of', 'the', 'bn:00023435n', 'bn:00086557v', 'much', 'bn:00019745n', ':', 'auditor', 'bn:00086708v', 'crookery', 'the', 'first', 'day', 'on', 'the', 'job', '.']
# ['none', 'of', 'the', '<UNK>', 'bn:00083245v', 'much', 'bn:00019746n', ':', 'auditor', 'bn:00086708v', '<UNK>', 'the', 'first', 'day', 'on', 'the', 'job', '.']
#
#
# ['wedtech', "'s", 'bn:00018547n', 'simply', 'bn:00084040v', 'they', 'to', 'bn:00089538v', '.']
# ['<UNK>', "'s", '<UNK>', 'simply', 'bn:00084040v', 'they', 'to', 'bn:00083206v', '.']
#
#
# ['the', 'bn:00018547n', 'themselves', 'be', 'garden-variety', 'low', 'life', ',', 'bn:00100329a', 'consumer', 'who', 'bn:00086682v', 'big', 'house', ',', 'mercedes', 'car', ',', 'beautiful', 'woman', ',', 'expensive', 'bn:00005007n', '.']
# ['the', '<UNK>', 'themselves', 'be', '<UNK>', 'low', 'life', ',', '<UNK>', 'consumer', 'who', 'bn:00086682v', 'big', 'house', ',', '<UNK>', 'car', ',', 'beautiful', 'woman', ',', 'expensive', 'bn:00005007n', '.']
#
#
# dev batch 56 loss 5.995344 dev_batch_hit:5 dev_batch_char:8 batch_accuracy:62.500000
# ['among', 'the', 'lot', 'of', 'they', ',', 'not', 'one', 'be', 'bn:00041427n', 'with', 'good', 'and', 'evil', ',', 'or', 'especially', 'intelligent', 'or', 'even', 'temporarily', 'insane', '.']
# ['among', 'the', 'lot', 'of', 'they', ',', 'not', 'one', 'be', '<UNK>', 'with', 'good', 'and', 'evil', ',', 'or', 'especially', 'intelligent', 'or', 'even', 'temporarily', 'insane', '.']
#
#
# ['the', 'one', 'character', 'at', 'least', 'somewhat', 'interesting', 'be', 'irving', 'loui', 'lobsenz', ',', 'a', 'bn:00007663n', 'who', 'bn:00084769v', 'he', 'bn:00056758n', 'to', 'rusty', 'kent', 'london', 'and', 'bn:00083293v', 'a', 'bn:00052664n', 'gambler', 'and', 'bn:00007287n', 'of', 'a', 'book', 'on', 'blackjack', '.']
# ['the', 'one', 'character', 'at', 'least', 'somewhat', 'interesting', 'be', 'irving', '<UNK>', '<UNK>', ',', 'a', '<UNK>', 'who', 'bn:00084772v', 'he', 'bn:00056758n', 'to', 'rusty', 'kent', 'london', 'and', 'bn:00083294v', 'a', 'master', 'gambler', 'and', 'bn:00007287n', 'of', 'a', 'book', 'on', 'blackjack', '.']
#
#
# ['he', 'bn:00085363v', 'the', 'story', 'toward', 'the', 'end', ',', 'just', 'bn:00046209n', 'time', 'to', 'bn:00083293v', 'bn:00082728v', '.']
# ['he', 'bn:00085363v', 'the', 'story', 'toward', 'the', 'end', ',', 'just', 'in', 'time', 'to', 'bn:00083293v', 'bn:00082728v', '.']
#
#
# ['bn:00082170v', 'bn:00046209n', 'bn:00028099n', 'out', '``', 'feeding', 'frenzy', "'s", '``', 'tidbit', ',', 'the', 'bn:00007287n', 'bn:00088901v', 'the', 'root', 'cause', 'of', 'wedtech', ',', 'namely', 'the', 'section', '8', 'a', 'federal', 'bn:00062759n', 'under', 'whose', 'auspices', 'the', 'bn:00027388n', 'bn:00085337v', '.']
# ['bn:00082177v', 'in', '<UNK>', 'out', '``', 'feeding', 'frenzy', "'s", '``', 'tidbit', ',', 'the', 'bn:00007287n', 'bn:00088901v', 'the', 'root', 'cause', 'of', '<UNK>', ',', 'namely', 'the', 'section', '8', 'a', 'federal', 'bn:00064646n', 'under', 'whose', 'auspices', 'the', 'bn:00059799n', 'bn:00085337v', '.']
#
#
# dev batch 60 loss 6.668740 dev_batch_hit:8 dev_batch_char:13 batch_accuracy:61.538462
# ['they', 'do', 'at', 'least', 'bn:00085344v', 'to', 'bn:00093287v', 'that', 'the', 'bn:00023301n', 'might', 'bn:00086682v', 'to', 'bn:00084711v', '``', 'rigid', 'affirmative', 'action', 'bn:00062759n', '.', '``']
# ['they', 'do', 'at', 'least', 'bn:00085344v', 'to', 'bn:00093291v', 'that', 'the', 'bn:00023301n', 'might', 'bn:00086682v', 'to', 'bn:00087608v', '``', 'rigid', 'affirmative', 'action', 'bn:00064646n', '.', '``']
#
#
# ['program', 'like', 'section', '8', 'a', 'be', 'a', 'little', 'like', 'bn:00090272v', 'bn:00040921n', 'bn:00046209n', 'the', 'street', 'and', 'then', 'bn:00087894v', 'bn:00075412n', 'when', 'thief', 'bn:00095597v', 'by', 'to', 'bn:00083441v', 'it', 'up', '.']
# ['program', 'like', 'section', '8', 'a', 'be', 'a', 'little', 'like', 'bn:00090271v', 'bn:00006911n', 'in', 'the', 'street', 'and', 'then', 'bn:00087778v', 'bn:00075412n', 'when', 'thief', 'bn:00095597v', 'by', 'to', 'bn:00090351v', 'it', 'up', '.']
#
#
# ['numerous', 'other', 'scandal', ',', 'among', 'they', 'the', 'bn:00000005n', 'at', 'bn:00026324n', ',', 'bn:00089240v', 'the', 'same', 'bn:00017761n', 'as', 'wedtech', '.']
# ['numerous', 'other', 'scandal', ',', 'among', 'they', 'the', 'bn:00058969n', 'at', '<UNK>', ',', 'bn:00088078v', 'the', 'same', 'bn:00017761n', 'as', '<UNK>', '.']
#
#
# ['they', 'bn:00085337v', 'bn:00046209n', 'government', 'bn:00062759n', 'that', 'bn:00082690v', 'tailor-made', 'for', 'corruption', '.']
# ['they', 'bn:00085337v', 'in', 'government', 'bn:00064646n', 'that', 'bn:00082690v', 'tailor-made', 'for', 'corruption', '.']
#
#
# dev batch 64 loss 8.830941 dev_batch_hit:8 dev_batch_char:18 batch_accuracy:44.444444
# ['why', 'be', 'bn:00062759n', 'like', 'this', 'not', 'bn:00087115v', '?']
# ['why', 'be', 'bn:00064646n', 'like', 'this', 'not', 'bn:00087115v', '?']
#
#
# ['``', 'feeding', 'frenzy', '``', 'do', 'bn:00088643v', 'a', 'few', 'bn:00020058n', '.']
# ['``', 'feeding', 'frenzy', '``', 'do', 'bn:00088643v', 'a', 'few', 'bn:00019749n', '.']
#
#
# ['bn:00046209n', 'and', 'around', 'bn:00096798a', 'level', 'of', 'government', 'bn:00046209n', 'the', 'u.s.', 'be', 'bn:00041942n', 'of', 'bn:00061450n', 'who', 'can', 'best', 'be', 'bn:00086612v', 'as', 'bn:00083386v', 'to', 'a', 'political', 'insider', 'commercial', 'party', '.']
# ['in', 'and', 'around', 'all', 'level', 'of', 'government', 'in', 'the', 'u.s.', 'be', 'bn:00041942n', 'of', 'bn:00061450n', 'who', 'can', 'best', 'be', 'bn:00086612v', 'as', 'bn:00083389v', 'to', 'a', 'political', 'insider', 'commercial', 'party', '.']
#
#
# ['they', 'bn:00085261v', 'that', 'whenever', 'bn:00007299n', 'be', 'bn:00092580v', 'bn:00080746n', ',', 'bn:00086713v', 'bn:00020982n', 'or', 'bn:00085644v', 'a', 'large', 'defense', 'bn:00031641n', ',', 'there', 'be', 'big', 'bn:00055644n', 'to', 'be', 'bn:00087106v', 'bn:00046209n', 'bn:00086713v', ',', 'bn:00001975n', 'or', 'sell', 'the', 'process', 'and', 'bn:00021584n', 'of', 'government', '.']
# ['they', 'bn:00085261v', 'that', 'whenever', 'bn:00007299n', 'be', 'bn:00092580v', 'bn:00067741n', ',', 'bn:00088990v', 'bn:00020982n', 'or', 'bn:00090039v', 'a', 'large', 'defense', 'bn:00031641n', ',', 'there', 'be', 'big', 'bn:00055645n', 'to', 'be', 'bn:00084089v', 'in', 'bn:00082304v', ',', '<UNK>', 'or', 'sell', 'the', 'process', 'and', 'bn:00021584n', 'of', 'government', '.']
#
#
# dev batch 68 loss 9.181822 dev_batch_hit:11 dev_batch_char:20 batch_accuracy:55.000000
# ['they', 'be', 'we', 'version', 'of', 'the', 'bn:00029050n', 'bloc', "'s", 'bn:00057879n', 'and', 'they', 'bn:00089240v', 'absolutely', 'no', 'bn:00080435n', 'to', 'bn:00093430v', 'anything', 'bn:00084769v', '.']
# ['they', 'be', 'we', 'version', 'of', 'the', 'east', 'bloc', "'s", '<UNK>', 'and', 'they', 'bn:00087863v', 'absolutely', 'no', 'bn:00080435n', 'to', 'bn:00088205v', 'anything', 'bn:00084769v', '.']
#
#
# ['how', 'many', 'government', 'program', 'and', 'policy', 'bn:00083184v', 'because', 'they', 'bn:00014138n', 'the', 'bn:00063155n', 'of', 'political', 'insider', '?']
# ['how', 'many', 'government', 'program', 'and', 'policy', 'bn:00083184v', 'because', 'they', 'bn:00051289n', 'the', 'bn:00063157n', 'of', 'political', 'insider', '?']
#
#
# ['this', 'be', 'the', 'real', 'bn:00047688n', 'bn:00084110v', 'by', 'the', 'wedtech', 'scandal', '.']
# ['this', 'be', 'the', 'real', 'bn:00047688n', 'bn:00084112v', 'by', 'the', '<UNK>', 'scandal', '.']
#
#
# ['mr.', 'bn:00001861n', 'be', 'chairman', 'and', 'chief', 'executive', 'officer', 'of', 'the', 'bn:00107267a', 'york', 'state', 'bn:00113439a', 'development', 'corp.', ',', '1983-85', '.']
# ['mr.', 'stern', 'be', 'chairman', 'and', 'chief', 'executive', 'officer', 'of', 'the', 'new', 'york', 'state', 'urban', 'development', 'corp.', ',', '<UNK>', '.']
#
#
# dev batch 72 loss 8.852841 dev_batch_hit:4 dev_batch_char:9 batch_accuracy:44.444444
# ['i', 'have', 'to', 'bn:00082226v', 'back', 'to', 'french', '101', 'when', 'the', 'monsieur', 'avec', 'bn:00019859n', 'bn:00082613v', 'over', 'my', 'shoulder', 'during', 'the', 'coffee', 'phase', 'of', 'dinner', 'and', 'bn:00082817v', 'whether', 'i', 'bn:00086682v', 'to', 'bn:00086607v', 'bn:00046209n', 'a', 'montgolfiere', '.']
# ['i', 'have', 'to', 'bn:00087917v', 'back', 'to', 'french', '101', 'when', 'the', 'monsieur', '<UNK>', '<UNK>', 'bn:00082613v', 'over', 'my', 'shoulder', 'during', 'the', 'coffee', 'phase', 'of', 'dinner', 'and', 'bn:00082817v', 'whether', 'i', 'bn:00086682v', 'to', 'bn:00093014v', 'in', 'a', '<UNK>', '.']
#
#
# ['i', 'be', 'a', 'last-minute', 'bn:00092424v', 'bn:00089826v', 'bn:00007018n', 'at', 'a', 'french', 'journalism', 'convention', 'and', 'so', 'far', 'the', 'festivity', 'have', 'be', 'bn:00094792v', 'entirely', 'by', 'eating', ',', 'drinking', ',', 'bn:00072322n', ',', 'sleeping', 'and', 'drinking', '.']
# ['i', 'be', 'a', 'last-minute', 'bn:00092429v', '<UNK>', '<UNK>', 'at', 'a', 'french', 'journalism', 'convention', 'and', 'so', 'far', 'the', 'festivity', 'have', 'be', 'bn:00094794v', 'entirely', 'by', 'eating', ',', 'drinking', ',', '<UNK>', ',', 'sleeping', 'and', 'drinking', '.']
#
#
# ['the', 'bn:00044576n', 'with', 'the', 'bn:00019859n', 'bn:00092837v', 'a', 'bn:00103887a', 'bn:00007011n', 'to', 'bn:00084088v', 'a', 'bn:00010728n', 'of', 'bn:00050333n', 'sportif', 'into', 'we', 'itinerary', '.']
# ['the', 'bn:00001533n', 'with', 'the', '<UNK>', 'bn:00083187v', 'a', '<UNK>', 'bn:00007011n', 'to', 'bn:00089861v', 'a', 'bn:00010726n', 'of', 'les', '<UNK>', 'into', 'we', 'itinerary', '.']
#
#
# ['but', 'as', 'the', 'french', 'bn:00083189v', 'a', 'zen-like', 'bn:00074009n', 'of', 'bn:00098529a', 'when', 'it', 'bn:00083240v', 'athletics', 'bn:00082844v', 'bn:00086708v', 'a', 'nautilus', 'bn:00052556n', 'bn:00046209n', 'pari', ',', 'my', 'fellow', 'conventioner', 'be', 'bn:00089240v', 'none', 'of', 'it', '.']
# ['but', 'as', 'the', 'french', 'bn:00083725v', 'a', '<UNK>', 'bn:00074009n', 'of', '<UNK>', 'when', 'it', 'bn:00085383v', 'athletics', 'bn:00082844v', 'bn:00086708v', 'a', 'nautilus', 'bn:00052556n', 'in', '<UNK>', ',', 'my', 'fellow', '<UNK>', 'be', 'bn:00082198v', 'none', 'of', 'it', '.']
#
#
# dev batch 76 loss 6.464544 dev_batch_hit:8 dev_batch_char:19 batch_accuracy:42.105263
# ['the', 'bn:00027185n', 'at', 'my', 'table', 'simply', 'bn:00089584v', 'more', 'gauloise', 'and', 'bn:00083133v', 'at', 'the', 'suggestion', 'of', 'bn:00083995v', 'a', 'perfectly', 'good', 'saturday', 'bn:00035851n', 'to', 'go', 'bn:00041026n', 'or', 'even', 'montgolfing', 'ballooning', 'to', 'you', ';', 'the', 'brother', 'bn:00047864n', ',', 'french', 'of', 'course', ',', 'be', 'the', 'world', "'s", 'first', 'hot-air', 'bn:00008196n', '.']
# ['the', '<UNK>', 'at', 'my', 'table', 'simply', 'bn:00088230v', 'more', '<UNK>', 'and', 'bn:00083133v', 'at', 'the', 'suggestion', 'of', 'bn:00083995v', 'a', 'perfectly', 'good', 'saturday', 'bn:00035851n', 'to', 'go', '<UNK>', 'or', 'even', '<UNK>', 'ballooning', 'to', 'you', ';', 'the', 'brother', '<UNK>', ',', 'french', 'of', 'course', ',', 'be', 'the', 'world', "'s", 'first', '<UNK>', '<UNK>', '.']
#
#
# ['back', 'bn:00046209n', 'the', 'bn:00003341n', 'this', 'bn:00035907n', 'of', 'chi-chi', 'airborne', 'activity', 'bn:00095777v', 'heartwarmingly', 'bn:00100581a', 'bn:00004451n', '.']
# ['back', 'in', 'the', '<UNK>', 'this', 'kind', 'of', 'chi-chi', 'airborne', 'activity', 'bn:00082399v', '<UNK>', '<UNK>', 'bn:00067180n', '.']
#
#
# ['as', 'bn:00046209n', ':', '``', 'you', 'go', 'bn:00008187n', '?', '?', '!', '!']
# ['as', 'in', ':', '``', 'you', 'go', '<UNK>', '?', '?', '!', '!']
#
#
# ['bn:00046209n', 'france', '?', '?', '!', '!', '``']
# ['in', 'france', '?', '?', '!', '!', '``']
#
#
# dev batch 80 loss 10.109335 dev_batch_hit:3 dev_batch_char:6 batch_accuracy:50.000000
# ['american', 'it', 'bn:00082690v', 'have', 'bn:00082139v', 'malcolm', 'forbe', "'s", 'hot-air', 'bn:00050340n', 'and', 'bn:00088035v', 'ballooning', 'bn:00046209n', 'a', 'heady', 'bn:00033729n', '.']
# ['american', 'it', 'bn:00082693v', 'have', 'bn:00088426v', 'malcolm', '<UNK>', "'s", '<UNK>', 'bn:00050342n', 'and', 'bn:00094791v', 'ballooning', 'in', 'a', 'heady', 'way', '.']
#
#
# ['during', 'the', 'past', '25', 'year', ',', 'the', 'bn:00058285n', 'of', 'bn:00008196n', 'those', 'who', 'have', 'bn:00085337v', 'a', 'federal', 'aviation', 'authority', 'bn:00105968a', 'bn:00076647n', 'have', 'bn:00089872v', 'from', 'a', 'bn:00023268n', 'hundred', 'to', 'several', 'thousand', ',', 'with', 'bn:00110911a', 'bn:00005164n', 'bn:00091177v', 'as', 'high', 'as', '10,000', '.']
# ['during', 'the', 'past', '25', 'year', ',', 'the', 'bn:00034394n', 'of', '<UNK>', 'those', 'who', 'have', 'bn:00090590v', 'a', 'federal', 'aviation', 'authority', '<UNK>', 'bn:00032089n', 'have', 'bn:00094668v', 'from', 'a', 'couple', 'hundred', 'to', 'several', 'thousand', ',', 'with', 'some', 'bn:00005164n', 'bn:00092360v', 'as', 'high', 'as', '<UNK>', '.']
#
#
# ['bn:00110911a', '30', 'balloon', 'show', 'be', 'bn:00089384v', 'annually', 'bn:00046209n', 'the', 'u.s.', ',', 'bn:00089660v', 'the', 'world', "'s", 'largest', 'bn:00022390n', 'of', 'ersatz', 'phinea', 'fogg', '--', 'the', 'nine-day', 'bn:00002494n', 'bn:00047146n', 'balloon', 'fiesta', 'that', 'bn:00082920v', 'bn:00110911a', '800,000', 'enthusiast', 'and', 'more', 'than', '500', 'bn:00008187n', ',', 'bn:00110911a', 'of', 'which', 'be', 'fetchingly', 'bn:00086713v', 'to', 'bn:00092876v', 'carman', 'miranda', ',', 'bn:00037335n', 'or', 'a', '12-story-high', 'bn:00021666n', '.']
# ['some', '30', 'balloon', 'show', 'be', 'bn:00088818v', 'annually', 'in', 'the', 'u.s.', ',', 'bn:00089660v', 'the', 'world', "'s", 'largest', '<UNK>', 'of', 'ersatz', '<UNK>', 'fogg', '<UNK>', 'the', '<UNK>', '<UNK>', 'international', 'balloon', 'fiesta', 'that', 'bn:00082920v', 'some', '<UNK>', 'enthusiast', 'and', 'more', 'than', '500', 'bn:00008187n', ',', 'some', 'of', 'which', 'be', '<UNK>', 'bn:00088490v', 'to', 'bn:00092876v', '<UNK>', 'miranda', ',', '<UNK>', 'or', 'a', '<UNK>', '<UNK>', '.']
#
#
# ['the', 'bn:00021666n', 'bn:00008187n', 'be', 'bn:00086591v', 'official', 'entry', 'bn:00021644n', 'this', 'year', '.']
# ['the', '<UNK>', 'bn:00008187n', 'be', 'bn:00086593v', 'official', 'entry', 'bn:00063703n', 'this', 'year', '.']
#
#
# dev batch 84 loss 10.483840 dev_batch_hit:6 dev_batch_char:19 batch_accuracy:31.578947
# ['but', 'bn:00046209n', 'epinal', ',', 'a', 'bn:00041510n', '16th-century', 'river', 'town', 'adjacent', 'to', 'france', "'s", 'vosge', 'mountain', 'region', ',', 'none', 'of', 'these', 'yankee-come-lately', 'enthusiasm', 'for', 'thing', 'aloft', 'be', 'evident', '.']
# ['but', 'in', '<UNK>', ',', 'a', 'gray', '<UNK>', 'river', 'town', 'adjacent', 'to', 'france', "'s", '<UNK>', 'mountain', 'region', ',', 'none', 'of', 'these', '<UNK>', 'enthusiasm', 'for', 'thing', 'aloft', 'be', 'evident', '.']
#
#
# ['ballooning', 'at', 'the', 'de', 'rigueur', 'hour', 'of', '6', 'bn:00096107a', 'bn:00089384v', 'bn:00096798a', 'the', 'bn:00007062n', 'for', 'most', 'people', 'of', 'sunrise', 'root-canal', 'work', '.']
# ['ballooning', 'at', 'the', 'de', '<UNK>', 'hour', 'of', '6', 'a.m.', 'bn:00089391v', 'all', 'the', 'bn:00007064n', 'for', 'most', 'people', 'of', 'sunrise', '<UNK>', 'work', '.']
#
#
# ['bn:00088095v', 'the', 'nagging', 'of', 'a', 'culture', 'imperative', ',', 'i', 'promptly', 'bn:00093738v', '.']
# ['bn:00088099v', 'the', 'nagging', 'of', 'a', 'culture', 'imperative', ',', 'i', 'promptly', 'bn:00093738v', '.']
#
#
# ['the', 'first', 'bn:00076921n', 'anybody', 'will', 'bn:00093287v', 'you', 'about', 'ballooning', 'be', 'that', 'it', 'bn:00082820v', 'bn:00007146n', 'bn:00046209n', 'the', 'bn:00033729n', 'of', 'athletic', 'prowess', ',', 'or', 'even', 'a', 'measure', 'of', 'bn:00026476n', '.']
# ['the', 'first', 'bn:00076923n', 'anybody', 'will', 'bn:00094862v', 'you', 'about', 'ballooning', 'be', 'that', 'it', 'bn:00082822v', 'bn:00030821n', 'in', 'the', 'way', 'of', 'athletic', 'prowess', ',', 'or', 'even', 'a', 'measure', 'of', '<UNK>', '.']
#
#
# ...
# ['i', 'be', 'not', 'bn:00082412v', 'to', 'the', 'traditional', 'champagne', '<UNK>', 'during', 'the', '<UNK>', 'toast', '.']
#
#
# ['i', 'be', 'bn:00090943v', 'about', 'landing', 'bn:00046209n', 'a', 'canal', '.']
# ['i', 'be', 'bn:00094089v', 'about', 'landing', 'in', 'a', 'canal', '.']
#
#
# ['bn:00046209n', 'a', 'bn:00108813a', 'bn:00081157n', 'basket', '.']
# ['in', 'a', '<UNK>', '<UNK>', 'basket', '.']
#
#
# dev batch 96 loss 7.257422 dev_batch_hit:2 dev_batch_char:6 batch_accuracy:33.333333
# ['with', 'a', 'bn:00002306n', 'who', 'bn:00090943v', 'no', 'bn:00030862n', '.']
# ['with', 'a', 'bn:00002306n', 'who', 'bn:00094090v', 'no', 'english', '.']
#
#
# ['to', 'wit', ',', 'my', 'bn:00052801n', 'voyage', 'and', 'bn:00058211n', 'be', 'bn:00082412v', 'to', 'as', 'bn:00080052n', 'bn:00083341v', 'at', 'dawn', 'bn:00107820a', 'a', 'dew-sodden', 'fairway', 'and', 'bn:00084711v', 'at', 'noon', 'bn:00046209n', 'a', 'soggy', 'field', '.']
# ['to', 'wit', ',', 'my', 'maiden', 'voyage', 'and', '<UNK>', 'be', 'bn:00092621v', 'to', 'as', 'virgin', 'bn:00083345v', 'at', 'dawn', 'on', 'a', '<UNK>', 'fairway', 'and', 'bn:00084711v', 'at', 'noon', 'in', 'a', 'soggy', 'field', '.']
#
#
# ['balloon', 'bn:00031545n', 'almost', 'always', 'bn:00085337v', 'at', 'dawn', 'or', 'dusk', ',', 'when', 'the', 'wind', 'be', 'bn:00105937a', '.']
# ['balloon', 'bn:00035207n', 'almost', 'always', 'bn:00085337v', 'at', 'dawn', 'or', 'dusk', ',', 'when', 'the', 'wind', 'be', '<UNK>', '.']
#
#
# ['bn:00046209n', 'between', 'bn:00085320v', 'bn:00019222n', 'of', 'coffee', 'drinking', 'while', 'bn:00084662v', 'the', 'bn:00008187n', 'bn:00083681v', 'and', 'lot', 'of', 'bn:00094276v', 'around', 'bn:00086370v', 'who', 'would', 'bn:00088378v', 'bn:00046209n', 'what', 'balloon', 'and', 'bn:00046209n', 'what', 'order', 'the', 'bn:00008872n', 'bn:00089384v', 'no', 'more', 'than', 'four', 'passenger', '.']
# ['in', 'between', 'bn:00085327v', 'bn:00008985n', 'of', 'coffee', 'drinking', 'while', 'bn:00095665v', 'the', 'bn:00008187n', 'bn:00083058v', 'and', 'lot', 'of', 'bn:00094275v', 'around', 'bn:00086370v', 'who', 'would', 'bn:00088384v', 'in', 'what', 'balloon', 'and', 'in', 'what', 'order', 'the', 'bn:00008872n', 'bn:00085698v', 'no', 'more', 'than', 'four', 'passenger', '.']
#
#
# dev batch 100 loss 9.220271 dev_batch_hit:6 dev_batch_char:17 batch_accuracy:35.294118
# ['when', 'it', 'be', "n't", 'my', 'turn', 'bn:00046209n', 'the', 'balloon', 'i', 'bn:00083188v', 'its', 'bn:00001557n', 'from', 'the', '``', 'bn:00017920n', 'car', ',', '``', 'bn:00090400v', 'to', 'the', 'bn:00028795n', 'bn:00089427v', 'into', 'a', 'bn:00080378n', '.']
# ['when', 'it', 'be', '<UNK>', 'my', 'turn', 'in', 'the', 'balloon', 'i', 'bn:00088427v', 'its', 'bn:00001548n', 'from', 'the', '``', 'chase', 'car', ',', '``', 'bn:00090400v', 'to', 'the', 'bn:00028795n', 'bn:00089427v', 'into', 'a', '<UNK>', '.']
#
#
# ['after', 'long', 'stretch', 'of', 'this', 'attendant', 'ground', 'activity', 'bn:00085320v', '20', 'or', 'so', 'lovely', 'bn:00055094n', 'of', 'bn:00087308v', 'above', 'the', 'vosge', 'bn:00084662v', 'the', 'bn:00001887n', 'mist', 'bn:00082761v', 'off', 'the', 'river', 'and', 'the', 'french', 'bn:00023381n', 'bn:00082569v', 'about', 'the', 'field', '.']
# ['after', 'long', 'stretch', 'of', 'this', 'attendant', 'ground', 'activity', 'bn:00085327v', '20', 'or', 'so', 'lovely', 'bn:00055094n', 'of', 'bn:00083195v', 'above', 'the', '<UNK>', 'bn:00095665v', 'the', 'silver', 'mist', 'bn:00082761v', 'off', 'the', 'river', 'and', 'the', 'french', 'bn:00023381n', 'bn:00082569v', 'about', 'the', 'field', '.']
#
#
# ['it', "'", 'hard', 'not', 'to', 'bn:00088095v', 'that', 'god', "'s", 'bn:00046209n', 'he', 'heaven', 'with', 'this', 'bn:00035907n', 'of', 'bn:00098445a', 'view', 'of', 'the', 'world', ',', 'even', 'if', 'you', 'pilote', 'bn:00046209n', 'silly', 'plaid', 'bn:00010003n', 'bn:00089384v', 'bn:00085415v', 'how', '``', 'bn:00009771n', '``', 'it', 'bn:00096798a', 'be', '.']
# ['it', "'", 'hard', 'not', 'to', 'bn:00088095v', 'that', 'god', "'s", 'in', 'he', 'heaven', 'with', 'this', 'kind', 'of', '<UNK>', 'view', 'of', 'the', 'world', ',', 'even', 'if', 'you', '<UNK>', 'in', 'silly', 'plaid', '<UNK>', 'bn:00085714v', 'bn:00085415v', 'how', '``', 'belle', '``', 'it', 'all', 'be', '.']
#
#
# ['eventually', 'little', 'french', 'farmer', 'and', 'they', 'little', 'french', 'farmwife', 'bn:00085320v', 'out', 'of', 'they', 'stone', 'house', 'and', 'bn:00092204v', 'they', 'bn:00042759n', 'above', 'they', 'tiny', 'eye', 'and', 'bn:00094230v', 'at', 'we', '.']
# ['eventually', 'little', 'french', 'farmer', 'and', 'they', 'little', 'french', 'farmwife', 'bn:00085319v', 'out', 'of', 'they', 'stone', 'house', 'and', 'bn:00090224v', 'they', 'bn:00042759n', 'above', 'they', 'tiny', 'eye', 'and', 'bn:00094232v', 'at', 'we', '.']
#
#
# dev batch 104 loss 7.245068 dev_batch_hit:10 dev_batch_char:19 batch_accuracy:52.631579
# ['no', 'wonder', '.']
# ['no', 'wonder', '.']
#
#
# ['we', 'be', 'bn:00085320v', 'down', 'straight', 'into', 'they', 'canal', '.']
# ['we', 'be', 'bn:00085319v', 'down', 'straight', 'into', 'they', 'canal', '.']
#
#
# ['bn:00093430v', ',', 'the', 'other', 'rule', 'of', 'thumb', 'about', 'ballooning', 'be', 'that', 'you', 'ca', "n't", 'bn:00094331v', '.']
# ['bn:00092443v', ',', 'the', 'other', 'rule', 'of', 'thumb', 'about', 'ballooning', 'be', 'that', 'you', 'ca', '<UNK>', 'bn:00084792v', '.']
#
#
# ['and', 'neither', 'can', 'you', 'pilot', '.']
# ['and', 'neither', 'can', 'you', 'pilot', '.']
#
#
# dev batch 108 loss 6.758853 dev_batch_hit:0 dev_batch_char:3 batch_accuracy:0.000000
# ['you', 'can', 'bn:00083293v', 'only', 'up', 'or', 'down', 'by', 'bn:00089282v', 'the', 'balloon', "'s", 'bn:00002185n', 'with', 'a', 'bn:00064741n', 'bn:00014018n', ',', 'which', 'do', 'bn:00087106v', 'the', 'bn:00000942n', 'of', 'you', 'head', 'bn:00088095v', 'hot', 'and', 'bn:00086607v', 'the', 'air', 'bn:00024510n', '.']
# ['you', 'can', 'bn:00088912v', 'only', 'up', 'or', 'down', 'by', 'bn:00089282v', 'the', 'balloon', "'s", 'bn:00002185n', 'with', 'a', '<UNK>', 'bn:00014018n', ',', 'which', 'do', 'bn:00088736v', 'the', 'bn:00077607n', 'of', 'you', 'head', 'bn:00088100v', 'hot', 'and', 'bn:00093017v', 'the', 'air', 'bn:00024511n', '.']
#
#
# ['which', 'bn:00087106v', 'the', 'bn:00017920n', 'bn:00007309n', 'necessary', '.']
# ['which', 'bn:00088736v', 'the', 'chase', 'bn:00007309n', 'necessary', '.']
#
#
# ['most', 'bn:00008196n', 'seldom', 'bn:00088912v', 'higher', 'than', '2,000', 'foot', 'and', 'most', 'bn:00082951v', 'a', 'leisurely', '5-10', 'mile', 'a', 'bn:00044982n', '.']
# ['most', '<UNK>', 'seldom', 'bn:00088912v', 'higher', 'than', '<UNK>', 'foot', 'and', 'most', 'bn:00082952v', 'a', 'leisurely', '<UNK>', 'mile', 'a', 'bn:00000127n', '.']
#
#
# ['when', 'the', 'bn:00008187n', 'be', 'bn:00086100v', 'along', 'at', 'a', 'steady', 'altitude', 'there', 'be', 'little', 'sense', 'of', 'motion', '.']
# ['when', 'the', 'bn:00008187n', 'be', 'bn:00086101v', 'along', 'at', 'a', 'steady', 'altitude', 'there', 'be', 'little', 'sense', 'of', 'motion', '.']
#
#
# dev batch 112 loss 9.328485 dev_batch_hit:6 dev_batch_char:16 batch_accuracy:37.500000
# ['only', 'when', 'one', 'be', 'bn:00082803v', '--', 'or', 'bn:00046209n', 'we', 'case', 'bn:00085356v', 'a', 'bn:00070824n', 'trop', 'rapidement', '--', 'do', 'one', 'feel', ',', 'well', ',', 'airborne', 'bn:00046209n', 'a', 'picnic', 'basket', '.']
# ['only', 'when', 'one', 'be', 'bn:00082803v', '<UNK>', 'or', 'in', 'we', 'case', 'bn:00085356v', 'a', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'do', 'one', 'feel', ',', 'well', ',', 'airborne', 'in', 'a', 'picnic', 'basket', '.']
#
#
# ['``', 'what', "'", 'he', 'bn:00087106v', '?', '``', 'bn:00089343v', 'my', 'bn:00006532n', ',', 'who', 'be', 'the', 'only', 'other', 'bn:00102250a', 'member', 'of', 'the', 'convention', 'and', 'whose', 'knuckle', 'be', 'white', '.']
# ['``', 'what', "'", 'he', 'bn:00087107v', '?', '``', 'bn:00089345v', 'my', 'bn:00021281n', ',', 'who', 'be', 'the', 'only', 'other', '<UNK>', 'member', 'of', 'the', 'convention', 'and', 'whose', 'knuckle', 'be', 'white', '.']
#
#
# ['``', 'attention', ',', '``', 'bn:00084388v', 'we', 'bn:00002306n', 'as', 'we', 'bn:00008872n', 'bn:00090216v', 'into', 'the', 'canal', '.']
# ['``', 'attention', ',', '``', 'bn:00093372v', 'we', 'bn:00002306n', 'as', 'we', 'bn:00008872n', 'bn:00087425v', 'into', 'the', 'canal', '.']
#
#
# ['``', 'you', 'bet', 'attention', ',', '``', 'i', 'bn:00084388v', 'back', ',', 'bn:00083833v', 'atop', 'the', 'bn:00064741n', 'tank', ',', '``', 'i', 'be', 'bn:00089252v', 'bn:00002869n', 'bn:00013853n', '!', '``']
# ['``', 'you', 'bet', 'attention', ',', '``', 'i', 'bn:00093372v', 'back', ',', 'bn:00083833v', 'atop', 'the', '<UNK>', 'tank', ',', '``', 'i', 'be', 'bn:00089252v', '<UNK>', '<UNK>', '!', '``']
#
#
# dev batch 116 loss 9.831247 dev_batch_hit:6 dev_batch_char:12 batch_accuracy:50.000000
# ['we', 'bn:00002306n', 'simply', 'bn:00087901v', ',', 'fire', 'up', 'the', 'bn:00014018n', 'and', 'with', 'another', 'blast', 'of', 'flame', 'bn:00082761v', 'we', ',', 'oh', ',', 'a', 'good', '12-inch', 'above', 'the', 'water', 'level', '.']
# ['we', 'bn:00002306n', 'simply', 'bn:00087901v', ',', 'fire', 'up', 'the', 'bn:00014018n', 'and', 'with', 'another', 'blast', 'of', 'flame', 'bn:00084110v', 'we', ',', 'oh', ',', 'a', 'good', '<UNK>', 'above', 'the', 'water', 'level', '.']
#
#
# ['we', 'bn:00093316v', 'along', 'for', 'a', 'few', 'foot', 'before', 'he', 'bn:00090216v', 'we', 'into', 'the', 'drink', 'again', '.']
# ['we', 'bn:00093316v', 'along', 'for', 'a', 'few', 'foot', 'before', 'he', 'bn:00086849v', 'we', 'into', 'the', 'drink', 'again', '.']
#
#
# ['eventually', 'we', 'bn:00085320v', 'to', 'bn:00092903v', 'bn:00046209n', 'a', 'soggy', 'patch', 'of', 'field', 'where', 'we', 'bn:00089240v', 'the', 'exquisite', 'bn:00062972n', 'of', 'bn:00093364v', 'out', 'of', 'the', 'basket', 'into', 'the', 'mud', 'while', 'the', 'french', 'bn:00042601n', 'of', 'we', 'ballooning', 'tag', 'team', 'bn:00093364v', 'bn:00046209n', '.']
# ['eventually', 'we', 'bn:00085321v', 'to', 'bn:00092903v', 'in', 'a', 'soggy', 'patch', 'of', 'field', 'where', 'we', 'bn:00087863v', 'the', 'exquisite', 'bn:00026047n', 'of', 'bn:00085021v', 'out', 'of', 'the', 'basket', 'into', 'the', 'mud', 'while', 'the', 'french', 'bn:00042601n', 'of', 'we', 'ballooning', 'tag', 'team', 'bn:00085021v', 'in', '.']
#
#
# ['i', 'bn:00090448v', 'at', 'my', 'watch', '.']
# ['i', 'bn:00090448v', 'at', 'my', 'watch', '.']
#
#
# dev batch 120 loss 7.356912 dev_batch_hit:7 dev_batch_char:14 batch_accuracy:50.000000
# ['barely', 'half-an-hour', 'aloft', '.']
# ['barely', '<UNK>', 'aloft', '.']
#
#
# ['back', 'bn:00046209n', 'the', 'bn:00017920n', 'car', ',', 'we', 'bn:00087328v', 'around', 'bn:00110911a', 'more', ',', 'bn:00082276v', 'bn:00083731v', 'a', 'ditch', ',', 'bn:00087632v', 'the', 'bn:00002155n', 'of', 'a', 'local', 'bn:00033687n', 'to', 'bn:00087724v', 'the', 'trailer', 'bn:00029243n', 'and', 'bn:00087277v', 'we', 'out', 'of', 'the', 'ditch', '.']
# ['back', 'in', 'the', 'chase', 'car', ',', 'we', 'bn:00087328v', 'around', 'some', 'more', ',', 'bn:00083293v', 'bn:00083731v', 'a', 'ditch', ',', 'bn:00087632v', 'the', 'bn:00002155n', 'of', 'a', 'local', 'bn:00033687n', 'to', 'bn:00084102v', 'the', 'trailer', 'bn:00044283n', 'and', 'bn:00087277v', 'we', 'out', 'of', 'the', 'ditch', '.']
#
#
# ['we', 'finally', 'bn:00067110n', 'with', 'we', 'bn:00008187n', ',', 'which', 'have', 'bn:00085320v', 'to', 'bn:00092903v', 'bn:00107820a', 'a', 'dirt', 'road', 'amid', 'a', 'clutch', 'of', 'epinaler', 'who', 'bn:00084662v', 'we', 'bn:00083956v', 'we', 'bn:00023496n', '--', 'another', 'half-an-hour', 'of', 'non-flight', 'bn:00001128n', '--', 'that', 'bn:00089660v', 'the', 'precision', 'bn:00055504n', 'of', 'bn:00089958v', 'the', 'balloon', 'to', 'the', 'ground', ',', 'bn:00091762v', 'bn:00096798a', 'the', 'bn:00002185n', 'out', 'of', 'it', ',', 'bn:00088640v', 'it', 'up', 'and', 'bn:00084916v', 'it', 'and', 'the', 'bn:00008872n', 'into', 'the', 'trailer', '.']
# ['we', 'finally', '<UNK>', 'with', 'we', 'bn:00008187n', ',', 'which', 'have', 'bn:00085321v', 'to', 'bn:00092903v', 'on', 'a', 'dirt', 'road', 'amid', 'a', 'clutch', 'of', '<UNK>', 'who', 'bn:00095665v', 'we', 'bn:00083956v', 'we', 'bn:00023497n', '<UNK>', 'another', '<UNK>', 'of', '<UNK>', 'bn:00001172n', '<UNK>', 'that', 'bn:00089660v', 'the', 'precision', 'bn:00055504n', 'of', 'bn:00089958v', 'the', 'balloon', 'to', 'the', 'ground', ',', 'bn:00091762v', 'all', 'the', 'bn:00002185n', 'out', 'of', 'it', ',', 'bn:00084241v', 'it', 'up', 'and', 'bn:00085958v', 'it', 'and', 'the', 'bn:00008872n', 'into', 'the', 'trailer', '.']
#
#
# ['it', 'be', 'the', 'most', 'bn:00032203n', 'we', "'d", 'bn:00089240v', 'bn:00096798a', 'morning', 'and', 'it', 'be', 'bn:00083188v', 'by', 'we', 'bn:00087328v', 'immediately', 'to', 'the', 'nearest', 'bn:00049619n', 'hole', '.']
# ['it', 'be', 'the', 'most', 'bn:00032203n', 'we', '<UNK>', 'bn:00087863v', 'all', 'morning', 'and', 'it', 'be', 'bn:00085342v', 'by', 'we', 'bn:00087328v', 'immediately', 'to', 'the', 'nearest', '<UNK>', 'hole', '.']
#
#
# dev batch 124 loss 9.188880 dev_batch_hit:17 dev_batch_char:28 batch_accuracy:60.714286
# ['this', 'bn:00089805v', 'bn:00092969v', 'to', 'the', 'golf', 'course', ',', 'where', 'we', 'bn:00084662v', 'a', 'few', 'french', 'bn:00029065n', 'bn:00053891n', 'the', 'first', 'bn:00076358n', 'while', 'we', 'bn:00093776v', 'under', 'cinzano', 'umbrella', ',', 'i', 'nurse', 'a', 'bn:00031614n', 'and', 'my', 'bn:00029934n', '.']
# ['this', 'bn:00087672v', 'bn:00092969v', 'to', 'the', 'golf', 'course', ',', 'where', 'we', 'bn:00095665v', 'a', 'few', 'french', 'bn:00029065n', '<UNK>', 'the', 'first', 'bn:00076358n', 'while', 'we', 'bn:00093776v', 'under', '<UNK>', 'umbrella', ',', 'i', 'nurse', 'a', '<UNK>', 'and', 'my', 'bn:00029934n', '.']
#
#
# ['a', 'whole', 'morning', 'of', 'ballooning', 'and', 'i', 'have', 'be', 'off', 'the', 'ground', 'barely', '30', 'bn:00055094n', '.']
# ['a', 'whole', 'morning', 'of', 'ballooning', 'and', 'i', 'have', 'be', 'off', 'the', 'ground', 'barely', '30', 'minute', '.']
#
#
# ['still', ',', 'i', 'bn:00084374v', 'the', 'event', "'s", 'envy-quotient', 'back', 'bn:00046209n', 'the', 'bn:00003341n', 'be', 'near', 'peerless', '.']
# ['still', ',', 'i', 'bn:00084374v', 'the', 'event', "'s", '<UNK>', 'back', 'in', 'the', '<UNK>', 'be', 'near', 'peerless', '.']
#
#
# ['as', 'for', 'the', 'ride', 'back', 'to', 'camp', ',', 'we', 'pilot', 'and', 'bn:00096798a', 'the', 'other', 'bn:00103322a', 'passenger', 'bn:00085021v', 'into', 'the', 'bn:00017920n', 'car', '.']
# ['as', 'for', 'the', 'ride', 'back', 'to', 'camp', ',', 'we', 'pilot', 'and', 'all', 'the', 'other', '<UNK>', 'passenger', 'bn:00085021v', 'into', 'the', 'chase', 'car', '.']
#
#
# dev batch 128 loss 7.454542 dev_batch_hit:7 dev_batch_char:9 batch_accuracy:77.777778
# ['my', 'american', 'companion', 'and', 'i', 'be', 'bn:00088939v', 'to', 'bn:00086607v', 'alfresco', 'bn:00046209n', 'the', 'bn:00081157n', 'basket', '.']
# ['my', 'american', 'companion', 'and', 'i', 'be', 'bn:00090271v', 'to', 'bn:00093014v', 'alfresco', 'in', 'the', '<UNK>', 'basket', '.']
#
#
# ['as', 'we', 'bn:00094432v', 'by', 'a', 'bn:00098529a', 'bn:00037631n', ',', 'i', 'could', "n't", 'bn:00089411v', 'bn:00092450v', 'up', 'bn:00107820a', 'my', 'soggy', 'bn:00013853n', 'and', 'bn:00087322v', '.']
# ['as', 'we', 'bn:00094432v', 'by', 'a', '<UNK>', '<UNK>', ',', 'i', 'could', '<UNK>', 'bn:00089411v', 'bn:00092450v', 'up', 'on', 'my', 'soggy', '<UNK>', 'and', 'bn:00091982v', '.']
#
#
# ['bn:00056182n', 'de', 'vry', 'be', 'a', 'free-lance', 'writer', '.']
# ['<UNK>', 'de', '<UNK>', 'be', 'a', 'free-lance', 'writer', '.']
#
#
# dev batch 132 loss 6.528559 dev_batch_hit:3 dev_batch_char:6 batch_accuracy:50.000000
# Valid Epoch 5 loss 8.084133
# dev_hit_all:207 dev_all_char:443 accuracy:46.726862
# --------------------------------
# Model saved in path: /content/gdrive/My Drive/NLPHW3/POS_WnDomain_SenseEmbed_models_46.72686230248307/model.ckpt

# %% [markdown]
# **- setting file addresses for reading data and writing new files**

# %% [markdown]
# **- function for parsing large xml file and getting needed data from that.**
